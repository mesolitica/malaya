# %%
import fasttext

# %%
model = fasttext.train_supervised('shuf-train-fasttext.txt', dim = 24, minn = 2, loss = 'hs', )
# Out:
# Read 1365M words
# Number of words:  10293218
# Number of labels: 10
# Progress: 100.0% words/sec/thread: 5361408 lr:  0.000000 avg.loss:  0.363748 ETA:   0h 0m 0s

# %%
model.save_model("model-24.bin")

# %%
cutoff = int(len(model.get_words()) * 0.2)

# %%
# %%time
model.predict("bodo siak", k = 3)
# Out:
# CPU times: user 42 µs, sys: 1 µs, total: 43 µs
# Wall time: 44.1 µs
# (('__label__local-malay',
#   '__label__local-english',
#   '__label__socialmedia-indonesian'),
#  array([0.96265656, 0.03594289, 0.0013367 ]))

# %%
# %%time
model.predict("rada ketuaan kalo umur masih pas lebih bagus lg aishwarya", k = 3)
# Out:
# CPU times: user 26 µs, sys: 0 ns, total: 26 µs
# Wall time: 27.9 µs
# (('__label__socialmedia-indonesian',
#   '__label__local-malay',
#   '__label__standard-malay'),
#  array([9.99964595e-01, 6.27807312e-05, 2.25839340e-05]))

# %%
# !head -n 2 filter-twitter-malay-rojak-id.jsonl.dedup
# Out:
# "rada ketuaan kalo umur masih pas lebih bagus lg aishwarya"
# "ada kursi gaa soalnya nunggu kamu pegel kalo sambil berdiri"

# %%
model.quantize(input='shuf-train-fasttext.txt', retrain=True, qnorm=True, cutoff = cutoff)
# Out:
# Progress:  26.1% words/sec/thread: 5735748 lr:  0.074096 avg.loss:  0.361211 ETA:   0h 0m46s

# %%
model.save_model("model-24.ftz")
# Out:
# Progress: 100.0% words/sec/thread: 5652483 lr:  0.000000 avg.loss:  0.335071 ETA:   0h 0m 0s
