# %% [markdown]
# # Extract general Malaya entities

# %% [markdown]
# <div class="alert alert-info">
#
# This tutorial is available as an IPython notebook at [Malaya/example/general-malaya-entities](https://github.com/huseinzol05/Malaya/tree/master/example/general-malaya-entities).
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
# This module only use Regex to extract entities.
#
# </div>

# %%
import logging

logging.basicConfig(level=logging.INFO)

# %%
# %%time
import malaya
# Out:
# CPU times: user 3.34 s, sys: 3.4 s, total: 6.73 s
# Wall time: 2.41 s

# %% [markdown]
# ## Load general Malaya entity model
#
# This model able to classify,
#
# 1. date
# 2. money
# 3. temperature
# 4. distance
# 5. volume
# 6. duration
# 7. phone
# 8. email
# 9. url
# 10. time
# 11. datetime
# 12. local and generic foods, can check available rules in `malaya.texts.entity.food`
# 13. local and generic drinks, can check available rules in `malaya.texts.entity.food`
#
# We can insert BERT or any deep learning model by passing `malaya.entity.general_entity(model = model)`, as long the model has `predict` method and return `[(string, label), (string, label)]`. This is an optional.

# %%
entity = malaya.entity.general_entity()

# %% [markdown]
# ### Examples

# %%
entity.predict('Husein baca buku Perlembagaan yang berharga 3k ringgit dekat kfc sungai petani minggu lepas, 2 ptg 2 oktober 2019 , suhu 32 celcius, sambil makan ayam goreng dan milo o ais')
# Out:
# {'date': {'2 oktober 2019': datetime.datetime(2019, 10, 2, 0, 0),
#   'minggu lalu': datetime.datetime(2022, 12, 23, 15, 14, 38, 952986)},
#  'money': {'3k ringgit': 'RM3000.0'},
#  'temperature': ['32 celcius'],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {'2 PM': datetime.datetime(2022, 12, 30, 14, 0)},
#  'datetime': {'2 ptg 2 oktober 2019': datetime.datetime(2019, 10, 2, 14, 0)},
#  'food': ['ayam goreng'],
#  'drink': ['milo o ais'],
#  'weight': []}

# %%
entity.predict('contact Husein at husein.zol05@gmail.com')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': ['husein.zol05@gmail.com'],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %%
entity.predict('tolong tempahkan meja makan makan nasi dagang dan jus apple, milo tarik esok dekat Restoran Sebulek')
# Out:
# {'date': {'esok': datetime.datetime(2022, 12, 31, 15, 14, 39, 207849)},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': ['nasi dagang'],
#  'drink': ['milo tarik', 'jus apple'],
#  'weight': []}

# %% [markdown]
# ### date

# %%
entity.predict('husein balik rumah pada 2/12/2022')
# Out:
# {'date': {'2/12/2022': datetime.datetime(2022, 2, 12, 0, 0)},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %%
entity.predict('husein balik rumah pada 2 jan 2022')
# Out:
# {'date': {'2 jan 2022': datetime.datetime(2022, 1, 2, 0, 0)},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %%
entity.predict('husein balik rumah pada 2022 mac 2')
# Out:
# {'date': {'2022 mac 2': datetime.datetime(2022, 3, 2, 0, 0)},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %% [markdown]
# ### money

# %%
entity.predict('harga buku 2 ringgit')
# Out:
# {'date': {},
#  'money': {'2 ringgit': 'RM2'},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %%
entity.predict('harga buku rm2.50 sen')
# Out:
# {'date': {},
#  'money': {'rm2.50 ': 'RM2.50'},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %%
entity.predict('harga buku 5.34k ringgit')
# Out:
# {'date': {},
#  'money': {'5.34k ringgit': 'RM5340.0'},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %%
entity.predict('harga buku 5.34m ringgit')
# Out:
# {'date': {},
#  'money': {'5.34m ringgit': 'RM5340000.0'},
#  'temperature': [],
#  'distance': ['5.34m'],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %%
entity.predict('harga buku 5.34b ringgit')
# Out:
# {'date': {},
#  'money': {'5.34b ringgit': 'RM5340000000.0'},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %%
entity.predict('harga buku rm 5.2')
# Out:
# {'date': {},
#  'money': {'rm 5.2': 'RM5.2'},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %% [markdown]
# ### temperature

# %%
entity.predict('suhu harini 21.3c')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': ['21.3c'],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %%
entity.predict('suhu harini 21.3    c')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': ['21.3 c'],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %% [markdown]
# ### distance

# %%
entity.predict('sejauh 10 batu')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': [],
#  'distance': ['10 batu'],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %%
entity.predict('sejauh 10.234    km')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': [],
#  'distance': ['10.234 km'],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %% [markdown]
# ### volume

# %%
entity.predict('volume 21.2ml')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': ['21.2ml'],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %% [markdown]
# ### duration

# %%
entity.predict('duration 2jam')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': ['2jam'],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {'2jam': datetime.datetime(2022, 12, 30, 13, 14, 39, 341699)},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %%
entity.predict('duration sejam')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': ['sejam'],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %% [markdown]
# ### phone

# %%
entity.predict('no telepon 013-1111111')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': ['013-1111111'],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %% [markdown]
# ### email

# %%
entity.predict('email at husein@email.com')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': ['husein@email.com'],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %% [markdown]
# ### URL

# %%
entity.predict('website di https://huseinhouse.com')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': ['https://huseinhouse.com'],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %% [markdown]
# ### Time

# %%
entity.predict('pada pkul 2')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {'pukul 2': datetime.datetime(2022, 12, 2, 0, 0)},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %%
entity.predict('pada pkul 2.14')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {'pukul 2.14': datetime.datetime(2022, 12, 30, 2, 14)},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %%
entity.predict('pada pkul 2:58:59')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {'2:58:59': datetime.datetime(2022, 12, 30, 2, 58, 59),
#   'pukul 2:58:59': datetime.datetime(2022, 12, 30, 2, 58, 59)},
#  'datetime': {},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %% [markdown]
# ### datetime

# %%
entity.predict('saya gerak 12/02/2022 14:23:21')
# Out:
# {'date': {'12/02/2022': datetime.datetime(2022, 12, 2, 0, 0)},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {'14:23:21': datetime.datetime(2022, 12, 30, 14, 23, 21)},
#  'datetime': {'12/02/2022 14:23:21': datetime.datetime(2022, 12, 2, 14, 23, 21)},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %%
entity.predict('saya gerak 12/02/2022 2pm')
# Out:
# {'date': {'12/02/2022': datetime.datetime(2022, 12, 2, 0, 0)},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {'2pm': datetime.datetime(2022, 12, 30, 14, 0)},
#  'datetime': {'12/02/2022 2pm': datetime.datetime(2022, 12, 2, 14, 0)},
#  'food': [],
#  'drink': [],
#  'weight': []}

# %% [markdown]
# ### local and generic foods

# %%
entity.predict('nasi goreng pattaya 1')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': ['nasi goreng pattaya'],
#  'drink': [],
#  'weight': []}

# %%
entity.predict('ayam penyet 1')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': ['ayam penyet'],
#  'drink': [],
#  'weight': []}

# %% [markdown]
# ### local and generic drinks

# %%
entity.predict('teh o ais 1')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': ['teh o ais'],
#  'weight': []}

# %%
entity.predict('teh ice 1')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': ['teh ice'],
#  'weight': []}

# %%
entity.predict('nescafe beng 1')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': ['nescafe beng'],
#  'weight': []}

# %%
entity.predict('jus rambutan 1')
# Out:
# {'date': {},
#  'money': {},
#  'temperature': [],
#  'distance': [],
#  'volume': [],
#  'duration': [],
#  'phone': [],
#  'email': [],
#  'url': [],
#  'time': {},
#  'datetime': {},
#  'food': [],
#  'drink': ['jus rambutan'],
#  'weight': []}
