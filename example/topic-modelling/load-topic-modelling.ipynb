# %%
import pandas as pd
import malaya

# %%
df = pd.read_csv('tests/02032018.csv',sep=';')
df = df.iloc[3:,1:]
df.columns = ['text','label']
corpus = df.text.tolist()

# %% [markdown]
# ## Train LDA2Vec model

# %%
lda2vec = malaya.topic_model.lda2vec(corpus, 10)
# Out:
# minibatch loop: 100%|██████████| 250/250 [00:02<00:00, 121.28it/s, cost=-8.54e+3, epoch=1]
# minibatch loop: 100%|██████████| 250/250 [00:01<00:00, 127.67it/s, cost=-9.17e+3, epoch=2]
# minibatch loop: 100%|██████████| 250/250 [00:01<00:00, 129.87it/s, cost=-9.82e+3, epoch=3]
# minibatch loop: 100%|██████████| 250/250 [00:01<00:00, 129.39it/s, cost=-1.05e+4, epoch=4]
# minibatch loop: 100%|██████████| 250/250 [00:01<00:00, 135.31it/s, cost=-1.11e+4, epoch=5]
# minibatch loop: 100%|██████████| 250/250 [00:01<00:00, 132.94it/s, cost=-1.18e+4, epoch=6]
# minibatch loop: 100%|██████████| 250/250 [00:01<00:00, 132.80it/s, cost=-1.25e+4, epoch=7]
# minibatch loop: 100%|██████████| 250/250 [00:02<00:00, 124.34it/s, cost=-1.31e+4, epoch=8]
# minibatch loop: 100%|██████████| 250/250 [00:01<00:00, 129.12it/s, cost=-1.38e+4, epoch=9]
# minibatch loop: 100%|██████████| 250/250 [00:01<00:00, 126.22it/s, cost=-1.45e+4, epoch=10]

# %% [markdown]
# #### Print topics

# %%
lda2vec.print_topics(5)
# Out:
# topic 0       topic 1       topic 2       topic 3       topic 4
# --------      --------      --------      --------      --------
# jahat         fakta         perinci       selaras       timbal
# tabur         intelek       intelek       tiket         merosak
# fakta         pajak         fakta         intelek       perinci
# seru          mewah         puji          digital       samping
# melenyapka    minimum       maruah        kelas         intelek
# maruah        kelas         asa           pajak         mewah
# indah         butir         suai          jarang        minimum
# anggap        atus          tadbir        ketua         labur
# misi          ogos          jelang        celik         catat
# banding       pesawat       liow          rancak        giat

# %% [markdown]
# #### Important sentences based on topics

# %%
lda2vec.get_sentences(5)
# Out:
# ['bukan itu sahaja wan saiful akan tempat dalam majlis pimpin tinggi satu bagi isi kosong posisi yang tinggal beberapa ahli parti',
#  'kami jual syarikat paja kami pagi ini dan wang yang terima akan tingkat ringgit jadi ia akan cermin dengan lebih baik lagi kuat benar dan daya tahan ekonomi malaysia',
#  'dua dua sekolah dapat kongsi pelbagai mudah seperti padang',
#  'bila semua aspek wang dalam mdb selesai memang mdb tidak punya fungsi lagi jadi wajar ia tutup',
#  'dasar sumber sumber yang dapat daripada baca dan perhati saya rasa adalah tidak adil kepada rakyat yang undi apabila mereka biar tanya tanya akan main politik pihak bangkang']

# %% [markdown]
# #### Get topics

# %%
lda2vec.get_topics(10)
# Out:
# [(0, 'jahat tabur fakta seru melenyapka maruah indah anggap misi banding'),
#  (1, 'fakta intelek pajak mewah minimum kelas butir atus ogos pesawat'),
#  (2, 'perinci intelek fakta puji maruah asa suai tadbir jelang liow'),
#  (3, 'selaras tiket intelek digital kelas pajak jarang ketua celik rancak'),
#  (4, 'timbal merosak perinci samping intelek mewah minimum labur catat giat'),
#  (5, 'kanvas campur lengkap label angkat intelek atus press fakta samping'),
#  (6, 'kenal mewah celik robert tnb samping mahathir respons seru limpa'),
#  (7, 'fakta dada kelas liow minimum pajak rosakkan samping jahat acara'),
#  (8, 'rupa sebahagian irwan jenayah tawan atus alat mesej anggap mewah'),
#  (9,
#   'intelek imbang semenanjung kakitangan puas dada produk peperangan cemar setia')]

# %% [markdown]
# #### Visualize topics

# %%
lda2vec.visualize_topics(notebook_mode = True)
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0      0.000061  0.000016       1        1  12.106076
# 9      0.000107 -0.000004       2        1  10.752045
# 7      0.000061 -0.000042       3        1  10.709019
# 4     -0.000008  0.000018       4        1  10.363924
# 8      0.000096  0.000057       5        1  10.322508
# 3     -0.000059 -0.000021       6        1  10.302469
# 1     -0.000011 -0.000120       7        1  10.045714
# 6     -0.000058  0.000102       8        1   9.869652
# 2     -0.000071 -0.000014       9        1   9.040380
# 5     -0.000118  0.000008      10        1   6.488214, topic_info=     Category      Freq              Term     Total  loglift  logprob
# term
# 456   Default  2.000000            kanvas  2.000000  30.0000  30.0000
# 363   Default  2.000000            angkat  2.000000  29.0000  29.0000
# 508   Default  2.000000              suai  2.000000  28.0000  28.0000
# 315   Default  2.000000              asia  2.000000  27.0000  27.0000
# 566   Default  2.000000             label  2.000000  26.0000  26.0000
# 753   Default  2.000000             press  2.000000  25.0000  25.0000
# 635   Default  2.000000            campur  2.000000  24.0000  24.0000
# 625   Default  2.000000           lengkap  2.000000  23.0000  23.0000
# 826   Default  2.000000               asa  2.000000  22.0000  22.0000
# 145   Default  2.000000              giat  2.000000  21.0000  21.0000
# 367   Default  2.000000            tangan  2.000000  20.0000  20.0000
# 179   Default  2.000000           selatan  2.000000  19.0000  19.0000
# 312   Default  2.000000              aset  2.000000  18.0000  18.0000
# 801   Default  2.000000            rancak  2.000000  17.0000  17.0000
# 890   Default  2.000000          langkawi  2.000000  16.0000  16.0000
# 848   Default  2.000000           intelek  2.000000  15.0000  15.0000
# 81    Default  2.000000           ekonomi  2.000000  14.0000  14.0000
# 214   Default  2.000000            pegang  2.000000  13.0000  13.0000
# 358   Default  2.000000             insya  2.000000  12.0000  12.0000
# 857   Default  2.000000              puji  2.000000  11.0000  11.0000
# 904   Default  2.000000             wakil  2.000000  10.0000  10.0000
# 467   Default  2.000000             isnin  2.000000   9.0000   9.0000
# 756   Default  2.000000         evangelis  2.000000   8.0000   8.0000
# 191   Default  2.000000            tadbir  2.000000   7.0000   7.0000
# 661   Default  2.000000            budaya  2.000000   6.0000   6.0000
# 902   Default  2.000000       profesional  2.000000   5.0000   5.0000
# 540   Default  2.000000             kisah  2.000000   4.0000   4.0000
# 667   Default  2.000000              ogos  2.000000   3.0000   3.0000
# 525   Default  2.000000            segmen  2.000000   2.0000   2.0000
# 919   Default  2.000000            tenaga  2.000000   1.0000   1.0000
# ...       ...       ...               ...       ...      ...      ...
# 508   Topic10  0.189971              suai  2.768451   0.0560  -6.7533
# 919   Topic10  0.188115            tenaga  2.742094   0.0558  -6.7632
# 358   Topic10  0.187409             insya  2.737001   0.0539  -6.7669
# 367   Topic10  0.187938            tangan  2.745360   0.0536  -6.7641
# 540   Topic10  0.190634             kisah  2.785389   0.0534  -6.7499
# 62    Topic10  0.177593              kait  2.594905   0.0534  -6.8207
# 745   Topic10  0.190000             hitam  2.776546   0.0532  -6.7532
# 661   Topic10  0.187321            budaya  2.740376   0.0522  -6.7674
# 838   Topic10  0.185697           diploma  2.717770   0.0517  -6.7761
# 868   Topic10  0.182672             dolar  2.675796   0.0509  -6.7925
# 815   Topic10  0.184453        perspektif  2.704501   0.0499  -6.7828
# 267   Topic10  0.189528          mahkamah  2.782105   0.0488  -6.7557
# 600   Topic10  0.187999             minit  2.763660   0.0473  -6.7638
# 539   Topic10  0.192559              atus  2.846990   0.0416  -6.7398
# 409   Topic10  0.190594  bertanggungjawab  2.813387   0.0432  -6.7501
# 667   Topic10  0.190318              ogos  2.820558   0.0392  -6.7515
# 857   Topic10  0.191234              puji  2.842057   0.0364  -6.7467
# 879   Topic10  0.190534              beim  2.826089   0.0384  -6.7504
# 681   Topic10  0.188461             gemar  2.779378   0.0441  -6.7613
# 380   Topic10  0.190282              tani  2.825239   0.0373  -6.7517
# 526   Topic10  0.191950           samping  2.882866   0.0259  -6.7430
# 801   Topic10  0.190121            rancak  2.827646   0.0356  -6.7526
# 848   Topic10  0.192725           intelek  2.928333   0.0143  -6.7389
# 191   Topic10  0.189377            tadbir  2.812018   0.0373  -6.7565
# 685   Topic10  0.191971             fakta  2.920520   0.0130  -6.7429
# 491   Topic10  0.189317            banjir  2.815525   0.0357  -6.7568
# 520   Topic10  0.191520             pajak  2.921489   0.0103  -6.7452
# 618   Topic10  0.190004             celik  2.872774   0.0192  -6.7532
# 901   Topic10  0.189458              tuai  2.862064   0.0201  -6.7560
# 686   Topic10  0.188950             mesej  2.838878   0.0255  -6.7587
#
# [556 rows x 6 columns], token_table=Empty DataFrame
# Columns: [Topic, Freq, Term]
# Index: [], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 10, 8, 5, 9, 4, 2, 7, 3, 6])

# %% [markdown]
# ## Train LDA model

# %%
lda = malaya.topic_model.lda(corpus,10,stemming=False)
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/decomposition/online_lda.py:536: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)

# %% [markdown]
# #### Print topics

# %%
lda.print_topics(5)
# Out:
# topic 0       topic 1       topic 2       topic 3       topic 4
# --------      --------      --------      --------      --------
# malaysia      menteri       laku          projek        bahasa
# ambil         tumpu         wujud         terima        raja
# negara        perdana       projek        tingkat       mudah
# tindak        najib         malaysia      jual          ajar
# wang          islam         salah         undi          inggeris
# putus         kuok          bukti         syarikat      rumah
# isu           nyata         berita        raja          bayar
# punca         pekan         hadap         bangun        laku
# raja          isu           nyata         beli          sewa
# hak           amanah        rakyat        indonesia     masuk

# %% [markdown]
# #### Important sentences based on topics

# %%
lda.get_sentences(5)
# Out:
# ['indonesia rak negara ambil tindak rana putus doj isu kait mdb ambil tindak',
#  'harga daging bahagian jual murah harga pasar hati limpa tulang jual harga kilogram banding pasar',
#  'fikir kuat tulis kertas cadang sekira rejim tadbir negara ubah tuntas mahukan mustahil laksana rana political will wujud',
#  'teras wajib antarabangsa senarai komitmen malaysia instrumen instrumen antarabangsa kait hak asasi manusia',
#  'makna strategi set dasar kondusif destinasi malaysia bijak strategi kempen pasar rancang pasar berbeza']

# %% [markdown]
# #### Get topics

# %%
lda.get_topics(10)
# Out:
# [(0, 'malaysia ambil negara tindak wang putus isu punca raja hak'),
#  (1, 'menteri tumpu perdana najib islam kuok nyata pekan isu amanah'),
#  (2, 'laku wujud projek malaysia salah bukti berita hadap nyata rakyat'),
#  (3, 'projek terima tingkat jual undi syarikat raja bangun beli indonesia'),
#  (4, 'bahasa raja mudah ajar inggeris rumah bayar laku sewa masuk'),
#  (5, 'parti negara kongsi malaysia sedia bangun jppm wang takut bank'),
#  (6, 'asli awam dakwa jakoa dana masyarakat syarikat gagal ahli perdana'),
#  (7, 'hutang mdb selesai wang tempoh tutup gantung pendek rana bayar'),
#  (8, 'rakyat rana terjemah niaga asli sumber masyarakat pimpin kerja babit'),
#  (9, 'umno pilih raya selesai menteri buah isu terima status jemaah')]

# %% [markdown]
# #### Visualize topics

# %%
lda.visualize_topics(notebook_mode = True)
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 5      0.006287 -0.131170       1        1  15.788848
# 3     -0.108752 -0.005563       2        1  14.050333
# 8     -0.022796  0.031845       3        1  12.877680
# 6      0.073832  0.208669       4        1  11.552908
# 0      0.074011 -0.105365       5        1   9.760192
# 4     -0.219940  0.019667       6        1   9.049965
# 9      0.085577  0.027241       7        1   8.488975
# 2     -0.031982  0.004656       8        1   6.238265
# 7      0.081533 -0.072999       9        1   6.232561
# 1      0.062229  0.023019      10        1   5.960274, topic_info=     Category       Freq       Term      Total  loglift  logprob
# term
# 131   Default  17.000000     hutang  17.000000  30.0000  30.0000
# 196   Default  18.000000       laku  18.000000  29.0000  29.0000
# 235   Default  17.000000        mdb  17.000000  28.0000  28.0000
# 302   Default  19.000000     projek  19.000000  27.0000  27.0000
# 341   Default  14.000000    selesai  14.000000  26.0000  26.0000
# 266   Default  21.000000      parti  21.000000  25.0000  25.0000
# 423   Default  17.000000       wang  17.000000  24.0000  24.0000
# 227   Default  30.000000   malaysia  30.000000  23.0000  23.0000
# 254   Default  26.000000     negara  26.000000  22.0000  22.0000
# 312   Default  17.000000     rakyat  17.000000  21.0000  21.0000
# 28    Default  16.000000       asli  16.000000  20.0000  20.0000
# 425   Default  10.000000      wujud  10.000000  19.0000  19.0000
# 239   Default  16.000000    menteri  16.000000  18.0000  18.0000
# 414   Default   9.000000       umno   9.000000  17.0000  17.0000
# 38    Default  11.000000     bahasa  11.000000  16.0000  16.0000
# 291   Default  12.000000      pilih  12.000000  15.0000  15.0000
# 12    Default  11.000000      ambil  11.000000  14.0000  14.0000
# 31    Default   8.000000       awam   8.000000  13.0000  13.0000
# 385   Default   6.000000     tempoh   6.000000  12.0000  12.0000
# 246   Default   8.000000      mudah   8.000000  11.0000  11.0000
# 310   Default  19.000000       raja  19.000000  10.0000  10.0000
# 406   Default   5.000000      tumpu   5.000000   9.0000   9.0000
# 282   Default  10.000000    perdana  10.000000   8.0000   8.0000
# 318   Default   7.000000       raya   7.000000   7.0000   7.0000
# 410   Default   5.000000      tutup   5.000000   6.0000   6.0000
# 261   Default   9.000000      nyata   9.000000   5.0000   5.0000
# 48    Default  10.000000      bayar  10.000000   4.0000   4.0000
# 394   Default   7.000000     tindak   7.000000   3.0000   3.0000
# 251   Default   6.000000      najib   6.000000   2.0000   2.0000
# 5     Default   7.000000       ajar   7.000000   1.0000   1.0000
# ...       ...        ...        ...        ...      ...      ...
# 239   Topic10   5.675262    menteri  16.215085   1.7702  -3.0352
# 200   Topic10   0.787598    langgar   2.296957   1.7497  -5.0101
# 282   Topic10   3.629507    perdana  10.760880   1.7332  -3.4822
# 392   Topic10   0.787321      teruk   2.370369   1.7179  -5.0104
# 89    Topic10   0.743752  demokrasi   2.247609   1.7141  -5.0674
# 43    Topic10   0.736158    bangkit   2.322632   1.6710  -5.0776
# 270   Topic10   2.053763      pekan   6.613522   1.6506  -4.0516
# 146   Topic10   0.970877      jabat   3.358588   1.5790  -4.8009
# 39    Topic10   0.735460      baiah   2.632697   1.5448  -5.0786
# 272   Topic10   0.736738      pelan   2.690879   1.5247  -5.0768
# 250   Topic10   0.735131      musuh   2.697932   1.5199  -5.0790
# 205   Topic10   0.738034      lapor   2.738618   1.5088  -5.0751
# 319   Topic10   0.798014      razak   2.994389   1.4977  -4.9969
# 86    Topic10   0.740835        dar   2.813356   1.4857  -5.0713
# 267   Topic10   1.466118        pas   5.926098   1.4233  -4.3887
# 30    Topic10   0.786313       atur   3.192903   1.4187  -5.0117
# 399   Topic10   0.783312      tolak   3.321055   1.3755  -5.0155
# 261   Topic10   2.088114      nyata   9.407457   1.3148  -4.0350
# 145   Topic10   1.982925        isu   9.802082   1.2220  -4.0867
# 349   Topic10   1.044609       seri   4.751264   1.3053  -4.7277
# 2     Topic10   1.414606       ahli   8.184050   1.0647  -4.4245
# 312   Topic10   1.415411     rakyat  17.239172   0.3203  -4.4239
# 175   Topic10   1.119825       kena  14.443571   0.2630  -4.6581
# 338   Topic10   0.850984    selamat   5.419261   0.9687  -4.9327
# 149   Topic10   0.874156      jalan   9.046211   0.4832  -4.9058
# 305   Topic10   0.806353        pru   5.253206   0.9460  -4.9865
# 390   Topic10   0.815253     terima  12.888905   0.0594  -4.9756
# 314   Topic10   0.816588       rana  20.751314  -0.4152  -4.9739
# 84    Topic10   0.790973      dakwa   8.741772   0.4174  -5.0058
# 228   Topic10   0.788001       malu   5.727747   0.8365  -5.0096
#
# [465 rows x 6 columns], token_table=      Topic      Freq         Term
# term
# 0         4  0.502553        aabar
# 0         9  0.502553        aabar
# 2         2  0.122189         ahli
# 2         4  0.488756         ahli
# 2         7  0.122189         ahli
# 2        10  0.122189         ahli
# 5         4  0.276880         ajar
# 5         6  0.692200         ajar
# 6         3  0.490838     aktiviti
# 6         9  0.490838     aktiviti
# 7         1  0.631476         alam
# 7         2  0.126295         alam
# 7         4  0.126295         alam
# 7         6  0.126295         alam
# 8         1  0.290284        alami
# 8         2  0.580567        alami
# 10        7  0.422958  allahyarham
# 11        1  0.234676       amanah
# 11        7  0.234676       amanah
# 11       10  0.469351       amanah
# 12        1  0.083929        ambil
# 12        2  0.167857        ambil
# 12        5  0.671429        ambil
# 12        8  0.083929        ambil
# 14        1  0.396424       ancang
# 14        2  0.198212       ancang
# 14        9  0.396424       ancang
# 15        2  0.310519       angkat
# 15        4  0.621039       angkat
# 16        5  0.467250       angkut
# ...     ...       ...          ...
# 412       3  0.456189          uji
# 413       8  0.395610        ulang
# 413       9  0.395610        ulang
# 414       7  0.871044         umno
# 415       1  0.696962       undang
# 415       2  0.232321       undang
# 416       1  0.131439         undi
# 416       2  0.657195         undi
# 416       3  0.131439         undi
# 416       4  0.131439         undi
# 417       5  0.276023       untung
# 417       6  0.552046       untung
# 417       8  0.276023       untung
# 418       2  0.274236         urus
# 418       4  0.137118         urus
# 418       6  0.411354         urus
# 418       7  0.137118         urus
# 418       9  0.137118         urus
# 419       4  0.527862        usaha
# 419       7  0.175954        usaha
# 419       8  0.175954        usaha
# 422       4  0.280292        wajar
# 422       9  0.560585        wajar
# 423       1  0.279571         wang
# 423       3  0.055914         wang
# 423       5  0.279571         wang
# 423       9  0.335485         wang
# 425       5  0.186890        wujud
# 425       7  0.093445        wujud
# 425       8  0.654113        wujud
#
# [742 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[6, 4, 9, 7, 1, 5, 10, 3, 8, 2])

# %% [markdown]
# ## Train NMF model

# %%
nmf = malaya.topic_model.nmf(corpus,10)
nmf.print_topics(5)
# Out:
# topic 0       topic 1       topic 2       topic 3       topic 4
# --------      --------      --------      --------      --------
# bangun        projek        parti         mdb           menteri
# negara        sewa          umno          niaga         perdana
# malaysia      syarikat      tangguh       urus          asli
# kongsi        jual          pilih         doj           seri
# alam          tanah         putus         low           terima
# sedia         swasta        jalan         jho           najib
# selatan       indonesia     lembaga       tuntut        razak
# program       kena          ros           sivil         jemaah
# kerjasama     rana          ambil         dakwa         kuok
# sosial        rumah         politik       sebarang      lantik

# %%
nmf.get_sentences(5)
# Out:
# ['sedia kongsi alam bangun ekonomi sosial negara bangun rangka program kerjasama teknikal malaysia mtcp sedia malaysia kongsi alam bangun negara negara selatan selatan',
#  'sedia kongsi alam bangun ekonomi sosial negara bangun rangka program kerjasama teknikal malaysia mtcp sedia malaysia kongsi alam bangun negara negara selatan selatan',
#  'negara bangun malaysia main peran kongsi alam mahir bangun kawasan bandar',
#  'negara bangun malaysia main peran kongsi alam mahir bangun kawasan bandar',
#  'kali kongsi maklumat kena pelbagai khidmat biaya program sedia usahawan wanita iks sabah kongsi idea alam aspirasi promosi produk peringkat luas']

# %%
nmf.get_topics(10)
# Out:
# [(0,
#   'bangun negara malaysia kongsi alam sedia selatan program kerjasama sosial'),
#  (1, 'projek sewa syarikat jual tanah swasta indonesia kena rana rumah'),
#  (2, 'parti umno tangguh pilih putus jalan lembaga ros ambil politik'),
#  (3, 'mdb niaga urus doj low jho tuntut sivil dakwa sebarang'),
#  (4, 'menteri perdana asli seri terima najib razak jemaah kuok lantik'),
#  (5, 'negara wang maju bidang ekonomi didik latih industri dagang bantu'),
#  (6, 'rakyat malaysia pimpin maklumat dasar negara asas kait percaya utama'),
#  (7, 'ajar raja ahli laksana mudah laku masyarakat kalang bahasa sokong'),
#  (8, 'hutang wang mdb selesai wujud tempoh gantung pendek jangka projek'),
#  (9, 'tingkat harga jual airasia lihat nilai tuju langkah pasar agih')]

# %% [markdown]
# ## Train LSA model

# %%
lsa = malaya.topic_model.lsa(corpus,10)
lsa.print_topics(5)
# Out:
# topic 0       topic 1       topic 2       topic 3       topic 4
# --------      --------      --------      --------      --------
# negara        menteri       mdb           projek        projek
# malaysia      projek        niaga         jual          parti
# bangun        mdb           projek        menteri       jual
# kongsi        parti         wang          tingkat       sewa
# alam          raja          hutang        sewa          tangguh
# sedia         rana          doj           asli          syarikat
# selatan       perdana       urus          syarikat      pilih
# ekonomi       tingkat       jho           tanah         umno
# rakyat        kena          low           perdana       rana
# teknikal      laku          tuntut        swasta        tanah

# %%
lsa.get_sentences(5)
# Out:
# ['sedia kongsi alam bangun ekonomi sosial negara bangun rangka program kerjasama teknikal malaysia mtcp sedia malaysia kongsi alam bangun negara negara selatan selatan',
#  'sedia kongsi alam bangun ekonomi sosial negara bangun rangka program kerjasama teknikal malaysia mtcp sedia malaysia kongsi alam bangun negara negara selatan selatan',
#  'percaya kongsi maklumat asas utama maklumat kait pimpin negara rakyat malaysia rakyat pilih pimpin negara kaliber sesuai pandang rakyat',
#  'negara bangun malaysia main peran kongsi alam mahir bangun kawasan bandar',
#  'negara bangun malaysia main peran kongsi alam mahir bangun kawasan bandar']

# %%
lsa.get_topics(10)
# Out:
# [(0,
#   'negara malaysia bangun kongsi alam sedia selatan ekonomi rakyat teknikal'),
#  (1, 'menteri projek mdb parti raja rana perdana tingkat kena laku'),
#  (2, 'mdb niaga projek wang hutang doj urus jho low tuntut'),
#  (3, 'projek jual menteri tingkat sewa asli syarikat tanah perdana swasta'),
#  (4, 'projek parti jual sewa tangguh syarikat pilih umno rana tanah'),
#  (5, 'negara wang hutang rakyat menteri maju selesai didik bidang ancang'),
#  (6,
#   'rakyat malaysia pimpin maklumat dasar asas utama percaya sesuai pandang'),
#  (7, 'ajar tingkat raja maju bidang didik mudah ahli proses laksana'),
#  (8, 'hutang asli mdb wang masyarakat malaysia selesai bangun tingkat jakoa'),
#  (9, 'tingkat harga malaysia airasia jual pilih tangguh umno lihat niaga')]
