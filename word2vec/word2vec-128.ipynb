# %%
import word2vec
import numpy as np
import tensorflow as tf
import json
import os
os.environ['CUDA_VISIBLE_DEVICES'] = ''
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
with open('news-bm.json','r') as fopen:
    sentences = json.loads(fopen.read())

# %%
word_array, dictionary, rev_dictionary, num_lines, num_words = word2vec.build_word_array(sentences,vocab_size=50000)

# %%
X, Y = word2vec.build_training_set(word_array)
graph_params = {'batch_size': 32,
                'vocab_size': np.max(X)+1,
                'embed_size': 128,
                'hid_size': 128,
                'neg_samples': 128,
                'learn_rate': 0.01,
                'momentum': 0.9,
                'embed_noise': 0.1,
                'hid_noise': 0.3,
                'epoch':500,
                'optimizer': 'Momentum'}

# %%
split = round(X.shape[0]*0.9)
X_val, Y_val = (X[split:, :], Y[split:, :])

# %%
model = word2vec.Model(graph_params)
print('model built, vocab size %d, document length %d'%(np.max(X)+1, len(word_array)))
# Out:
# model built, vocab size 33735, document length 1211339

# %%
embed_weights, nce_weights = model.train(X, Y, X_val, Y_val,
                                         graph_params['epoch'],
                                         graph_params['batch_size'])
# Out:
# epoch 1, total batch 37854, train loss 23.764853, val loss 7.825896
# epoch 2, total batch 41639, train loss 7.352015, val loss 6.663199
# epoch 3, total batch 45424, train loss 6.350492, val loss 5.971328
# epoch 4, total batch 49209, train loss 5.834031, val loss 5.667165
# epoch 5, total batch 52994, train loss 5.580320, val loss 5.448720
# epoch 6, total batch 56779, train loss 5.376206, val loss 5.272802
# epoch 7, total batch 60564, train loss 5.201048, val loss 5.122690
# epoch 8, total batch 64349, train loss 5.042687, val loss 4.982159
# epoch 9, total batch 68134, train loss 4.910967, val loss 4.861358
# epoch 10, total batch 71919, train loss 4.786499, val loss 4.751952
# epoch 11, total batch 75704, train loss 4.678626, val loss 4.645815
# epoch 12, total batch 79489, train loss 4.574756, val loss 4.548809
# epoch 13, total batch 83274, train loss 4.483155, val loss 4.451109
# epoch 14, total batch 87059, train loss 4.415428, val loss 4.383939
# epoch 15, total batch 90844, train loss 4.341059, val loss 4.319546
# epoch 16, total batch 94629, train loss 4.271884, val loss 4.240952
# epoch 17, total batch 98414, train loss 4.203804, val loss 4.185676
# epoch 18, total batch 102199, train loss 4.146012, val loss 4.129810
# epoch 19, total batch 105984, train loss 4.089401, val loss 4.076268
# epoch 20, total batch 109769, train loss 4.031304, val loss 4.019548
# epoch 21, total batch 113554, train loss 3.987335, val loss 3.971909
# epoch 22, total batch 117339, train loss 3.935912, val loss 3.928316
# epoch 23, total batch 121124, train loss 3.899337, val loss 3.886838
# epoch 24, total batch 124909, train loss 3.857296, val loss 3.848184
# epoch 25, total batch 128694, train loss 3.814025, val loss 3.802063
# epoch 26, total batch 132479, train loss 3.773345, val loss 3.771747
# epoch 27, total batch 136264, train loss 3.726649, val loss 3.749137
# epoch 28, total batch 140049, train loss 3.709533, val loss 3.708074
# epoch 29, total batch 143834, train loss 3.674270, val loss 3.677119
# epoch 30, total batch 147619, train loss 3.642260, val loss 3.641422
# epoch 31, total batch 151404, train loss 3.600244, val loss 3.609922
# epoch 32, total batch 155189, train loss 3.579602, val loss 3.598019
# epoch 33, total batch 158974, train loss 3.559877, val loss 3.563108
# epoch 34, total batch 162759, train loss 3.519275, val loss 3.534174
# epoch 35, total batch 166544, train loss 3.494303, val loss 3.512873
# epoch 36, total batch 170329, train loss 3.459501, val loss 3.485591
# epoch 37, total batch 174114, train loss 3.438400, val loss 3.460799
# epoch 38, total batch 177899, train loss 3.426013, val loss 3.435153
# epoch 39, total batch 181684, train loss 3.390751, val loss 3.414334
# epoch 40, total batch 185469, train loss 3.380722, val loss 3.395333
# epoch 41, total batch 189254, train loss 3.352953, val loss 3.375550
# epoch 42, total batch 193039, train loss 3.327915, val loss 3.343340
# epoch 43, total batch 196824, train loss 3.304604, val loss 3.333461
# epoch 44, total batch 200609, train loss 3.286904, val loss 3.303722
# epoch 45, total batch 204394, train loss 3.260682, val loss 3.299240
# epoch 46, total batch 208179, train loss 3.251118, val loss 3.272631
# epoch 47, total batch 211964, train loss 3.227439, val loss 3.261308
# epoch 48, total batch 215749, train loss 3.204860, val loss 3.230927
# epoch 49, total batch 219534, train loss 3.185140, val loss 3.222233
# epoch 50, total batch 223319, train loss 3.175461, val loss 3.211122
# epoch 51, total batch 227104, train loss 3.154944, val loss 3.185331
# epoch 52, total batch 230889, train loss 3.139544, val loss 3.168142
# epoch 53, total batch 234674, train loss 3.119762, val loss 3.159348
# epoch 54, total batch 238459, train loss 3.099167, val loss 3.129511
# epoch 55, total batch 242244, train loss 3.093138, val loss 3.124282
# epoch 56, total batch 246029, train loss 3.080162, val loss 3.109015
# epoch 57, total batch 249814, train loss 3.050489, val loss 3.097110
# epoch 58, total batch 253599, train loss 3.021803, val loss 3.087594
# epoch 59, total batch 257384, train loss 3.006019, val loss 3.062249
# epoch 60, total batch 261169, train loss 2.999269, val loss 3.045064
# epoch 61, total batch 264954, train loss 2.991971, val loss 3.035614
# epoch 62, total batch 268739, train loss 2.990200, val loss 3.025339
# epoch 63, total batch 272524, train loss 2.967068, val loss 3.013926
# epoch 64, total batch 276309, train loss 2.946652, val loss 2.993983
# epoch 65, total batch 280094, train loss 2.933056, val loss 2.980294
# epoch 66, total batch 283879, train loss 2.920507, val loss 2.969396
# epoch 67, total batch 287664, train loss 2.902160, val loss 2.965968
# epoch 68, total batch 291449, train loss 2.892782, val loss 2.945573
# epoch 69, total batch 295234, train loss 2.878287, val loss 2.937189
# epoch 70, total batch 299019, train loss 2.872746, val loss 2.921782
# epoch 71, total batch 302804, train loss 2.861080, val loss 2.905444
# epoch 72, total batch 306589, train loss 2.851287, val loss 2.900773
# epoch 73, total batch 310374, train loss 2.829939, val loss 2.889954
# epoch 74, total batch 314159, train loss 2.820600, val loss 2.873947
# epoch 75, total batch 317944, train loss 2.823425, val loss 2.861741
# epoch 76, total batch 321729, train loss 2.800827, val loss 2.856308
# epoch 77, total batch 325514, train loss 2.786040, val loss 2.847158
# epoch 78, total batch 329299, train loss 2.773236, val loss 2.837567
# epoch 79, total batch 333084, train loss 2.767415, val loss 2.822746
# epoch 80, total batch 336869, train loss 2.751999, val loss 2.819873
# epoch 81, total batch 340654, train loss 2.755652, val loss 2.807117
# epoch 82, total batch 344439, train loss 2.729480, val loss 2.795470
# epoch 83, total batch 348224, train loss 2.724060, val loss 2.795116
# epoch 84, total batch 352009, train loss 2.716879, val loss 2.772294
# epoch 85, total batch 355794, train loss 2.713801, val loss 2.768674
# epoch 86, total batch 359579, train loss 2.697032, val loss 2.759825
# epoch 87, total batch 363364, train loss 2.681502, val loss 2.748488
# epoch 88, total batch 367149, train loss 2.683071, val loss 2.739734
# epoch 89, total batch 370934, train loss 2.675464, val loss 2.730649
# epoch 90, total batch 374719, train loss 2.654008, val loss 2.720724
# epoch 91, total batch 378504, train loss 2.642792, val loss 2.715225
# epoch 92, total batch 382289, train loss 2.633360, val loss 2.713658
# epoch 93, total batch 386074, train loss 2.634110, val loss 2.703164
# epoch 94, total batch 389859, train loss 2.624684, val loss 2.686368
# epoch 95, total batch 393644, train loss 2.604954, val loss 2.684662
# epoch 96, total batch 397429, train loss 2.596620, val loss 2.668217
# epoch 97, total batch 401214, train loss 2.585758, val loss 2.663966
# epoch 98, total batch 404999, train loss 2.586323, val loss 2.656139
# epoch 99, total batch 408784, train loss 2.582077, val loss 2.655239
# epoch 100, total batch 412569, train loss 2.572299, val loss 2.646229
# epoch 101, total batch 416354, train loss 2.561010, val loss 2.635776
# epoch 102, total batch 420139, train loss 2.550966, val loss 2.629405
# epoch 103, total batch 423924, train loss 2.548767, val loss 2.618740
# epoch 104, total batch 427709, train loss 2.535182, val loss 2.614408
# epoch 105, total batch 431494, train loss 2.528952, val loss 2.602600
# epoch 106, total batch 435279, train loss 2.530612, val loss 2.599125
# epoch 107, total batch 439064, train loss 2.511516, val loss 2.590287
# epoch 108, total batch 442849, train loss 2.503824, val loss 2.587437
# epoch 109, total batch 446634, train loss 2.485398, val loss 2.588724
# epoch 110, total batch 450419, train loss 2.495699, val loss 2.565088
# epoch 111, total batch 454204, train loss 2.481935, val loss 2.557783
# epoch 112, total batch 457989, train loss 2.471990, val loss 2.551301
# epoch 113, total batch 461774, train loss 2.478218, val loss 2.550093
# epoch 114, total batch 465559, train loss 2.454937, val loss 2.542961
# epoch 115, total batch 469344, train loss 2.456690, val loss 2.537946
# epoch 116, total batch 473129, train loss 2.442958, val loss 2.530192
# epoch 117, total batch 476914, train loss 2.432922, val loss 2.522945
# epoch 118, total batch 480699, train loss 2.431193, val loss 2.523224
# epoch 119, total batch 484484, train loss 2.433741, val loss 2.511448
# epoch 120, total batch 488269, train loss 2.420855, val loss 2.507327
# epoch 121, total batch 492054, train loss 2.414379, val loss 2.493072
# epoch 122, total batch 495839, train loss 2.413227, val loss 2.493838
# epoch 123, total batch 499624, train loss 2.397173, val loss 2.485525
# epoch 124, total batch 503409, train loss 2.392126, val loss 2.486836
# epoch 125, total batch 507194, train loss 2.390583, val loss 2.477958
# epoch 126, total batch 510979, train loss 2.380650, val loss 2.468985
# epoch 127, total batch 514764, train loss 2.367424, val loss 2.460948
# epoch 128, total batch 518549, train loss 2.370983, val loss 2.455093
# epoch 129, total batch 522334, train loss 2.353513, val loss 2.451771
# epoch 130, total batch 526119, train loss 2.348471, val loss 2.448112
# epoch 131, total batch 529904, train loss 2.355601, val loss 2.439265
# epoch 132, total batch 533689, train loss 2.340020, val loss 2.434443
# epoch 133, total batch 537474, train loss 2.340734, val loss 2.426023
# epoch 134, total batch 541259, train loss 2.325722, val loss 2.417499
# epoch 135, total batch 545044, train loss 2.320728, val loss 2.425913
# epoch 136, total batch 548829, train loss 2.330442, val loss 2.409898
# epoch 137, total batch 552614, train loss 2.319568, val loss 2.405875
# epoch 138, total batch 556399, train loss 2.309181, val loss 2.403369
# epoch 139, total batch 560184, train loss 2.306573, val loss 2.393580
# epoch 140, total batch 563969, train loss 2.301673, val loss 2.389751
# epoch 141, total batch 567754, train loss 2.294011, val loss 2.388510
# epoch 142, total batch 571539, train loss 2.286375, val loss 2.376720
# epoch 143, total batch 575324, train loss 2.284279, val loss 2.379439
# epoch 144, total batch 579109, train loss 2.280222, val loss 2.374059
# epoch 145, total batch 582894, train loss 2.275168, val loss 2.360396
# epoch 146, total batch 586679, train loss 2.276139, val loss 2.362041
# epoch 147, total batch 590464, train loss 2.264815, val loss 2.359102
# epoch 148, total batch 594249, train loss 2.260756, val loss 2.352295
# epoch 149, total batch 598034, train loss 2.245111, val loss 2.348334
# epoch 150, total batch 601819, train loss 2.233890, val loss 2.345791
# epoch 151, total batch 605604, train loss 2.240144, val loss 2.344061
# epoch 152, total batch 609389, train loss 2.238781, val loss 2.331618
# epoch 153, total batch 613174, train loss 2.232996, val loss 2.337464
# epoch 154, total batch 616959, train loss 2.227763, val loss 2.322641
# epoch 155, total batch 620744, train loss 2.218725, val loss 2.322753
# epoch 156, total batch 624529, train loss 2.228074, val loss 2.314918
# epoch 157, total batch 628314, train loss 2.202608, val loss 2.314759
# epoch 158, total batch 632099, train loss 2.212956, val loss 2.305702
# epoch 159, total batch 635884, train loss 2.205696, val loss 2.304357
# epoch 160, total batch 639669, train loss 2.196339, val loss 2.307780
# epoch 161, total batch 643454, train loss 2.208205, val loss 2.293787
# epoch 162, total batch 647239, train loss 2.187866, val loss 2.284102
# epoch 163, total batch 651024, train loss 2.188648, val loss 2.290421
# epoch 164, total batch 654809, train loss 2.185656, val loss 2.288042
# epoch 165, total batch 658594, train loss 2.191774, val loss 2.280884
# epoch 166, total batch 662379, train loss 2.182477, val loss 2.277027
# epoch 167, total batch 666164, train loss 2.171793, val loss 2.268837
# epoch 168, total batch 669949, train loss 2.166725, val loss 2.266848
# epoch 169, total batch 673734, train loss 2.167292, val loss 2.264199
# epoch 170, total batch 677519, train loss 2.163856, val loss 2.261116
# epoch 171, total batch 681304, train loss 2.148389, val loss 2.251381
# epoch 172, total batch 685089, train loss 2.147658, val loss 2.249009
# epoch 173, total batch 688874, train loss 2.135858, val loss 2.245693
# epoch 174, total batch 692659, train loss 2.130821, val loss 2.244904
# epoch 175, total batch 696444, train loss 2.133479, val loss 2.234021
# epoch 176, total batch 700229, train loss 2.131742, val loss 2.235827
# epoch 177, total batch 704014, train loss 2.125454, val loss 2.231944
# epoch 178, total batch 707799, train loss 2.125829, val loss 2.225738
# epoch 179, total batch 711584, train loss 2.126493, val loss 2.219622
# epoch 180, total batch 715369, train loss 2.106003, val loss 2.226081
# epoch 181, total batch 719154, train loss 2.118705, val loss 2.213668
# epoch 182, total batch 722939, train loss 2.105348, val loss 2.210738
# epoch 183, total batch 726724, train loss 2.104115, val loss 2.206204
# epoch 184, total batch 730509, train loss 2.099198, val loss 2.203551
# epoch 185, total batch 734294, train loss 2.095599, val loss 2.195921
# epoch 186, total batch 738079, train loss 2.086749, val loss 2.206235
# epoch 187, total batch 741864, train loss 2.092635, val loss 2.190937
# epoch 188, total batch 745649, train loss 2.086054, val loss 2.184377
# epoch 189, total batch 749434, train loss 2.077503, val loss 2.192725
# epoch 190, total batch 753219, train loss 2.076794, val loss 2.179110
# epoch 191, total batch 757004, train loss 2.082067, val loss 2.182579
# epoch 192, total batch 760789, train loss 2.073225, val loss 2.171952
# epoch 193, total batch 764574, train loss 2.068199, val loss 2.180920
# epoch 194, total batch 768359, train loss 2.055852, val loss 2.164029
# epoch 195, total batch 772144, train loss 2.064123, val loss 2.176406
# epoch 196, total batch 775929, train loss 2.058012, val loss 2.161895
# epoch 197, total batch 779714, train loss 2.055272, val loss 2.161990
# epoch 198, total batch 783499, train loss 2.047119, val loss 2.158514
# epoch 199, total batch 787284, train loss 2.040792, val loss 2.154780
# epoch 200, total batch 791069, train loss 2.046410, val loss 2.150944
# epoch 201, total batch 794854, train loss 2.045231, val loss 2.149482
# epoch 202, total batch 798639, train loss 2.038938, val loss 2.153161
# epoch 203, total batch 802424, train loss 2.035014, val loss 2.140838
# epoch 204, total batch 806209, train loss 2.028270, val loss 2.135192
# epoch 205, total batch 809994, train loss 2.033025, val loss 2.139117
# epoch 206, total batch 813779, train loss 2.020101, val loss 2.132765
# epoch 207, total batch 817564, train loss 2.016642, val loss 2.136625
# epoch 208, total batch 821349, train loss 2.025564, val loss 2.130671
# epoch 209, total batch 825134, train loss 2.017467, val loss 2.128384
# epoch 210, total batch 828919, train loss 2.011669, val loss 2.127068
# epoch 211, total batch 832704, train loss 2.008351, val loss 2.119487
# epoch 212, total batch 836489, train loss 2.012970, val loss 2.119624
# epoch 213, total batch 840274, train loss 2.009430, val loss 2.111874
# epoch 214, total batch 844059, train loss 2.001444, val loss 2.105652
# epoch 215, total batch 847844, train loss 1.997636, val loss 2.103664
# epoch 216, total batch 851629, train loss 1.985930, val loss 2.104975
# epoch 217, total batch 855414, train loss 1.986430, val loss 2.107952
# epoch 218, total batch 859199, train loss 1.993777, val loss 2.096569
# epoch 219, total batch 862984, train loss 1.988521, val loss 2.093619
# epoch 220, total batch 866769, train loss 1.982861, val loss 2.093473
# epoch 221, total batch 870554, train loss 1.985733, val loss 2.092842
# epoch 222, total batch 874339, train loss 1.964839, val loss 2.084545
# epoch 223, total batch 878124, train loss 1.975657, val loss 2.088212
# epoch 224, total batch 881909, train loss 1.969729, val loss 2.078495
# epoch 225, total batch 885694, train loss 1.965037, val loss 2.078855
# epoch 226, total batch 889479, train loss 1.959949, val loss 2.074122
# epoch 227, total batch 893264, train loss 1.955681, val loss 2.072226
# epoch 228, total batch 897049, train loss 1.966442, val loss 2.075790
# epoch 229, total batch 900834, train loss 1.957214, val loss 2.076060
# epoch 230, total batch 904619, train loss 1.954972, val loss 2.064416
# epoch 231, total batch 908404, train loss 1.959832, val loss 2.064031
# epoch 232, total batch 912189, train loss 1.948125, val loss 2.055722
# epoch 233, total batch 915974, train loss 1.940645, val loss 2.054177
# epoch 234, total batch 919759, train loss 1.937721, val loss 2.057162
# epoch 235, total batch 923544, train loss 1.934571, val loss 2.050691
# epoch 236, total batch 927329, train loss 1.940728, val loss 2.045939
# epoch 237, total batch 931114, train loss 1.933654, val loss 2.051357
# epoch 238, total batch 934899, train loss 1.936087, val loss 2.047148
# epoch 239, total batch 938684, train loss 1.928297, val loss 2.039460
# epoch 240, total batch 942469, train loss 1.915686, val loss 2.043253
# epoch 241, total batch 946254, train loss 1.919940, val loss 2.038116
# epoch 242, total batch 950039, train loss 1.926585, val loss 2.038630
# epoch 243, total batch 953824, train loss 1.917520, val loss 2.030632
# epoch 244, total batch 957609, train loss 1.914035, val loss 2.026568
# epoch 245, total batch 961394, train loss 1.915941, val loss 2.020152
# epoch 246, total batch 965179, train loss 1.915118, val loss 2.028060
# epoch 247, total batch 968964, train loss 1.913440, val loss 2.018627
# epoch 248, total batch 972749, train loss 1.907158, val loss 2.022895
# epoch 249, total batch 976534, train loss 1.900165, val loss 2.019565
# epoch 250, total batch 980319, train loss 1.898724, val loss 2.017860
# epoch 251, total batch 984104, train loss 1.897652, val loss 2.012904
# epoch 252, total batch 987889, train loss 1.897743, val loss 2.006021
# epoch 253, total batch 991674, train loss 1.888315, val loss 2.005222
# epoch 254, total batch 995459, train loss 1.901996, val loss 2.006798
# epoch 255, total batch 999244, train loss 1.891148, val loss 2.009770
# epoch 256, total batch 1003029, train loss 1.891015, val loss 2.003972
# epoch 257, total batch 1006814, train loss 1.887050, val loss 2.007581
# epoch 258, total batch 1010599, train loss 1.881909, val loss 1.998827
# epoch 259, total batch 1014384, train loss 1.881288, val loss 1.992352
# epoch 260, total batch 1018169, train loss 1.870859, val loss 1.993586
# epoch 261, total batch 1021954, train loss 1.880300, val loss 1.984309
# epoch 262, total batch 1025739, train loss 1.867985, val loss 1.984198
# epoch 263, total batch 1029524, train loss 1.874251, val loss 1.979845
# epoch 264, total batch 1033309, train loss 1.876053, val loss 1.989371
# epoch 265, total batch 1037094, train loss 1.870186, val loss 1.979013
# epoch 266, total batch 1040879, train loss 1.867920, val loss 1.970926
# epoch 267, total batch 1044664, train loss 1.866687, val loss 1.972142
# epoch 268, total batch 1048449, train loss 1.862172, val loss 1.975601
# epoch 269, total batch 1052234, train loss 1.861235, val loss 1.970410
# epoch 270, total batch 1056019, train loss 1.853934, val loss 1.964539
# epoch 271, total batch 1059804, train loss 1.851614, val loss 1.962107
# epoch 272, total batch 1063589, train loss 1.860204, val loss 1.963462
# epoch 273, total batch 1067374, train loss 1.849259, val loss 1.964055
# epoch 274, total batch 1071159, train loss 1.860313, val loss 1.966039
# epoch 275, total batch 1074944, train loss 1.847099, val loss 1.956795
# epoch 276, total batch 1078729, train loss 1.842751, val loss 1.954701
# epoch 277, total batch 1082514, train loss 1.840749, val loss 1.958100
# epoch 278, total batch 1086299, train loss 1.835995, val loss 1.949415
# epoch 279, total batch 1090084, train loss 1.827032, val loss 1.952220
# epoch 280, total batch 1093869, train loss 1.828932, val loss 1.942690
# epoch 281, total batch 1097654, train loss 1.830691, val loss 1.946047
# epoch 282, total batch 1101439, train loss 1.827011, val loss 1.950685
# epoch 283, total batch 1105224, train loss 1.824135, val loss 1.943123
# epoch 284, total batch 1109009, train loss 1.818537, val loss 1.935216
# epoch 285, total batch 1112794, train loss 1.824265, val loss 1.940516
# epoch 286, total batch 1116579, train loss 1.833703, val loss 1.938349
# epoch 287, total batch 1120364, train loss 1.829357, val loss 1.937710
# epoch 288, total batch 1124149, train loss 1.816779, val loss 1.936606
# epoch 289, total batch 1127934, train loss 1.813985, val loss 1.932164
# epoch 290, total batch 1131719, train loss 1.816675, val loss 1.920734
# epoch 291, total batch 1135504, train loss 1.812672, val loss 1.926559
# epoch 292, total batch 1139289, train loss 1.806985, val loss 1.923277
# epoch 293, total batch 1143074, train loss 1.810269, val loss 1.927029
# epoch 294, total batch 1146859, train loss 1.809621, val loss 1.927210
# epoch 295, total batch 1150644, train loss 1.801008, val loss 1.920349
# epoch 296, total batch 1154429, train loss 1.799102, val loss 1.918972
# epoch 297, total batch 1158214, train loss 1.806758, val loss 1.920199
# epoch 298, total batch 1161999, train loss 1.807073, val loss 1.914899
# epoch 299, total batch 1165784, train loss 1.805693, val loss 1.912941
# epoch 300, total batch 1169569, train loss 1.795646, val loss 1.914906
# epoch 301, total batch 1173354, train loss 1.797376, val loss 1.907611
# epoch 302, total batch 1177139, train loss 1.793596, val loss 1.908691
# epoch 303, total batch 1180924, train loss 1.786899, val loss 1.903979
# epoch 304, total batch 1184709, train loss 1.791998, val loss 1.900614
# epoch 305, total batch 1188494, train loss 1.788608, val loss 1.904413
# epoch 306, total batch 1192279, train loss 1.789658, val loss 1.900350
# epoch 307, total batch 1196064, train loss 1.787295, val loss 1.905839
# epoch 308, total batch 1199849, train loss 1.776989, val loss 1.893968
# epoch 309, total batch 1203634, train loss 1.780814, val loss 1.892619
# epoch 310, total batch 1207419, train loss 1.781073, val loss 1.884429
# epoch 311, total batch 1211204, train loss 1.776822, val loss 1.893476
# epoch 312, total batch 1214989, train loss 1.771117, val loss 1.891729
# epoch 313, total batch 1218774, train loss 1.774018, val loss 1.885519
# epoch 314, total batch 1222559, train loss 1.759251, val loss 1.890361
# epoch 315, total batch 1226344, train loss 1.774302, val loss 1.890223
# epoch 316, total batch 1230129, train loss 1.767596, val loss 1.883890
# epoch 317, total batch 1233914, train loss 1.775524, val loss 1.882801
# epoch 318, total batch 1237699, train loss 1.763281, val loss 1.879315
# epoch 319, total batch 1241484, train loss 1.760892, val loss 1.879562
# epoch 320, total batch 1245269, train loss 1.763981, val loss 1.877848
# epoch 321, total batch 1249054, train loss 1.759007, val loss 1.874001
# epoch 322, total batch 1252839, train loss 1.752315, val loss 1.872788
# epoch 323, total batch 1256624, train loss 1.750187, val loss 1.862044
# epoch 324, total batch 1260409, train loss 1.750821, val loss 1.865068
# epoch 325, total batch 1264194, train loss 1.754182, val loss 1.867443
# epoch 326, total batch 1267979, train loss 1.748046, val loss 1.869564
# epoch 327, total batch 1271764, train loss 1.752886, val loss 1.863755
# epoch 328, total batch 1275549, train loss 1.745446, val loss 1.861199
# epoch 329, total batch 1279334, train loss 1.749567, val loss 1.859003
# epoch 330, total batch 1283119, train loss 1.742109, val loss 1.860528
# epoch 331, total batch 1286904, train loss 1.740397, val loss 1.862053
# epoch 332, total batch 1290689, train loss 1.738040, val loss 1.859056
# epoch 333, total batch 1294474, train loss 1.735136, val loss 1.855786
# epoch 334, total batch 1298259, train loss 1.736315, val loss 1.853695
# epoch 335, total batch 1302044, train loss 1.734538, val loss 1.852554
# epoch 336, total batch 1305829, train loss 1.737084, val loss 1.855235
# epoch 337, total batch 1309614, train loss 1.729529, val loss 1.850331
# epoch 338, total batch 1313399, train loss 1.727538, val loss 1.845614
# epoch 339, total batch 1317184, train loss 1.724819, val loss 1.847164
# epoch 340, total batch 1320969, train loss 1.731800, val loss 1.848995
# epoch 341, total batch 1324754, train loss 1.726128, val loss 1.842583
# epoch 342, total batch 1328539, train loss 1.730196, val loss 1.841829
# epoch 343, total batch 1332324, train loss 1.726668, val loss 1.837480
# epoch 344, total batch 1336109, train loss 1.721389, val loss 1.838188
# epoch 345, total batch 1339894, train loss 1.708059, val loss 1.838303
# epoch 346, total batch 1343679, train loss 1.721038, val loss 1.839258
# epoch 347, total batch 1347464, train loss 1.713512, val loss 1.838572
# epoch 348, total batch 1351249, train loss 1.718986, val loss 1.836461
# epoch 349, total batch 1355034, train loss 1.716320, val loss 1.831161
# epoch 350, total batch 1358819, train loss 1.720477, val loss 1.830997
# epoch 351, total batch 1362604, train loss 1.718685, val loss 1.826635
# epoch 352, total batch 1366389, train loss 1.710891, val loss 1.830874
# epoch 353, total batch 1370174, train loss 1.707370, val loss 1.832871
# epoch 354, total batch 1373959, train loss 1.706647, val loss 1.827988
# epoch 355, total batch 1377744, train loss 1.698882, val loss 1.832930
# epoch 356, total batch 1381529, train loss 1.707399, val loss 1.824543
# epoch 357, total batch 1385314, train loss 1.703618, val loss 1.825931
# epoch 358, total batch 1389099, train loss 1.705774, val loss 1.822175
# epoch 359, total batch 1392884, train loss 1.698884, val loss 1.823543
# epoch 360, total batch 1396669, train loss 1.701237, val loss 1.820528
# epoch 361, total batch 1400454, train loss 1.703841, val loss 1.825736
# epoch 362, total batch 1404239, train loss 1.690632, val loss 1.820364
# epoch 363, total batch 1408024, train loss 1.686340, val loss 1.811524
# epoch 364, total batch 1411809, train loss 1.682737, val loss 1.805215
# epoch 365, total batch 1415594, train loss 1.698883, val loss 1.817396
# epoch 366, total batch 1419379, train loss 1.691642, val loss 1.813342
# epoch 367, total batch 1423164, train loss 1.685672, val loss 1.805939
# epoch 368, total batch 1426949, train loss 1.680127, val loss 1.807134
# epoch 369, total batch 1430734, train loss 1.678203, val loss 1.805506
# epoch 370, total batch 1434519, train loss 1.696908, val loss 1.803177
# epoch 371, total batch 1438304, train loss 1.686331, val loss 1.804635
# epoch 372, total batch 1442089, train loss 1.685021, val loss 1.796185
# epoch 373, total batch 1445874, train loss 1.685499, val loss 1.805557
# epoch 374, total batch 1449659, train loss 1.683186, val loss 1.795641
# epoch 375, total batch 1453444, train loss 1.683080, val loss 1.793515
# epoch 376, total batch 1457229, train loss 1.683030, val loss 1.795459
# epoch 377, total batch 1461014, train loss 1.680774, val loss 1.789717
# epoch 378, total batch 1464799, train loss 1.676103, val loss 1.788694
# epoch 379, total batch 1468584, train loss 1.673894, val loss 1.793430
# epoch 380, total batch 1472369, train loss 1.673020, val loss 1.791353
# epoch 381, total batch 1476154, train loss 1.678279, val loss 1.800771
# epoch 382, total batch 1479939, train loss 1.671948, val loss 1.784687
# epoch 383, total batch 1483724, train loss 1.667310, val loss 1.787150
# epoch 384, total batch 1487509, train loss 1.665877, val loss 1.789208
# epoch 385, total batch 1491294, train loss 1.674080, val loss 1.789247
# epoch 386, total batch 1495079, train loss 1.664256, val loss 1.790384
# epoch 387, total batch 1498864, train loss 1.667218, val loss 1.784067
# epoch 388, total batch 1502649, train loss 1.664738, val loss 1.786362
# epoch 389, total batch 1506434, train loss 1.663955, val loss 1.779353
# epoch 390, total batch 1510219, train loss 1.666661, val loss 1.783069
# epoch 391, total batch 1514004, train loss 1.662586, val loss 1.774933
# epoch 392, total batch 1517789, train loss 1.660666, val loss 1.768878
# epoch 393, total batch 1521574, train loss 1.653308, val loss 1.766890
# epoch 394, total batch 1525359, train loss 1.650294, val loss 1.772172
# epoch 395, total batch 1529144, train loss 1.666184, val loss 1.768825
# epoch 396, total batch 1532929, train loss 1.648557, val loss 1.771808
# epoch 397, total batch 1536714, train loss 1.661091, val loss 1.773892
# epoch 398, total batch 1540499, train loss 1.646330, val loss 1.772642
# epoch 399, total batch 1544284, train loss 1.635069, val loss 1.770113
# epoch 400, total batch 1548069, train loss 1.648418, val loss 1.765602
# epoch 401, total batch 1551854, train loss 1.651721, val loss 1.764874
# epoch 402, total batch 1555639, train loss 1.653046, val loss 1.758504
# epoch 403, total batch 1559424, train loss 1.647453, val loss 1.761792
# epoch 404, total batch 1563209, train loss 1.640417, val loss 1.761710
# epoch 405, total batch 1566994, train loss 1.641670, val loss 1.760676
# epoch 406, total batch 1570779, train loss 1.632698, val loss 1.759304
# epoch 407, total batch 1574564, train loss 1.635930, val loss 1.759449
# epoch 408, total batch 1578349, train loss 1.643983, val loss 1.759420
# epoch 409, total batch 1582134, train loss 1.640118, val loss 1.754260
# epoch 410, total batch 1585919, train loss 1.637430, val loss 1.749012
# epoch 411, total batch 1589704, train loss 1.636948, val loss 1.753305
# epoch 412, total batch 1593489, train loss 1.635984, val loss 1.750914
# epoch 413, total batch 1597274, train loss 1.634507, val loss 1.750380
# epoch 414, total batch 1601059, train loss 1.634062, val loss 1.748789
# epoch 415, total batch 1604844, train loss 1.614578, val loss 1.745393
# epoch 416, total batch 1608629, train loss 1.621127, val loss 1.748933
# epoch 417, total batch 1612414, train loss 1.632389, val loss 1.745431
# epoch 418, total batch 1616199, train loss 1.625103, val loss 1.749068
# epoch 419, total batch 1619984, train loss 1.630929, val loss 1.743600
# epoch 420, total batch 1623769, train loss 1.624141, val loss 1.745636
# epoch 421, total batch 1627554, train loss 1.626063, val loss 1.741775
# epoch 422, total batch 1631339, train loss 1.634476, val loss 1.736468
# epoch 423, total batch 1635124, train loss 1.627727, val loss 1.742154
# epoch 424, total batch 1638909, train loss 1.623253, val loss 1.742190
# epoch 425, total batch 1642694, train loss 1.618923, val loss 1.742456
# epoch 426, total batch 1646479, train loss 1.620959, val loss 1.740090
# epoch 427, total batch 1650264, train loss 1.607431, val loss 1.730793
# epoch 428, total batch 1654049, train loss 1.624625, val loss 1.738638
# epoch 429, total batch 1657834, train loss 1.618960, val loss 1.726970
# epoch 430, total batch 1661619, train loss 1.612273, val loss 1.736426
# epoch 431, total batch 1665404, train loss 1.615379, val loss 1.732506
# epoch 432, total batch 1669189, train loss 1.611173, val loss 1.724865
# epoch 433, total batch 1672974, train loss 1.611238, val loss 1.728467
# epoch 434, total batch 1676759, train loss 1.604695, val loss 1.727514
# epoch 435, total batch 1680544, train loss 1.611439, val loss 1.730271
# epoch 436, total batch 1684329, train loss 1.609654, val loss 1.725222
# epoch 437, total batch 1688114, train loss 1.601769, val loss 1.725464
# epoch 438, total batch 1691899, train loss 1.609363, val loss 1.729846
# epoch 439, total batch 1695684, train loss 1.614327, val loss 1.728971
# epoch 440, total batch 1699469, train loss 1.604351, val loss 1.723955
# epoch 441, total batch 1703254, train loss 1.598582, val loss 1.722974
# epoch 442, total batch 1707039, train loss 1.594640, val loss 1.718216
# epoch 443, total batch 1710824, train loss 1.598827, val loss 1.732949
# epoch 444, total batch 1714609, train loss 1.606213, val loss 1.717998
# epoch 445, total batch 1718394, train loss 1.601421, val loss 1.720685
# epoch 446, total batch 1722179, train loss 1.599547, val loss 1.725130
# epoch 447, total batch 1725964, train loss 1.602267, val loss 1.718765
# epoch 448, total batch 1729749, train loss 1.594786, val loss 1.709631
# epoch 449, total batch 1733534, train loss 1.597675, val loss 1.718803
# epoch 450, total batch 1737319, train loss 1.589393, val loss 1.709117
# epoch 451, total batch 1741104, train loss 1.591900, val loss 1.709253
# epoch 452, total batch 1744889, train loss 1.596071, val loss 1.709142
# epoch 453, total batch 1748674, train loss 1.593796, val loss 1.718689
# epoch 454, total batch 1752459, train loss 1.597774, val loss 1.715366
# epoch 455, total batch 1756244, train loss 1.598535, val loss 1.707628
# epoch 456, total batch 1760029, train loss 1.593606, val loss 1.704024
# epoch 457, total batch 1763814, train loss 1.594326, val loss 1.707325
# epoch 458, total batch 1767599, train loss 1.582307, val loss 1.702315
# epoch 459, total batch 1771384, train loss 1.602014, val loss 1.701283
# epoch 460, total batch 1775169, train loss 1.584389, val loss 1.701175
# epoch 461, total batch 1778954, train loss 1.584883, val loss 1.702063
# epoch 462, total batch 1782739, train loss 1.590744, val loss 1.699995
# epoch 463, total batch 1786524, train loss 1.578622, val loss 1.698945
# epoch 464, total batch 1790309, train loss 1.584291, val loss 1.698205
# epoch 465, total batch 1794094, train loss 1.584736, val loss 1.697167
# epoch 466, total batch 1797879, train loss 1.580234, val loss 1.692004
# epoch 467, total batch 1801664, train loss 1.582600, val loss 1.699144
# epoch 468, total batch 1805449, train loss 1.574424, val loss 1.695193
# epoch 469, total batch 1809234, train loss 1.571052, val loss 1.698440
# epoch 470, total batch 1813019, train loss 1.582172, val loss 1.695837
# epoch 471, total batch 1816804, train loss 1.575854, val loss 1.694065
# epoch 472, total batch 1820589, train loss 1.580215, val loss 1.699678
# epoch 473, total batch 1824374, train loss 1.574706, val loss 1.692852
# epoch 474, total batch 1828159, train loss 1.574522, val loss 1.696609
# epoch 475, total batch 1831944, train loss 1.563851, val loss 1.691476
# epoch 476, total batch 1835729, train loss 1.573800, val loss 1.689630
# epoch 477, total batch 1839514, train loss 1.579268, val loss 1.695517
# epoch 478, total batch 1843299, train loss 1.567681, val loss 1.692317
# epoch 479, total batch 1847084, train loss 1.578752, val loss 1.687982
# epoch 480, total batch 1850869, train loss 1.574477, val loss 1.688856
# epoch 481, total batch 1854654, train loss 1.572908, val loss 1.690673
# epoch 482, total batch 1858439, train loss 1.569126, val loss 1.688997
# epoch 483, total batch 1862224, train loss 1.572490, val loss 1.690790
# epoch 484, total batch 1866009, train loss 1.569301, val loss 1.689668
# epoch 485, total batch 1869794, train loss 1.568466, val loss 1.686404
# epoch 486, total batch 1873579, train loss 1.557054, val loss 1.683559
# epoch 487, total batch 1877364, train loss 1.567544, val loss 1.685226
# epoch 488, total batch 1881149, train loss 1.565053, val loss 1.677386
# epoch 489, total batch 1884934, train loss 1.558530, val loss 1.679878
# epoch 490, total batch 1888719, train loss 1.558579, val loss 1.674902
# epoch 491, total batch 1892504, train loss 1.559120, val loss 1.675320
# epoch 492, total batch 1896289, train loss 1.550982, val loss 1.678367
# epoch 493, total batch 1900074, train loss 1.558194, val loss 1.674935
# epoch 494, total batch 1903859, train loss 1.550652, val loss 1.677251
# epoch 495, total batch 1907644, train loss 1.554524, val loss 1.670573
# epoch 496, total batch 1911429, train loss 1.555830, val loss 1.669528
# epoch 497, total batch 1915214, train loss 1.545265, val loss 1.675812
# epoch 498, total batch 1918999, train loss 1.558175, val loss 1.680172
# epoch 499, total batch 1922784, train loss 1.552478, val loss 1.668659
# epoch 500, total batch 1926569, train loss 1.553616, val loss 1.667981

# %%
word_vector_embed = word2vec.Word2Vec(embed_weights, dictionary)
word_vector_nce = word2vec.Word2Vec(nce_weights, dictionary)

# %%
word = 'mahathir'
print("Embedding layer: 8 closest words to: '%s'"%(word))
print(word_vector_embed.n_closest(word=word, num_closest=8, metric='cosine'), '\n')
print("NCE layer: 8 closest words to: '%s'"%(word))
print(word_vector_nce.n_closest(word=word, num_closest=8, metric='cosine'))
# Out:
# Embedding layer: 8 closest words to: 'mahathir'
# ['mahahir', 'rosmah', 'razak', 'norlela', 'shaeraine', 'zamihan', 'mahatir', 'najibpembangkang']
#
# NCE layer: 8 closest words to: 'mahathir'
# ['zambry', 'musa', 'subramaniam', 'rais', 'maszlee', 'daim', 'zakir', 'najib']

# %%
print(word_vector_nce.analogy('mahathir', 'anwar', 'kerajaan', 5))
# Out:
# ['kerajaan', 'anwar', 'dbkl', 'majikan', 'kwsp']

# %%
print(word_vector_embed.analogy('mahathir', 'anwar', 'kerajaan', 5))
# Out:
# ['anwar', 'kerajaan', 'rakyat', 'lpp', 'iktisad']

# %%
passage = [rev_dictionary[i] for i in word_array[12200:12300]]

# %%
readable = ''
for word in passage:
    if word == '"':
        readable += word
    elif word in ['?', '!', '.', ',']:
        readable += word + ' '
    else: 
        readable += ' ' + word
print(readable)
# Out:
#  sangat dominan sedangkan mca ada masalah mic dan gerakan ada masalah ini yang lemahkan bnnamun nature politik memang begitu tapi boleh settle down lepas prucuma bimbang orang malaysia sangat emosi dengan apa yang berlaku maka ia tidak sihatazizudin politik kena rasional jadi kita patut ke arah politik matangnamun hakikatnya melihat pada isu kaum ia berlaku di semua negarakena rasionalkan politik perkauman itu cuma di malaysia kita masih baik dan tidak berperang sesama sendirilihat faktor ekonomi mempengaruhi politik jadi fenomena arab spring tidak akan berlaku di malaysiamoderator adakah bn boleh reformmaszlee kalau kita lihat bn dan umno ada dinamik berevolusi ketika

# %%
x, y = word2vec.build_training_set(word_array[(12200-2):(12300+2)])
y_hat = model.sess.run(model.logits,feed_dict={model.X:x})
passage_predict = [rev_dictionary[i] for i in y_hat]

# %%
readable = ''
for word in passage_predict:
    if word == '"':
        readable += word
    elif word in ['?', '!', '.', ',']:
        readable += word + ' '
    else: 
        readable += ' ' + word
print(readable)
# Out:
#  lebih besar kerana tidak bukan pimpinan bendera dan tidak menyelesaikan isu ini yang aktif bnnamun permainan politik kalau ramai tak boleh diteruskan tahun lepas saya semua di ramai dan bangga terhadap apa yang berlaku kerana ia tidak benar kita secara denda jual mereka bergerak ke atas politik bangsa kita ada sesuatu polarisasi ini cina berlaku di semua jenis mainan politik seperti itu melayu di mana yang lebih terkawal dan perlu sesuai dengan jenis faktor yang dunia ekonomi negara seperti arab saudi tidak akan terjadi di - dan bn boleh buat kalau kita sokong sekarang dan sudah juga yang semalam kepada

# %%
import pickle
with open('word2vec-128.p', 'wb') as fopen:
    pickle.dump({'dictionary':dictionary,'rev_dictionary':rev_dictionary,
                 'embed_weights':embed_weights,'nce_weights':nce_weights}, fopen)
