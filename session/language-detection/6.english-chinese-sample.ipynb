# %%
# !wget http://downloads.tatoeba.org/exports/sentences.tar.bz2
# !bunzip2 sentences.tar.bz2
# !tar xvf sentences.tar

# %%
import pandas as pd

df = pd.read_csv('sentences.csv', sep = '\t', header = None)
df.head()
# Out:
#    0    1                       2
# 0  1  cmn                  我們試試看！
# 1  2  cmn                 我该去睡觉了。
# 2  3  cmn                 你在干什麼啊？
# 3  4  cmn                  這是什麼啊？
# 4  5  cmn  今天是６月１８号，也是Muiriel的生日！

# %%
eng = df.loc[df[1] == 'eng']
eng = eng.iloc[:,-1].tolist()

# %%
df[1].unique()
# Out:
# array(['cmn', 'deu', 'rus', 'fra', 'eng', 'jpn', 'spa', 'ita', 'kor',
#        'vie', 'nld', 'epo', 'por', 'tur', 'heb', 'hun', 'ell', 'ind',
#        'ara', 'arz', 'fin', 'bul', 'yue', 'swe', 'ukr', 'bel', 'que',
#        'ces', 'swh', 'nno', 'wuu', 'nob', 'zsm', 'est', 'kat', 'pol',
#        'lat', 'urd', 'sqi', 'isl', 'fry', 'afr', 'ron', 'fao', 'san',
#        'bre', 'tat', 'yid', 'uig', 'uzb', 'srp', 'qya', 'dan', 'pes', nan,
#        'slk', 'eus', 'cycl', 'acm', 'tgl', 'lvs', 'kaz', 'hye', 'hin',
#        'lit', 'ben', 'cat', 'bos', 'hrv', 'tha', 'orv', 'cha', 'mon',
#        'lzh', 'scn', 'gle', 'mkd', 'slv', 'frm', 'glg', 'vol', 'ain',
#        'jbo', 'toki', 'ina', 'nds', 'mal', 'tlh', 'roh', 'ltz', 'oss',
#        'ido', 'gla', 'mlt', 'sco', 'ast', 'jav', 'oci', 'ile', 'ota',
#        'xal', 'tel', 'sjn', 'nov', 'khm', 'tpi', 'ang', 'aze', 'tgk',
#        'tuk', 'chv', 'hsb', 'dsb', 'bod', 'sme', 'cym', 'mri', 'ksh',
#        'kur', 'ewe', 'kab', 'ber', 'tpw', 'udm', 'lld', 'pms', 'lad',
#        'grn', 'mlg', 'xho', 'pnb', 'grc', 'hat', 'lao', 'npi', 'cor',
#        'nah', 'avk', 'mar', 'guj', 'pan', 'kir', 'myv', 'prg', 'sux',
#        'crs', 'ckt', 'bak', 'zlm', 'hil', 'cbk', 'chr', 'nav', 'lkt',
#        'enm', 'arq', 'lin', 'abk', 'pcd', 'rom', 'gsw', 'tam', 'zul',
#        'awa', 'wln', 'amh', 'bar', 'mhr', 'bho', 'mrj', 'osx', 'pfl',
#        'mgm', 'sna', 'mah', 'hau', 'kan', 'nog', 'sin', 'glv', 'dng',
#        'kal', 'liv', 'vro', 'apc', 'jdt', 'fur', 'che', 'haw', 'yor',
#        'crh', 'pdc', 'ppl', 'kin', 'shs', 'mnw', 'tet', 'sah', 'kum',
#        'ngt', 'nya', 'pus', 'hif', 'mya', 'moh', 'wol', 'tir', 'ton',
#        'lzz', 'oar', 'lug', 'brx', 'non', 'mww', 'hak', 'nlv', 'ngu',
#        'bua', 'aym', 'vec', 'ibo', 'tkl', 'bam', 'kha', 'ceb', 'lou',
#        'fuc', 'smo', 'gag', 'lfn', 'arg', 'umb', 'tyv', 'kjh', 'oji',
#        'cyo', 'urh', 'kzj', 'pam', 'srd', 'lmo', 'swg', 'mdf', 'gil',
#        'snd', 'tso', 'sot', 'zza', 'tsn', 'pau', 'som', 'egl', 'ady',
#        'asm', 'ori', 'dtp', 'cho', 'max', 'kam', 'niu', 'sag', 'ilo',
#        'kaa', 'fuv', 'nch', 'hoc', 'iba', 'gbm', 'sun', 'war', 'mvv',
#        'pap', 'ary', 'kxi', 'csb', 'pag', 'cos', 'rif', 'kek', 'krc',
#        'aii', 'ban', 'ssw', 'tvl', 'mfe', 'tah', 'bvy', 'bcl', 'hnj',
#        'nau', 'nst', 'afb', 'quc', 'min', 'tmw', 'mad', 'bjn', 'mai',
#        'cjy', 'got', 'hsn', 'gan', 'tzl', 'dws', 'ldn', 'afh', 'sgs',
#        'krl', 'vep', 'rue', 'tly', 'mic', 'ext', 'izh', 'sma', 'jam',
#        'cmo', 'mwl', 'kpv', 'koi', 'ike', '\\N', 'run', 'mnc', 'aoz',
#        'otk', 'kas', 'aln', 'akl', 'shy', 'fkv', 'gos', 'fij', 'thv',
#        'gcf', 'cay', 'xmf', 'tig', 'lij', 'rap', 'div', 'hrx', 'cpi',
#        'gaa', 'ltg', 'bzt', 'emx', 'gom', 'chg', 'osp'], dtype=object)

# %%
ms = df.loc[df[1] == 'zlm']
ms = ms.iloc[:,-1].tolist()
len(ms)
# Out:
# 98

# %%
ind = df.loc[df[1] == 'ind']
ind = ind.iloc[:,-1].tolist()
len(ind)
# Out:
# 12515

# %%
others = df.loc[~df[1].isin(['zlm', 'ind', 'eng'])]
others = others.iloc[:,-1].tolist()
len(others)
# Out:
# 6816517

# %%
import re
import cleaning
from tqdm import tqdm

def preprocessing(string):
    string = re.sub(
        'http\S+|www.\S+',
        '',
        ' '.join(
            [i for i in string.split() if i.find('#') < 0 and i.find('@') < 0]
        ),
    )
    
    chars = ',.()!:\'"/;=-'
    for c in chars:
        string = string.replace(c, f' {c} ')
        
    string = re.sub(
        u'[0-9!@#$%^&*()_\-+{}|\~`\'";:?/.>,<]',
        ' ',
        string,
        flags = re.UNICODE,
    )
    string = re.sub(r'[ ]+', ' ', string).strip()
    
    return string.lower()

def loop(strings):
    for i in tqdm(range(len(strings))):
        strings[i] = preprocessing(strings[i])
    return strings

# %%
eng = cleaning.multiprocessing(eng, loop)
# Out:
# 100%|██████████| 80573/80573 [00:01<00:00, 74237.04it/s]
#  97%|█████████▋| 77984/80573 [00:01<00:00, 70602.29it/s]
# 100%|██████████| 80573/80573 [00:01<00:00, 67629.92it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]0:00, 69817.19it/s]
# 100%|██████████| 4/4 [00:00<00:00, 10936.91it/s]
# 100%|██████████| 80573/80573 [00:01<00:00, 73532.33it/s]
# 100%|██████████| 80573/80573 [00:01<00:00, 70092.20it/s]
#  98%|█████████▊| 78614/80573 [00:01<00:00, 65517.94it/s]
# 100%|██████████| 80573/80573 [00:01<00:00, 64470.88it/s]
# 100%|██████████| 80573/80573 [00:01<00:00, 68718.48it/s]
#  95%|█████████▍| 76367/80573 [00:01<00:00, 69520.98it/s]
# 100%|██████████| 80573/80573 [00:01<00:00, 74932.94it/s]
# 100%|██████████| 80573/80573 [00:01<00:00, 68346.33it/s]
#
# 100%|██████████| 80573/80573 [00:01<00:00, 64975.34it/s]
# 100%|██████████| 80573/80573 [00:01<00:00, 65209.12it/s]
# 100%|██████████| 80573/80573 [00:01<00:00, 62820.06it/s]

# %%
ms = cleaning.multiprocessing(ms, loop)
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 3296.11it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 3147.70it/s]
#
#
# 100%|██████████| 6/6 [00:00<00:00, 4368.31it/s]
#
#
#
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#
#
#
#
# 100%|██████████| 2/2 [00:00<00:00, 11491.24it/s]

# %%
ind = cleaning.multiprocessing(ind, loop)
# Out:
# 100%|██████████| 782/782 [00:00<00:00, 59036.43it/s]
# 100%|██████████| 782/782 [00:00<00:00, 48154.47it/s]
#
# 100%|██████████| 782/782 [00:00<00:00, 56839.89it/s]
#
# 100%|██████████| 782/782 [00:00<00:00, 55925.96it/s]
#   0%|          | 0/3 [00:00<?, ?it/s], 52451.44it/s]
#
# 100%|██████████| 782/782 [00:00<00:00, 53525.67it/s]
# 100%|██████████| 782/782 [00:00<00:00, 40678.97it/s]
#
#
# 100%|██████████| 782/782 [00:00<00:00, 44519.11it/s]
#
#
# 100%|██████████| 782/782 [00:00<00:00, 26638.94it/s]

# %%
others = cleaning.multiprocessing(others, loop)
# Out:
# 100%|██████████| 426032/426032 [00:05<00:00, 82248.14it/s]
# 100%|██████████| 5/5 [00:00<00:00, 23912.79it/s]67.35it/s]
# 100%|██████████| 426032/426032 [00:05<00:00, 71134.40it/s]
# 100%|██████████| 426032/426032 [00:06<00:00, 69098.88it/s]
# 100%|██████████| 426032/426032 [00:06<00:00, 70319.38it/s]
# 100%|██████████| 426032/426032 [00:06<00:00, 69293.78it/s]
# 100%|██████████| 426032/426032 [00:05<00:00, 71253.13it/s]
# 100%|██████████| 426032/426032 [00:06<00:00, 70523.62it/s]
# 100%|██████████| 426032/426032 [00:05<00:00, 71551.52it/s]
# 100%|██████████| 426032/426032 [00:05<00:00, 74259.51it/s]
# 100%|██████████| 426032/426032 [00:05<00:00, 72331.63it/s]
# 100%|██████████| 426032/426032 [00:05<00:00, 73642.58it/s]
# 100%|██████████| 426032/426032 [00:05<00:00, 72656.56it/s]
# 100%|██████████| 426032/426032 [00:05<00:00, 71790.40it/s]
# 100%|██████████| 426032/426032 [00:05<00:00, 72639.01it/s]
# 100%|██████████| 426032/426032 [00:05<00:00, 74095.97it/s]
# 100%|██████████| 426032/426032 [00:06<00:00, 70851.76it/s]

# %%
import json

with open('eng.json', 'w') as fopen:
    json.dump(eng, fopen)

# %%
with open('ms.json', 'w') as fopen:
    json.dump(ms, fopen)

# %%
with open('ind.json', 'w') as fopen:
    json.dump(ind, fopen)

# %%
with open('others.json', 'w') as fopen:
    json.dump(others, fopen)

# %%
import json

with open('ind.json') as fopen:
    ind = json.load(fopen)
    
ind
# Out:
# ['ibu sedang masak di dapur',
#  'mary tidak punya teman bicara tapi dia tidak merasa kesepian',
#  'mary adalah gadis yang enak diajak bicara',
#  'mary memutuskan untuk tidak akan menemuinya lagi',
#  'apakah mary sudah mulai',
#  'mary sangat suka susu',
#  'mary belum mulai',
#  'mary gagal lagi meski begitu dia masih muda',
#  'mary selalu membantu pacarnya mengerjakan tugas',
#  'pesawat ini mampu menampung orang penumpang sekali terbang',
#  'harga tanah di jepang mahal sekali',
#  'dilihat dari pesawat pulau itu terlihat indah sekali',
#  'pulau itu ada di jepang sebelah selatan',
#  'pulau itu ada di jepang sebelah barat',
#  'pulau itu tertutup es dan salju selama musim dingin',
#  'pulau itu ditemukan oleh siapa',
#  'pulau itu dihantam topan',
#  'pulau itu mudah dijangkau dengan perahu',
#  'pulau itu bagaikan surga bagi anak anak',
#  'setiap jengkal pulau telah dijelajahi',
#  'pulau itu terletak dua mil dari pantai',
#  'pulau itu terletak satu mil dari pantai',
#  'pulau itu hangat sepanjang tahun',
#  'pulau itu pernah diperintah prancis',
#  'pada tahun dua puluh satu persen populasinya akan melebihi enam puluh lima',
#  'pada tahun populasi kota ini akan dua kali lipat',
#  'dua ratus orang meninggal karena kolera tahun lalu',
#  'tolong perlihatkan yang ini',
#  'siapa yang merusak ini',
#  'perempuan itu membeli daging ayam',
#  'perempuan itu suka burung atau bunga',
#  'perempuan itu membeli buku tentang burung',
#  'apakah dia tahan melakukan perjalanan jauh',
#  'perekam itu saya beli di toko ini',
#  'masalahnya bukan pada tujuan pendidikan tapi lebih kepada pelaksanaannya',
#  'masalahnya adalah kita tidak punya cukup uang',
#  'saya seharusnya membersihkan ruangan itu',
#  'saya simpati terhadap orang yang terkena penyakit itu',
#  'dibandingkan rumahnya rumahku terlihat lebih kecil',
#  'rumahku menghadap selatan',
#  'rumahku dekat dengan menara tokyo',
#  'halaman rumahku sempit',
#  'rumahku berada di seberang jalan',
#  'rumahku dirancang agar tahan gempa',
#  'rumahku dekat dengan fasilitas yang nyaman di kota besar',
#  'keluargaku keluarga besar',
#  'rumahku besar',
#  'rumahku di sebelah utara kota',
#  'rumahku di samping pohon tinggi',
#  'rumahku di pinggiran kota',
#  'rumahku dekat sekali dengan taman',
#  'rumahku lama dan jelek',
#  'keluargaku keluarga lama',
#  'rumahku berada di atas bukit',
#  'karena rumahku di atas bukit pemandangannya indah',
#  'rumahku menghadap laut',
#  'rumahku kebakaran',
#  'rumahku dekat stasiun',
#  'rumahku dekat sekali dengan stasiun',
#  'rumahku dekat stasiun dan nyaman',
#  'rumahku hanya menit berjalan kaki dari stasiun',
#  'rumahku menit berjalan kaki dari stasiun',
#  'rumahku agak jauh dari stasiun',
#  'rumahku dekat dengan pemberhentian bis',
#  'rumahku menghadap jalan ramai',
#  'rumahku selalu bergetar saat truk lewat',
#  'rumahku berada di daratan selatan sungai thames',
#  'rumahku tepat di seberang jalan',
#  'rumahku sedikit masuk dari jalan itu',
#  'rumahku di pinggiran kota itu',
#  'rumahku jauh dari sini',
#  'rumahku blok dari sini',
#  'rumahku di kampung',
#  'rumahku di seberang jembatan itu',
#  'rumahku di lantai',
#  'rumahku berlantai',
#  'rumahku mirip dengan rumahmu',
#  'di sebelah rumahku didirikan bangunan tinggi',
#  'di belakang rumahku ada kolam kecil',
#  'di depan rumahku ada danau',
#  'di halaman rumahku dulu ada kebun sayur',
#  'di depan rumahku ada kantor pos',
#  'di depan rumahku ada toko buku',
#  'di depan rumahku ada toko',
#  'di depan rumahku ada pohon besar',
#  'di depan rumahku ada taman umum',
#  'di depan rumahku sedang dibangun sebuah gedung',
#  'di depan rumahku ada pohon sakura',
#  'di atas rumahku jadi tenang',
#  'di belakang rumahku hutan',
#  'di belakang rumahku gereja',
#  'di dekat rumahku mengalir sungai kecil',
#  'di dekat rumahku ada taman indah',
#  'di dekat rumahku ada jalan besar',
#  'di dekat rumahku ada taman',
#  'di dekat rumahku ada sekolah',
#  'di dekat rumahku ada beberapa toko',
#  'di dekat rumahku tidak ada toko',
#  'di dekat rumahku ada taman bagus',
#  'di dekat rumahku ada apartemen',
#  'atap rumahku merah',
#  'kalau mau datang ke rumahku tolong telepon dulu',
#  'tolong datang ke rumahku',
#  'bisa datang ke rumah dan main piano',
#  'rumahku sudah diasuransikan penuh',
#  'di rumahku cuma ada halaman kecil',
#  'rumahku sudah punya asuransi kebakaran',
#  'di rumahku perabotannya sedikit',
#  'di rumahku memang ada hantunya',
#  'tutup pintu itu',
#  'tangannya terluka waktu jatuh',
#  'dia punya sawah luas di colorado',
#  'dia tidak dapat berjalan lagi',
#  'saya tahu dia tidak dapat bekerja lagi',
#  'orang yang ingin berbicara denganmu sudah datang di bawah',
#  'saya senang sekali berjumpa denganmu',
#  'senang sekali berjumpa dengan anda pak tamori',
#  'saya pikir dia akan senang jika bertemu denganmu',
#  'saya merasa senang sekali berjumpa dengan anda',
#  'boleh minta tolong',
#  'aku ingin kamu buat teh untukku',
#  'saya merasa terhormat bisa berjumpa dengan anda',
#  'senang bisa bertemu denganmu',
#  'saya merasa senang sekali bertemu denganmu',
#  'senang bertemu denganmu saya tunggu kabar darimu',
#  'tak terpikir bisa berjumpa denganmu',
#  'saya berharap bisa bertemu denganmu',
#  'senang bertemu denganmu',
#  'wanita yang ingin bertemu denganmu sudah datang',
#  'berapa gaji yang harus kubayar tergantung pada kemampuanmu',
#  'tertawa adalah obat paling mujarab',
#  'apakah tertawa hanya ada pada manusia',
#  'tertawa terbahak bahak membuat gerahamku serasa mau lepas',
#  'peraturan seharusnya dipatuhi',
#  'kita harus taat peraturan',
#  'penting sekali mematuhi peraturan',
#  'peraturan mengharuskan setiap warga negara membayar pajak',
#  'peraturan mengatakan bahwa setiap warga negara sama',
#  'awas ada truk lewat',
#  'awas',
#  'hampir saja aku tertabrak mobil',
#  'kopinya kurang',
#  'kopi sebagai hidangan penutup',
#  'mau kopi atau teh',
#  'sebagian orang suka kopi sebagian lagi suka teh',
#  'aku ingin sekali minum kopi',
#  'aku ingin minum kopi',
#  'kopinya tumpah',
#  'jika masih ada sisa kopi tolong berikan padaku',
#  'saya ingin meminum secangkir kopi',
#  'ingin minum kopi',
#  'gordon tertarik dengan gaya hidup jepang',
#  'gordon melamun terus minggu ini',
#  'saat kamu memakai jas biar aku yang membawa tasmu',
#  'biar kubantu memakai jas',
#  'pakai jasmu',
#  'lepaskan jasmu',
#  'sebaiknya kamu pakai jasmu',
#  'tolong lepas jasmu',
#  'lepas jasmu dan silakan bersantai',
#  'kenapa tidak kau lepas jasmu',
#  'boleh kubawakan jasmu',
#  'tolong gantung jasmu',
#  'gantung jasmu di penggantung baju',
#  'silakan taruh jasmu di bawah',
#  'boleh kugantungkan jasmu',
#  'kancing jasku lepas',
#  'salah satu kancing jasku lepas',
#  'saya ingin kursi di dekat jasku',
#  'tempat duduk berjarak kira kira yard dari jasku boleh juga',
#  'pelatih itu mengawasi berenangnya para perenang',
#  'pelatih itu menyuruh para perenang berenang mil setiap hari',
#  'menurut pelatih bob adalah perenang bagus',
#  'ibunya guru bahasa inggris',
#  'ibunya dulu seorang penyanyi',
#  'ibunya selalu mengeluh tentang hal itu',
#  'ayahnya memanggilnya tom',
#  'sepertinya ayahnya sedang masuk rumah sakit',
#  'sepertinya ayahnya sedang di luar negeri',
#  'hobiku memancing ikan',
#  'hobiku mengoleksi perangko luar negeri',
#  'hobiku musik',
#  'hobiku mendengarkan musik',
#  'hobiku golf',
#  'hobiku bermain piano',
#  'hobiku mengoleksi koin',
#  'hobiku mengumpulkan kupu kupu cantik',
#  'hobiku bermain gitar',
#  'hobiku menulis cerita',
#  'salah satu hobiku musik klasik',
#  'salah satu hobiku membuat bunga palsu',
#  'salah satu hobiku mengumpulkan perangko lama',
#  'kecepatan pesawat jauh lebih tinggi daripada helikopter',
#  'sudah pesan tempat di pesawat',
#  'sepertinya pesawat terlambat',
#  'pesawat itu sudah tak tampak',
#  'suara pesawat pun terdengar',
#  'berkat pesawat perjalanan dari osaka ke tokyo dapat ditempuh dalam jam',
#  'berkat pesawat orang dapat melakukan perjalanan jarak jauh dengan cepat',
#  'berkat pesawat kita dapat mengelilingi dunia dalam hari',
#  'salah satu mesin pesawat mati',
#  'pak sato telah naik pesawat dengan selamat',
#  'ini adalah kali ke naik pesawat',
#  'saya tertinggal pesawat bisa naik penerbangan berikutnya',
#  'agar tak tertinggal pesawat saya bergegas ke bandara',
#  'saya tak ingin tertinggal pesawat',
#  'ini adalah pertama kali saya naik pesawat',
#  'sebanyak penumpang naik pesawat',
#  'saya tak suka bepergian naik pesawat',
#  'pernah bepergian naik pesawat',
#  'dengan naik pesawat ke london bisa hanya hari',
#  'naik pesawat atau kereta',
#  'bepergian naik pesawat adalah paling cepat',
#  'kalau naik pesawat lebih mahal lho',
#  'bepergian naik pesawat berapa ongkosnya',
#  'bepergian ke okinawa naik pesawat berapa lama',
#  'aku hanyalah pengelana yang mencari kemurnian jiwa',
#  'karena hanya satu menit berharga hampir pound',
#  'saya menghadiri pesta hanya untuk bersosialisasi',
#  'anda jujur mengakui kesalahan anda',
#  'orang hindu menyembah di kuil',
#  'tak ada hubungan antara mereka',
#  'lakukan tapi sekarang',
#  'menyiapkannya sekaligus',
#  'mari kita selesaikan segera',
#  'lakukan sekaligus',
#  'kita butuh uang untuk melakukan apapun',
#  'biarkan rasa yang memilih',
#  'bersatu kita teguh bercerai kita runtuh',
#  'bhinneka tunggal ika',
#  'siapa bersungguh sungguh dia akan sukses',
#  'berlomba lomba dalam kebaikan',
#  'dirikanlah shalat',
#  'bukan itu maksud saya sex diskriminasi diskriminasi perempuan benar benar selain itu pria dan wanita berbeda',
#  'peringatan dilarang cabul',
#  'perang datang dan pergi tapi prajuritku tetap abadi',
#  'matang lebih baik',
#  'iblis menggugat tuhan',
#  'kiamat sudah dekat',
#  'beranak dalam pohon',
#  'tuhan adalah kejahatan',
#  'tahu sebelum terjadi',
#  'melihat dengan telinga',
#  'baca musiknya dengar fiksinya',
#  'saya tidak mengetahui cara penggunaan komputer ini',
#  'sangat penting baginya manakah dari keduanya yang lebih indah',
#  'pria itu bukan hanya bisa berbahasa inggris tapi juga bahasa jerman',
#  'tidak dapat dipungkiri keberaniannya patut dikagumi',
#  'nancy tersenyum bahagia',
#  'berapa harga dasi ini',
#  'opera apakah yang sedang dipertunjukkan di lincoln center saat ini',
#  'karena itulah dia tidak pergi belajar ke luar negeri',
#  'yang perlu anda lakukan hanyalah menandatangani nama anda di sini',
#  'rapat tersebut ditunda hingga jumat depan',
#  'dia telah mencoba berbagai cara melangsingkan badan',
#  'dia memberitahuku bahwa dia akan mengunjungi nara bulan depan',
#  'kurangi minum dan tidurlah lebih banyak',
#  'kami dulu saling bertetangga',
#  'pertanyaannya sesulit itu hingga tiada siapapun mampu menjawabnya',
#  'kita banyak membuang waktu',
#  'terus jalan lurus hingga tiba di gereja tersebut',
#  'tolong kirimkan surat ini pada kesempatan berikutnya ke kantor pos',
#  'kameraku tahan air',
#  'sudah berapa lama menunggu bus',
#  'saat ayahku pensiun nanti dia sudah hampir tahun bekerja',
#  'kereta tersebut terguling',
#  'biasanya saya bangun pada pukul enam',
#  'seperti biasa tom terlambat datang ke kelas',
#  'majalah apapun boleh',
#  'mari mulai dari pelajaran',
#  'apa kabar',
#  'saya baik baik saja terima kasih',
#  'terima kasih sama sama',
#  'terima kasih banyak',
#  'nama saya jack',
#  'siapa nama anda',
#  'selamat pagi semuanya',
#  'selamat pagi kata tom sambil tersenyum',
#  'tolong sampaikan salamku kepadanya',
#  'dia meninggal dunia kemarin siang',
#  'kami berangkat besok siang',
#  'selamat tidur bu',
#  'kapan ulang tahunmu',
#  'besok dia berulang tahun',
#  'selamat ulang tahun muriel',
#  'aku suka lasagna',
#  'aku cinta kamu',
#  'jaga dirimu sendiri',
#  'saya tidak peduli',
#  'di amerika utara usaha umumnya berpegang pada prinsip pelanggan selalu benar',
#  'penemuan ini akan tercatat dalam sejarah',
#  'aku adalah seorang laki laki tanpa wanita',
#  'saya tidak dapat melihat akhir',
#  'saya tidak dapat mempercayai itu',
#  'saya mendengar anda tapi saya tidak dapat melihat anda',
#  'saya senang ketika saya membaca',
#  'apakah anda siap',
#  'aku berikan kamu kataku',
#  'kamu dapat beristirahat sampai malam',
#  'dunia akan tersenyum bahagia tanpa diriku',
#  'aku tidak dapat hidup tanpa sebuah tv',
#  'aku tidak dapat hidup tanpa kamu',
#  'aku tidak dapat membayangkan hidup tanpa kamu',
#  'aku tidak dapat melakukannya tanpa bantuan dia perempuan',
#  'terbakar dengan cinta',
#  'saya tidak terlalu mengerti apa yang ia laki laki katakan',
#  'meskipun dia telah tiada aku tetap mencintainya lebih dari apapun juga',
#  'cinta adalah misteri dan penderitaan tanpa batas waktu',
#  'aku akan memakan kamu anak kecil',
#  'memberi lebih baik daripada diberi',
#  'belajar untuk mencintai produk dalam negeri',
#  'sesuatu yang kecil dapat menyebabkan hal yang besar',
#  'cinta yang tulus adalah cinta yang tanpa paksaan',
#  'kemanakah kita pergi setelah kita mati',
#  'perjodohan adalah suatu bentuk pelanggaran terhadap hak asasi manusia',
#  'pernikahan yang indah adalah pernikahan yang didasari oleh kasih sayang dan cinta yang tulus',
#  'ada gula ada semut',
#  'saya mencoba menjelaskan kepada dia bahwa kami tidak bertanggung jawab atas kesalahannya namun ia menolak mendengar',
#  'buku tua ini bernilai yen',
#  'pria ini benar benar sangat tua',
#  'aku memanggil namamu',
#  'setahu aku museum itu tutup setiap hari senin',
#  'ranjang ini tampak kokoh',
#  'kucing yang hilang tersebut masih belum ditemukan',
#  'bosku dipaksa mengundurkan diri',
#  'gaya hidup dan keseimbangan makanan yang teratur adalah kunci bagi hidup sehat',
#  'tambah hasilnya',
#  'ibunya mengkhawatirkan anaknya',
#  'saya lebih memilih berpergian dengan mobil',
#  'hari ini berawan dan kemungkinan hujan jadi kita lebih baik tidak pergi berselancar',
#  'sungguh terima kasih atas bantuannya',
#  'sikapnya padaku berbeda dari biasanya',
#  'saya tidak bisa menyetujui proyek ini masih banyak hal yang tidak memuaskan',
#  'kyoto terkenal dengan kuil dan viharanya',
#  'dapatkah anda membantu saya mencarikan rumah dengan sebuah taman kecil',
#  'makin hari makin dingin',
#  'saya sama sekali tidak mengerti bahasa jerman',
#  'ada rekomendasi makanan yang enak',
#  'festival sekolah kami diadakan bulan lalu',
#  'permintaannya wajar',
#  'mohon tunggu giliran anda',
#  'pria tersebut mengaku bahwa ia merampok wanita tua itu',
#  'besok dia di rumah',
#  'dia pasti berhasil',
#  'tolong tutup pintu di belakangmu',
#  'bersikap lebih baiklah terhadap anak sendiri',
#  'putraku telah masuk sekolah menengah',
#  'boleh tolong buka pintunya',
#  'dia bekerja di pabrik',
#  'kamu mengambil kunci yang salah',
#  'aku ingin mengganti ini ke ukuran yang lebih kecil',
#  'aku melihat dari jendela garasi terkejut pada apa yang aku lihat',
#  'saya cinta kamu',
#  'saya mengecewakan karena dia laki laki tidak hadir',
#  'mobil tersebut rusak',
#  'saya suka semua film yang disutradarai juzo itami',
#  'yesus dilahirkan maria',
#  'selamat pagi',
#  'pria yang istrinya telah meninggal dunia disebut seorang duda',
#  'tahukah kenapa langit terlihat berwarna biru',
#  'baju itu memikat hatinya untuk masuk ke dalam toko',
#  'bis itu berhenti dan kami masuk',
#  'air dalam tanki tinggal sedikit mungkin juga habis',
#  'mereka memutuskan untuk bermukim di virginia tahun itu',
#  'saya tidak menyangka ia bisa berbuat sekejam itu',
#  'kau harus membayar harganya',
#  'tahun an dimulai dengan peristiwa teluk',
#  'aku ingin buku itu katanya pada dirinya sendiri',
#  'dalam waktu dekat ini kita akan mampu mengobati aids',
#  'pada pagi saya tiba di sana saya berjalan jalan dalam hutan oak',
#  'jika dia bertanya saya akan berikan jika tidak tidak',
#  'kami semua bahagia',
#  'semoga tuhan memberkatimu',
#  'pemasukannya berkurang setengah setelah pensiun',
#  'saya tidak tahu apa arti kata ini',
#  'saya suka musik instrumental',
#  'rambut anak itu hitam',
#  'ayahnya makan di sana dua kali seminggu',
#  'dia membagi dua kuenya',
#  'saya membaca new york times',
#  'sayang sekali hujan',
#  'sungai ini bermuara di pasifik',
#  'ini sekolah kami',
#  'yang coklat punya saya juga',
#  'nancy takut anjing',
#  'kepala saya masih merasa pusing',
#  'apa kamu cukup tidur',
#  'saya baru selesai membaca buku itu',
#  'kemarin pagi sangat dingin',
#  'dia keluar dari ruangan tanpa mengatakan sepatah kata pun',
#  'bill membawakan saya buku ini',
#  'dia suka bermain tenis',
#  'buddhisme bermula dari india',
#  'saya mulai malam ini',
#  'bagaimana kabar ibumu',
#  'judy melihat saya',
#  'kalimat ini benar secara gramatik',
#  'mohon tunggu sebentar',
#  'bagaimana kabar anda',
#  'tom bukan anak yang pemalas',
#  'tidak',
#  'semua orang dilahirkan merdeka dan mempunyai martabat dan hak hak yang sama mereka dikaruniai akal dan hati nurani dan hendaknya bergaul satu sama lain dalam semangat persaudaraan',
#  'saya dengar bahwa belajar di pagi hari lebih efektif belajar satu jam di pagi hari sama baiknya dengan belajar tiga jam di malam hari',
#  'jalur tokaido berhenti di tokyo',
#  'dia kaya pengalaman',
#  'perkataannya telah membuat kesan yang dalam terhadap murid murid',
#  'saya merasa agak tidak enak badan hari ini',
#  'kami ingin anda datang ke pesta kami',
#  'dia tidak datang katanya',
#  'pria itu tidak datang kata perempuan itu',
#  'dia memiliki keinginan yang kuat untuk bekerja sebagai seorang penerjemah',
#  'saya sedang ingin pergi berjalan jalan',
#  'saya tidak mengerti',
#  'sepertinya dia yakin bahwa apa yang dia katakan adalah benar',
#  'dia mengumpulkan banyak perangko',
#  'tiba tiba lampu padam',
#  'datang dan temui saya saat anda memiliki waktu',
#  'kami berharap agar dia segera kembali',
#  'silahkan menghubungi saya kembali nanti',
#  'saya ingin tahu siapa yang akan datang bersama kita',
#  'semua orang dipersilahkan',
#  'columbus menemukan amerika pada tahun',
#  'dia menghindar untuk bertemu dengannya dalam perjalanan',
#  'apakah kamu mengenal mereka',
#  'gerbang ditutup pada pukul delapan',
#  'terima kasih untuk pertolongan anda',
#  'istriku mempunyai kesalahan kesalahan meskipun demikian aku mencintainya',
#  'pengetahuan tentang komputer adalah dasar daripada segala ilmu pengetahuan',
#  'kita harus tetap tenang',
#  'dia membuat sebuah alasan',
#  'saya sangat sibuk akhir akhir ini hingga kepala saya pening saya bahkan tidak memiliki waktu untuk menonton video',
#  'jikalau barang seorang tiada mau bekerja jangan ia makan',
#  'siapa orang itu',
#  'sudah lama sejak saya mengunjungi nenek saya',
#  'dia meminta maaf karena telah menyinggungnya',
#  'saya sudah mengenalnya sejak kecil',
#  'saya yakin saya akan dapat menemukannya',
#  'saya tidak dapat membantumu',
#  'sepertinya koper saya telah dicuri',
#  'apa yang dia katakan di dalam suratnya',
#  'mereka tinggal di hotel selama seminggu',
#  'ibunya sedang menulis surat',
#  'yoko sedang berada di london saat ini dia belajar bahasa inggris',
#  'saya tidak dapat menerima bahwa istri saya benar benar sudah meninggal',
#  'saya akan bermain tenis',
#  'mike tidak ikut berlatih kemarin',
#  'saya dapat menemukan rumahnya dengan mudah',
#  'dapatkah kamu meletakannya di meja',
#  'bagaimanapun saya tidak punya uang',
#  'intinya adalah ibu terlalu sibuk',
#  'dia punya masa depan yang cerah',
#  'apa yang sedang dilakukan ken',
#  'kami mengenalnya',
#  'kucingku tersayang sudah seminggu hilang',
#  'angka tujuh terkadang dianggap sebagai angka keberuntungan',
#  'perusahan jepang umumnya menyediakan seragam untuk para karyawannya',
#  'kamu tidak harus pergi kecuali kalau kamu memang mau',
#  'saya sering jatuh tapi saya tidak pernah menyerah',
#  'tidak memerlukan waktu lama',
#  'kurang tidur tidak baik bagi kesehatan anda',
#  'kamu tidak melihat apapun',
#  'saya merasa sedih tanpa alasan',
#  'hewan dan tumbuhan hidup di planet ini',
#  'sudah sepuluh tahun sejak saya meninggalkan kuliah',
#  'dia naik taksi ke museum',
#  'ayo makan siang',
#  'saya makan hot dog untuk makan siang',
#  'dia dapat berenang dengan cepat',
#  'kota kibune terletak dekat kyoto',
#  'kamu dapat menghubunginya dengan menelpon nomor ini',
#  'dia menyembunyikan kesedihannya dibalik senyum',
#  'saya akan menelponmu besok pagi',
#  'saya sedang makan sebuah apel',
#  'sepatumu ada di sini',
#  'tidak ada bukti',
#  'dia masih bergantung secara finansial kepada orang tuanya',
#  'mengapa kamu tidak ikut memancing dengan kami akhir minggu ini jika kamu tidak sibuk',
#  'dia ditemukan terbaring tidak sadar di lantai dapur',
#  'ini di luar pertanyaan',
#  'ngomong ngomong berapa umurmu',
#  'yang satu merah dan yang lainnya putih',
#  'dia pasti sudah berkata bohong',
#  'dia menyeberang jalan',
#  'aku akan mendapat sim akhir tahun ini',
#  'kamu terlihat berbeda hari ini',
#  'aku mengatakan ini dari hati',
#  'kejujuran bukan jaminan sukses',
#  'makanan dan pelayanannya baik sekali',
#  'ledakan populasi adalah masalah yang serius',
#  'apakah kita diperbolehkan menggunakan lift',
#  'dia sepertinya dalam masalah',
#  'apa pekerjaannya',
#  'saya pikir itu ide yang bagus',
#  'saya harap saya dapat bertemu anda lagi segera',
#  'hari ini sangat panas',
#  'dia meninggalkan rumah pukul',
#  'saya akan menunggu di sini sampai dia datang',
#  'dia sedang mendengarkan radio dengan earphone',
#  'dia sangat mirip dengan ayahnya',
#  'dia terpeleset saat sedang menyeberang jalan',
#  'aku menunjukkan kamarku padanya',
#  'foto ini mengingatkanku pada masa kecilku',
#  'hujan deras selama sekitar setengah jam',
#  'penyair sering membandingkan kematian dengan tidur',
#  'dia tinggal di hutan seorang diri',
#  'pasangan itu telah berpisah tidak pernah bertemu lagi',
#  'saya lelah mendengarkan cerita ayah',
#  'kalau memungkinkan saya akan kembali besok',
#  'dia sangat pintar',
#  'aku tidak tahu artinya kebencian',
#  'ini adalah semacam hewan yang tinggal di laut',
#  'seberapa tinggi kamu',
#  'kupu kupu ini langka di negara kami',
#  'jadi kamu menyerah benar',
#  'jangan khawatir',
#  'buah segar baik untuk kesehatan',
#  'para ahli mengatakan hanya sekitar persen kebahagian berasal dari pendapatan aset aset dan faktor finansial lainnya',
#  'saya punya anjing yang dapat berlari dengan cepat',
#  'semua siswa di kelasku sangat bersahabat',
#  'tom tidak pernah datang tepat waktu',
#  'keberatan anda telah dicatat',
#  'saya lapar karena saya tidak sarapan',
#  'apakah kamu pernah ke jepang',
#  'mary menolak undangan ke konser',
#  'mata uang eropa melemah terhadap dolar',
#  'pesawat ini sangat jelek',
#  'bagaimana cuaca hari ini',
#  'saya melakukannya setiap minggu pagi',
#  'halo apa kabar',
#  'kamu sudah dari dulu ingin kesana bukan',
#  'pertumbuhan bayi ini normal untuk seumurannya',
#  'dia menulis surat untuk ibunya',
#  'laki laki itu mengangkat tangan untuk bertanya',
#  'dia membuat penemuan ilmiah penting',
#  'dia meninggalkan paris akhir bulan yang lalu',
#  'dengan kata lain dia malas',
#  'dia mulai merasa sakit',
#  'ayah saya meninggal dua tahun yang lalu',
#  'program pajak presiden reagan tidak berfungsi',
#  'dapatkah saya melihat paspor anda',
#  'penglihatannya sangat buruk',
#  'mati',
#  'apa kamu mau ikut',
#  'bintang yang bersinar di atas sana adalah jupiter',
#  'burung memiliki mata yang tajam',
#  'pemain yang paling tidak berbakat akan dikeluarkan dari tim',
#  'apa yang membuat dia tetap datang ke pesta itu',
#  'bisakah kita bicara secara pribadi',
#  'kenapa tidak dicoba',
#  'mereka mengatakan bahwa dia adalah musisi ketika masih muda',
#  'kamu ingin pergi',
#  'semalam suhu di bawah derajat',
#  'dia disukai teman temannya',
#  'kamu mau pergi',
#  'dia ngotot mengatakan bahwa analisanya tepat',
#  'saya akan memberi hadiah sepeda di hari ulang tahunmu',
#  'adalah penting di usia berapapun untuk takut akan tuhan dan menghormati orang tua',
#  'kantornya dekat dengan kantor saya',
#  'apakah kamu tahu siapa duta besar inggris untuk jepang',
#  'bill sudah berhenti merokok',
#  'semua bayangan kebahagiaannya hilang begitu saja dalam waktu singkat',
#  'ketika dia kembali ke kamarnya cincin berliannya telah hilang',
#  'api telah padam dan ruangan itu menjadi dingin',
#  'lihat buku itu terbakar',
#  'dia lari menyelamatkan diri',
#  'seperti ayah seperti anak',
#  'bir lokal apa yang paling enak',
#  'berikutnya akan ditayangkan berita lokal',
#  'berat bersih dari selai ini adalah gram',
#  'dia segera menikah setelah lulus kuliah',
#  'jika anda mendaftar di facebook informasi pendaftaran akan dikirim ke agen intelejen',
#  'saya sudah lulus sekolah',
#  'akhirnya saya lulus smp',
#  'helen lulus sma tahun lalu',
#  'apa dia lulus di ujian itu',
#  'saya harus pergi ke sana demi ayah saya',
#  'uang itu mungkin akan dibagi dua dengan rata',
#  'jumlah penduduk di kota itu semakin tahun semakin berkurang',
#  'dia adalah wanita dengan kepribadian yang kuat',
#  'saya mau yang ini',
#  'saya mau yang itu',
#  'saya tidak mengerti kata itu',
#  'saya tidak mengerti kata ini',
#  'semua sekolah tutup pada hari libur itu',
#  'apa kosa kata itu',
#  'saya mau bilang kata itu',
#  'senin depan libur',
#  'makanan itu enak sekali',
#  'minuman ini sangat enak',
#  'saya guru bahasa jepang',
#  'saya benar benar suka bahasa jepang',
#  'saya mau beli kamus murah',
#  'saya tidak mengerti bahasa belanda karena sukar',
#  'saya belum bisa bicara bahasa indonesia dengan lancar',
#  'saya bisa makan yang ini',
#  'boleh saya minta bon',
#  'permisi tetapi kamu bisa bantu saya',
#  'terima kasih karena kamu tolong saya terima kasih kembali',
#  'perubahan iklim global mungkin jadi penyebab punahnya dinosaurus',
#  'anak anak kecil suka dengan buku tentang dinosaurus dan monster',
#  'dinosaurus sekarang sudah punah',
#  'tidak ada yang mengerti aku',
#  'sejauh yang saya tahu desas desus itu tidak benar',
#  'seberapa pun kerasnya dia mencoba dia tidak akan berhasil',
#  'dia menyemangati saya untuk mencoba lagi',
#  'dia punya sedikit gigi',
#  'suhu minimum hari ini °c',
#  'biayanya paling tidak yen',
#  'dia tinggal di sebelah rumah saya',
#  'setelah mendaki gunung fuji saya mendapat inspirasi menulis puisi',
#  'biarkan saya sendiri dia berkata dengan marah',
#  'dia punya anak semua jadi musisi',
#  'tidak semua buku yang di atas meja miliki saya',
#  'lelaki itu jelas mengelabui kami',
#  'bagaimana pendapat anda tentang novel barunya',
#  'kakek saya meninggal tahun yang lalu',
#  'orang itu meninggal beberapa jam yang lalu',
#  'dia mengantar koran',
#  'apa ada biaya pengiriman',
#  'rumah itu dibangun dari batu bata',
#  'saya beli buku ini untuk saya bukan untuk istri',
#  'berapa orang yang ikut bepergian',
#  'mengapa kita tidak pulang',
#  'saya pergi ke bali saat libur musim panas',
#  'john tiba di jepang kemarin',
#  'janji adalah janji',
#  'ada banyak bangunan tua yang terkenal di kyoto',
#  'saya tidak suka bunga buatan',
#  'saya menemukan satu dolar di jalan',
#  'boleh saya pergi denganmu',
#  'ada masalah yang tidak kamu lihat',
#  'dia sepertinya tidak menyadari adanya masalah antara saya dan ayah saya',
#  'dia tidak menyadari kesalahannya',
#  'sumber dari pernyataan itu saya tidak tahu',
#  'cara yang sopan untuk memberi tahu suatu fakta tanpa menyebutkan sumber informasi adalah dengan mengatakan ada kabar burung',
#  'kedua orang tuanya baik baik saja',
#  'seorang wanita yang suaminya meninggal disebut janda',
#  'arloji saya dicuri',
#  'saya staf yang paling junior di kantor saya',
#  'nasihat gratis tidak selalu nasihat yang baik',
#  'aku cinta kamu saya tidak akan mengucapkan kata semacam itu',
#  'anjing itu nampaknya sakit',
#  'gadis itu terkenal bukan karena kecantikannya tapi karena kebaikannya',
#  'anak anak belajar untuk merespon suara yang berima sejak usia kecil',
#  'silahkan ikuti saya',
#  'kami makan di restoran mahal atas dan menginap di hotel kelas atas',
#  'saya suka membaca buku cerita',
#  'saya ingin kamu baca buku ini',
#  'berikan uangmu',
#  'mudah didapat mudah hilang',
#  'jet itu telah mendarat di tokyo',
#  'dia kembali dari singapura bulan januari depan',
#  'buku ini milikmu',
#  'mereka menyelesaikan proyek itu sesuai dengan jadwal',
#  'dia gugup sebelum ujian masuk',
#  'mengapa kamu gagal di ujian masuk',
#  'dia nampaknya akan lulus pada ujian masuk itu',
#  'dia belajar keras agar dapat lulus di ujian masuk',
#  'saya sudah jelaskan padanya',
#  'panas dan terang dibutuhkan untuk eksistensi kita',
#  'keluargaku adalah keluarga besar',
#  'orang amerika adalah orang yang ramah',
#  'seperti halnya tubuh perlu olahraga pikiran juga perlu stimulasi agar tetap sehat',
#  'apa kamu tinggal dengan orangtuamu',
#  'apa kamu sedang terburu buru',
#  'kamu kelas berapa',
#  'adik perempuan saya sering menangis',
#  'para sopir itu mulai berdebat siapa yang salah dalam kecelakaan itu',
#  'mereka memandang dia seolah olah pemimpin mereka',
#  'ini masalah yang harus kamu selesaikan sendiri',
#  'sayang sekali',
#  'diam atau kamu akan dikeluarkan',
#  'dia mirip dengan ibunya',
#  'saat ini tidak ada lagi yang perlu saya kerjakan',
#  'dia menyatakan bahwa mereka telah berteman selama tahun',
#  'malam ini kemungkinan akan turun hujan',
#  'bisa saya bantu',
#  'saya juga pergi',
#  'saya menganggap diamnya mereka sebagai tanda setuju',
#  'kamu tertarik pada apa',
#  'baiklah berapa banyak',
#  'dia masih percaya pada kata katanya',
#  'tidak ada yang tahu ke mana bill pergi',
#  'mereka ingin berpisah setelah menikah tahun',
#  'nama saya hashimoto',
#  'dia belum datang dia pasti ketinggalan bis',
#  'dia mengalami sedikit kemajuan dalam bahasa inggris',
#  'wah pagi ini cepat ya',
#  'kami memperpanjang rapat sampai menit',
#  'rute bis untuk kota itu diperpanjang hingga km',
#  'silahkan memperpanjang visa',
#  'saya sudah kenyang terima kasih',
#  'lebih baik tinggal di rumah daripada pergi keluar',
#  'saya tidak tahu kenapa kamu tidak menyukainya',
#  'waktu keberangkatan telah tiba dan kami pergi sesuai jalan jalan kami saya mati dan kamu hidup mana yang lebih baik hanya tuhan yang tahu',
#  'kamu mabuk',
#  'buku ini tentang perbintangan',
#  'saya mendengar dia menyanyikan sebuah lagu',
#  'apakah kamu pernah dengar lagu itu dinyanyikan dalam bahasa perancis',
#  'apa ini milikmu',
#  'ada lebih dari negara di dunia',
#  'mawar ini sangat indah',
#  'anjing itu dibuat agar menggonggong kepada orang asing',
#  'kamu akhirnya sukses mendapatkan pekerjaan',
#  'dia orang yang tidak banyak berbicara tapi selalu menepati janjinya',
#  'kamu sebaiknya memperhatikan apa yang dia katakan',
#  'pemberi kerja kadang kadang memanfaatkan pekerjanya',
#  'saya tidak tahu pasti kapan dia tiba',
#  'kata ini diturunkan dari bahasa jerman',
#  'tidak ada mawar yang tidak berduri',
#  'anak laki laki itu melompat',
#  'kudanya melompat',
#  'anak perempuan itu melompat',
#  'anjing itu lompat',
#  'siapa yang sedang membaca',
#  'tolong panggil seseorang yang mengerti bahasa jepang',
#  'saya tidak tahu hal itu',
#  'orang inggris terbiasa untuk berdiri untuk mengantri',
#  'orang jepang dan inggris biasanya menunggu di pemberhentian bis dengan mengantri',
#  'jangan lupa untuk bertemu saya di stasiun',
#  'saya malu telah melakukan hal tersebut',
#  'harganya terlalu mahal',
#  'bagi saya tidak ada perbedaan mendasar antara kebudayaan dari kedua negara tersebut',
#  'dia membuka surat itu dengan cepat',
#  'saya sedang belajar bahasa inggris sekarang',
#  'dia memberhentikan mobil',
#  'seandainya saya tahu alamatnya',
#  'dan saya tahu kamu tidak melakukannya untuk saya',
#  'dia belajar bahasa inggris',
#  'dia lebih tinggi daripada saya',
#  'beberapa murid datang ke perpustakaan',
#  'dia berduduk di situ dengan mata tertutup',
#  'dia sengaja menginjak kaki saya di kereta',
#  'saya tidak bisa selesai membaca buku tebal ini dalam seminggu',
#  'abbot membunuh mary',
#  'dia melakukan pekerjaannya sendiri',
#  'dia jarang pergi ke gereja',
#  'mata sama tajamnya seperti lidah',
#  'kita harus memperhatikan rambu rambu lalu lintas',
#  'saya perlu seseorang untuk diajak bicara',
#  'dia seorang dokter',
#  'aku kangen kamu',
#  'saya rindu anda',
#  'beritahukan semuanya kepada saya',
#  'kemudian mereka melihat matahari terbit',
#  'tidak sia sia pergi ke pulau bali karena anda dapat melihat indahnya matahari terbit',
#  'kamu sudah membuat keputusan ke belum',
#  'ibu saya sedang membuat kue',
#  'gratis untuk masyarakat uni eropa',
#  'tetap awasi dia',
#  'kamu harus berhenti merokok',
#  'dengarkan baik baik maksud perkataan saya',
#  'rencana itu sedang didiskusikan',
#  'peter jatuh cinta dengan gadis itu',
#  'jangan lupa membalas suratnya',
#  'ini tidak mahal',
#  'dia selalu kekurangan uang',
#  'apa yang dia katakan benar benar kebohongan',
#  'anda tidak perlu kuatir dengan hal itu',
#  'di mana kamu beli baju itu',
#  'kemarin saya memberikan sambutan untuk pernikahan',
#  'kematian seorang pria yang berbakat menyedihkan saya daripada surga rasanya dunia lebih membutuhkan dia',
#  'begitu tetangga melihat john menjual narkoba dia melaporkannya ke pihak berwajib',
#  'ketika kedua gadis mengutarakan pada john mereka memiliki perasaan terhadapnya ia kebingungan kepada siapa dirinya sebaiknya berpasangan',
#  'kamu masih muda',
#  'pukulannya tidak bisa begitu jauh karena ada angin yang melawan arah',
#  'saya pemimpin regu',
#  'saya tidak memiliki kaitan dengan regu itu',
#  'bagaimana bisa tercapai simpulan seperti ini',
#  'harga saham anjlok ke titik terendah',
#  'apa ini tempat yang banyak dikunjungi di daerah ini',
#  'dulunya ia merokok tetapi sekarang tidak lagi',
#  'mereka tampak seperti akan menangis',
#  'bagi saya yang mana pun tak masalah',
#  'emi tampak seperti apa',
#  'isyarat ini sangat dikenal di kalangan muda',
#  'mari makan malam sebelum ke pertandingan baseball',
#  'saya tiba di tokyo tengah hari',
#  'ia membungkukkan badan lalu memungut batu kecil',
#  'mengemis meski hanya tiga hari akan menjadi kebiasaan',
#  'saya tidak tahu cara membeli tiket',
#  'ia meminta supaya gajinya dinaikkan lagi',
#  'ia benar benar punya selera humor yang rendah',
#  'diantara yang lainnya ia yang paling jago berenang',
#  'harga beras diatur pemerintah',
#  'tolong beritahu cara penulisan nama anda',
#  'kamu tak akan bisa menyelesaikan tanpa kamus yang bagus',
#  'bagus jika kamu memiliki satu diantara dua buku itu',
#  'setelah tidur nyenyak perasaan menjadi enteng',
#  'saya bertanggung jawab atas kegagalan anak saya',
#  'ia menangis tanpa henti',
#  'hanya wanita yang diperbolehkan sebagai pelamar',
#  'ia mandiri secara ekonomi dari orang tuanya',
#  'anda ingin memesan apa',
#  'kereta itu akan melintasi stasiun motomachi',
#  'jumlahnya mencapai lebih dari yen',
#  'begitu mencoba menanggalkan posisi di angkatan laut ia merasa kesulitan beradaptasi dengan kehidupan di daratan',
#  'pengambilan sampah dilakukan tiga kali sepekan',
#  'saya lahir di osaka pada tahun',
#  'bayar pajak nggak salah tuh',
#  'sejuk di bawah pohon',
#  'mobil ini mogok',
#  'jangan dekati anjing itu',
#  'bagaimana anda bisa saling kenal',
#  'jangan merokok bertenggang rasalah dengan yang lainnya',
#  'faktanya manusia tak bisa hidup tanpa tidur',
#  'saya selalu ada simpati begitu melihat dirinya',
#  'mengunjungi benteng itu adalah pengalaman yang bernilai',
#  'aku tidak menyukai alice',
#  'cepatlah berangkat ia berujar padaku',
#  'hujan terus turun sejak ahad',
#  'lompatlah setinggi mungkin',
#  'baik kata orang itu saya tidak percaya tetapi tidak ada salahnya berharap saya berharap saya tahu siapa saya',
#  'kamu menganggap saya orang tolol menganggapmu orang tolol saya tidak pernah melakukannya',
#  'besok pagi tolong bangunkan saya pukul pagi',
#  'baru kemarin saya tahu hal tersebut',
#  'mengapa kamu menginginkan mobil tua itu',
#  'kita tidak bisa pergi karena badai',
#  'kita teman sekelas',
#  'coba lebih baik lagi lain kali',
#  'ayah saya sangat tertarik dengan sejarah purbakala',
#  'bersiap',
#  'adalah tidak mungkin untuk kembali ke masa lalu',
#  'saya sangat suka kue yang manis',
#  'saya kehabisan uang',
#  'pak smith senang dengan keberhasilan anaknya',
#  'saya bertemu dengannya kemarin',
#  'saya harus memecatmu bila sering terlambat datang',
#  'hirosi sedang memotong kayu menjadi papan papan',
#  'kamu membutuhkan sedikit keberanian untuk menyatakan cinta padanya',
#  'cepat tom',
#  'dia mengambil pelajaran piano seminggu sekali',
#  'saya khawatir akan kesehatanmu',
#  'mari naik kereta bawah tanah',
#  'saya kenyang',
#  'omong omong malam ini ada waktu',
#  'dari awal uangnya tidak cukup untuk mendirikan toko pangan',
#  'dia belum datang juga dia pasti ketinggalan bis',
#  'masalah ini bermula dari kesalahpahaman',
#  'saya kehilangan kepercayaan padanya',
#  'dia berhasil dalam ujian itu',
#  'dia sekarang menulis sebuah buku',
#  'perjalanan jauh melelahkan saya',
#  'saya akan mengambil jemuran sebelum hujan',
#  'kita datang tanggal di pagi hari',
#  'kamu harus belajar bahasa jepang lebih giat',
#  'saya sering bertemu pak sasaki di stasiun',
#  'mengerti kamu harus belajar bahasa asing',
#  'rata rata perawat mendapat cuti minggu dalam setahun',
#  'ia ingin menjadi insinyur',
#  'katakan padanya untuk tidak ikut campur',
#  'sistem ekonomi syariah hingga kini belum dipraktekkan di kalangan pesantren',
#  'sayangnya banyak umat islam yang tak menyadari mengapa ia beragama islam banyak muslim yang menjadi muslim hanya karena orang tua mereka muslim',
#  'tni angkatan laut dan angkatan laut korea selatan rokn sepakat kerja sama penanganan perompakan dan pembajakan serta beragam kejahatan di laut lainnya',
#  'aneh kata nenek tua seraya mengabulkan permintaannya dan menghilang selamanya itu adalah permintaan pertamamu',
#  'gempa bisa terjadi kapan saja',
#  'sangat kecil kemungkinan tom akan memenangkan pemilihan',
#  'seandainya dia satu tim dengan kita',
#  'apakah ada ukuran yang lebih kecil',
#  'tampaknya dia berubah pikiran',
#  'dia kurang cocok menjadi guru',
#  'dia menyuruh sekretaris untuk menterjemahkan surat itu ke dalam bahasa inggris',
#  'dia pandai berbahasa inggris dan perancis',
#  'sangat sulit untuk berhenti merokok',
#  'minum obat ini setiap jam',
#  'orang cina suka bekerja keras',
#  'dia menjadi pelupa dan hal itu mengkhawatirkannya',
#  'toko ini buka sepanjang tahun',
#  'itulah yang saya ingin tahu',
#  'saya jamin jam ini tidak meleset',
#  'kamu bisa menebak apa yang terjadi',
#  'dia selalu di sini antara pukul dan',
#  'tahukah kamu tentang kakaknya',
#  'sungai itu meluap dengan cepat karena hujan deras',
#  'saya perlu obat untuk mengurangi rasa sakit',
#  'saya tinggal di sini sejak lama',
#  'saya akan tinggal di sini selama seminggu',
#  'saya tidak bisa mendengar cerita semacam itu tanpa menangis',
#  'saya belum mendengar kabar darinya',
#  'ada panjang gelombang cahaya yang tak terlihat oleh mata manusia',
#  'dia sering tampil di tv',
#  'bis ini akan membawamu keliling kota',
#  'tom lahir di mana',
#  'pernahkan kamu melihat patung liberty',
#  'ke manapun kau pergi aku ikut',
#  'saya merasa buruk',
#  'permisi apa waktu itu',
#  'aku mau mati bersama getter jaani',
#  'saya percaya pada kylie minogue sejak juni',
#  'ini alamat e mail saya',
#  'selamat',
#  'mary adalah yang paling malas diantara teman teman sekolahnya',
#  'adalah perlu untuk mencintai ibu',
#  'lebih baik untuk saya tidak pergi',
#  'saya kehilangan dompet saya',
#  'cinta ialah suatu penipuan',
#  'beritahu saya kenapa dia menangis',
#  'saya bangun pada pukul lima pagi',
#  'aoi menari',
#  'dia dipercayai tidak bersalah',
#  'tikus itu diperangkap ke dalam jebakan dengan potongan keju besar',
#  'apa kepanjangan dari ussr',
#  'taksi itu menunggu di luar',
#  'berapa lama waktu yang dibutuhkan',
#  'itu nampak seperti telor',
#  'saya memperhatikan bahwa seekor binatang kecil sedang melihat ke arah kita',
#  'aku tak dapat hidup tanpamu',
#  'tatoeba dalam bahasa jepang berarti contohnya',
#  'kita tidak dapat lepas dari masa lalu',
#  'maaf jam berapa sekarang',
#  'ya sepertinya ada salah diagnosa',
#  'urusi urusanmu sendiri',
#  'saya tidak paham dengan perkataanmu',
#  'pidatomu jauh dari memuaskan',
#  'saya tidak dapat berpikir bahwa ceritamu benar',
#  'apakah orang tuamu setuju kamu menjadi pramugari',
#  'tolong ceritakan saya akan benar benar mendengarkan',
#  'lanjutkan ceritanya benar benar menarik',
#  'tidakkah kamu merasa malu mengatakan seperti itu',
#  'kamu seharusnya malu dengan tingkah laku kamu itu',
#  'seharusnya kamu tak perlu merasa malu',
#  'aku malu pada diriku sendiri',
#  'cintai teman kelasmu cintai kedua orang tuamu cintai tanah airmu',
#  'cinta mencintai cinta',
#  'bagaimana cinta dapat mencintai cinta',
#  'jauh dimata dekat dihati',
#  'mata dibalas mata gigi dibalas gigi',
#  'mata adalah cermin dari jiwa',
#  'dia buta karena memiliki satu mata',
#  'sebelah matanya buta',
#  'cermin hati adalah mata',
#  'mata adalah cermin hati',
#  'mata adalah jendela hati',
#  'terlalu mahal',
#  'malu bertanya sesat di jalan',
#  'kemanapun kamu menghadap disitu wajah tuhan',
#  'keiko memberitahu aku tentang kedatangan pesawatnya',
#  'kabar beritaku tak begitu penting bagi orang yang tidak ingin tahu',
#  'kalau aku pergi berlibur aku akan menyewa mobil',
#  'jembatan golden gate terbuat dari besi',
#  'tidak semua kertas kecil adalah cek',
#  'kesehatan lebih penting dibanding emas',
#  'apa yang keluar dari hati datang ke hati',
#  'hatiku penuh dengan kebahagiaan',
#  'siapakah mona lisa',
#  'mona lisa mungkin adalah lukisan paling terkenal yang pernah dibuat',
#  'mona lisa dilukis oleh leonardo da vinci',
#  'ken mengkoleksi uang uang kuno',
#  'saya sedang menulis surat',
#  'dia membelikan aku sebuah mainan kecil',
#  'saya harus melakukan sesuatu',
#  'luas ya',
#  'apakah kamu ingat apa yang dia katakan',
#  'ibuku setiap hari sibuk sekali',
#  'dia tidak mempunyai keberanian untuk mengatakan kebenaran',
#  'apa kabar kabar saya baik terima kasih',
#  'hai nama saya josé silva siapa nama anda',
#  'michael adalah nama saya tetapi michelle adalah nama wanita',
#  'nama keluarga saya adalah wang',
#  'kemanapun saya pergi apapun yang saya lakukan dia selalu menjagaku',
#  'apakah anda percaya pada tuhan',
#  'ia menatapku dengan mata membelalak',
#  'apakah anda percaya pada tuhan',
#  'tiada tuhan selain allah dan muhammad adalah utusan allah',
#  'dia yang memiliki cinta berada ditangan tuhan dan tuhan berada ditangannya untuk tuhan adalah cinta',
#  'ini sebuah buku yang menarik bukan',
#  'mencintai kehidupan adalah mencintai tuhan',
#  'dia bertanya bagaimana cara memasak ikan',
#  'mendapatkan saat kebahagiaan mencintai dan dicintai ini adalah realitas hanya di dunia semua lainnya adalah kebodohan ini satu satunya hal yang menjadi perhatian kita di sini',
#  'saya sangat khawatir dengan penyakit yang dideritanya',
#  'tolong dengar apa yang kami katakan',
#  'babi itu bertambah gemuk',
#  'sungai shinano paling panjang dibandingkan sungai lainnya di jepang',
#  'ia memiliki wajah bulat',
#  'sebagaimana tuhan shinto ada dewi matahari tuhan bulan dan bahkan pohon pohon tua memiliki tuhannya',
#  'saya kemarin di bus tidak sengaja bertemu dengan kawan lama',
#  'yang kamu katakan itu tidak masuk akal',
#  'selamat siang',
#  'manusia ditakdirkan untuk menderita',
#  'stroberi sekarang ini sedang musim',
#  'ia tidak mungkin mengatakan hal itu',
#  'magdalena dan ania adalah teman baik',
#  'saya bertanggung jawab atas perbuatan saya sendiri',
#  'datanglah ke rumah kapanpun kamu suka',
#  'cahaya itu akan terlihat jika aku terus berlari',
#  'masih ada cukup waktu',
#  'kecelakaan itu terjadi pada hari minggu sekitar pukul',
#  'jalan ini menuju arah mana',
#  'akan pergi kemanakah anda hari minggu besok',
#  'polisi itu mengejarmu',
#  'tak seorangpun tahu kemana dia melarikan diri',
#  'dia bisa berbicara empat bahasa',
#  'karena terluka dia memutuskan untuk kembali ke amerika',
#  'ayah menceritakan padaku pengalaman pengalamannya selama masa perang',
#  'dia terpilih menjadi anggota tim',
#  'jamnya terlambat sepuluh menit',
#  'siapakah pria itu',
#  'john mewakili kelasnya di perlombaan renang',
#  'hari ini lebih berawan dari kemarin',
#  'waktu berlalu begitu cepat',
#  ...]
