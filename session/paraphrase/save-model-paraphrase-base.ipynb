# %%
import os

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'mesolitica-storage.json'

# %%
from google.cloud import storage
client = storage.Client()
bucket = client.bucket('mesolitica-general')

# %%
# !mkdir t5-base-paraphrase
# Out:
# mkdir: cannot create directory ‘t5-base-paraphrase’: File exists

# %%
# !rm t5-base-paraphrase/*

# model = '513100'

# blob = bucket.blob(f't5-base-paraphrase-v1/model.ckpt-{model}.data-00000-of-00002')
# blob.download_to_filename(f't5-base-paraphrase/model.ckpt-{model}.data-00000-of-00002')

# blob = bucket.blob(f't5-base-paraphrase-v1/model.ckpt-{model}.data-00001-of-00002')
# blob.download_to_filename(f't5-base-paraphrase/model.ckpt-{model}.data-00001-of-00002')

# blob = bucket.blob(f't5-base-paraphrase-v1/model.ckpt-{model}.index')
# blob.download_to_filename(f't5-base-paraphrase/model.ckpt-{model}.index')

# blob = bucket.blob(f't5-base-paraphrase-v1/model.ckpt-{model}.meta')
# blob.download_to_filename(f't5-base-paraphrase/model.ckpt-{model}.meta')

# blob = bucket.blob('t5-base-paraphrase-v1/checkpoint')
# blob.download_to_filename('t5-base-paraphrase/checkpoint')

# blob = bucket.blob('t5-base-paraphrase-v1/operative_config.gin')
# blob.download_to_filename('t5-base-paraphrase/operative_config.gin')

# with open('t5-base-paraphrase/checkpoint', 'w') as fopen:
#     fopen.write(f'model_checkpoint_path: "model.ckpt-{model}"')

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = ''

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import t5

# %%
model = t5.models.MtfModel(
    model_dir='t5-base-paraphrase',
    tpu=None,
    tpu_topology=None,
    model_parallelism=2,
    batch_size=1,
    sequence_length={"inputs": 1024, "targets": 1024},
    learning_rate_schedule=0.003,
    save_checkpoints_steps=5000,
    keep_checkpoint_max=3,
    iterations_per_loop=100,
    mesh_shape="model:1,batch:1", 
    mesh_devices=["cpu:0"]
)

# %%
string = "Beliau yang juga saksi pendakwaan kesembilan berkata, ia bagi mengelak daripada wujud isu digunakan terhadap Najib."

# %%
print(string)
with tf.io.gfile.GFile('test.txt', "w") as f:
    f.write("parafrasa: %s\n" % string)
# Out:
# Beliau yang juga saksi pendakwaan kesembilan berkata, ia bagi mengelak daripada wujud isu digunakan terhadap Najib.

# %%
# !rm out.txt*

# %%
model.predict(
    input_file='test.txt',
    output_file='out.txt',
    temperature=0.5,
    beam_size=1,
    sentencepiece_model_path='sp10m.cased.t5.model'
)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 't5-base-paraphrase', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# isolate_session_state: true
# ...

# %%
# !rm -rf output/*

# %%
model.batch_size = 1
saved_model_path = model.export(
    'output',
    checkpoint_step=-1,
    beam_size=1,
    temperature=0.5,
    sentencepiece_model_path='sp10m.cased.t5.model'
)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 't5-base-paraphrase', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# isolate_session_state: true
# ...

# %%
saved_model_path.decode()
# Out:
# 'output/1592019111'

# %%
import tensorflow_text  

tf.compat.v1.reset_default_graph()
sess = tf.InteractiveSession()
meta_graph_def = tf.compat.v1.saved_model.load(sess, ["serve"], saved_model_path.decode())
signature_def = meta_graph_def.signature_def["serving_default"]
pred = lambda x: sess.run(
    fetches=signature_def.outputs["outputs"].name, 
    feed_dict={signature_def.inputs["input"].name: x}
)
# Out:
# WARNING:tensorflow:From <ipython-input-15-721f360137e2>:5: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# INFO:tensorflow:Restoring parameters from output/1592019111/variables/variables

# %%
# !rm -rf model

# %%
os.system(f'mv {saved_model_path.decode()} model')
# Out:
# 0

# %%
# !tar -czvf paraphrase-t5-base.tar.gz model
# Out:
# model/
# model/saved_model.pb
# model/variables/
# model/variables/variables.data-00000-of-00002
# model/variables/variables.data-00001-of-00002
# model/variables/variables.index
