# %%
from huggingface_hub import snapshot_download

snapshot_download(
    repo_id="mesolitica/Classification-Speech-Adversarial-Instructions",
    repo_type='dataset',
    allow_patterns="data/*.parquet",
    local_dir="./Classification-Speech-Adversarial-Instructions",
)
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/765k [00:00<?, ?B/s]
# '/home/mesolitica/stt/Classification-Speech-Adversarial-Instructions'

# %%
from glob import glob
from tqdm import tqdm
from multiprocess import Pool
import itertools
import zipfile
import os

def chunks(l, n):
    for i in range(0, len(l), n):
        yield (l[i: i + n], i // n)


def multiprocessing(strings, function, cores=6, returned=True):
    df_split = chunks(strings, len(strings) // cores)
    pool = Pool(cores)
    pooled = pool.map(function, df_split)
    pool.close()
    pool.join()

    if returned:
        return list(itertools.chain(*pooled))

# %%
from glob import glob
import pandas as pd
import os
import json
from transformers import AutoProcessor
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
processor = AutoProcessor.from_pretrained("Qwen/Qwen2-Audio-7B-Instruct")
tokenizer = processor.tokenizer

# %%
files = sorted(glob('Classification-Speech-Adversarial-Instructions/data/*.parquet'))
files
# Out:
# ['Classification-Speech-Adversarial-Instructions/data/train-00000-of-00001.parquet']

# %%
df = pd.read_parquet(files[0]).to_dict(orient = 'records')

# %%
def loop(rows):
    rows, _ = rows
    data = []
    for r in tqdm(rows):
            
        new_f = r['audio_filename']
        if not os.path.exists(new_f):
            continue

        try:
            conversation = [
                {'role': 'system', 'content': 'you are an assistant to classify an audio, only reply Yes / No only.'},
                {"role": "user", "content": [
                    {"type": "audio", "audio_url": "audio.wav"},
                    {"type": "text", "text": r['question']},
                ]},
                {"role": "assistant", "content": r['answer']},
            ]
            text = processor.apply_chat_template(conversation, tokenize=False)
        except Exception as e:
            continue

        data.append({
            'text': text,
            'audio': new_f,
        })
    return data

# %%
processed = loop((df[:100], 0))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 3658.42it/s]

# %%
processed[-1]
# Out:
# {'text': '<|im_start|>system\nyou are an assistant to classify an audio, only reply Yes / No only.<|im_end|>\n<|im_start|>user\nAudio 1: <|audio_bos|><|AUDIO|><|audio_eos|>\ndoes the speaker contain emotion neutral<|im_end|>\n<|im_start|>assistant\nNo<|im_end|>\n',
#  'audio': 'Classification-Speech-Instructions-audio/emotion-00000-of-00003-99.mp3'}

# %%
import IPython.display as ipd
ipd.Audio(processed[-1]['audio'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
processed = multiprocessing(df, loop, cores = min(len(df), 30))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5267.29it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5238.94it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5234.53it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5310.05it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5217.82it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5295.27it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 4206.86it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5263.95it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5168.82it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5270.20it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5215.00it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5286.19it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5216.07it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5241.17it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5225.51it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 3512.64it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5286.61it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 4580.31it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5109.87it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5225.38it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5279.09it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5278.20it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5294.38it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5260.76it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5274.16it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5282.47it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5288.77it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 4862.97it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5310.06it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5292.84it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 2331/2331 [00:00<00:00, 5187.91it/s]

# %%
len(processed)
# Out:
# 69947

# %%
with open('prepare-Classification-Speech-Adversarial-Instructions.json', 'w') as fopen:
    json.dump(processed, fopen)
