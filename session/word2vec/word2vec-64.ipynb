# %%
import word2vec
import numpy as np
import tensorflow as tf
import json
import os
os.environ['CUDA_VISIBLE_DEVICES'] = ''
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
with open('news-bm.json','r') as fopen:
    sentences = json.loads(fopen.read())

# %%
word_array, dictionary, rev_dictionary, num_lines, num_words = word2vec.build_word_array(sentences,vocab_size=50000)

# %%
X, Y = word2vec.build_training_set(word_array)
graph_params = {'batch_size': 32,
                'vocab_size': np.max(X)+1,
                'embed_size': 64,
                'hid_size': 64,
                'neg_samples': 128,
                'learn_rate': 0.01,
                'momentum': 0.9,
                'embed_noise': 0.1,
                'hid_noise': 0.3,
                'epoch':500,
                'optimizer': 'Momentum'}

# %%
split = round(X.shape[0]*0.9)
X_val, Y_val = (X[split:, :], Y[split:, :])

# %%
model = word2vec.Model(graph_params)
print('model built, vocab size %d, document length %d'%(np.max(X)+1, len(word_array)))
# Out:
# model built, vocab size 33735, document length 1211339

# %%
embed_weights, nce_weights = model.train(X, Y, X_val, Y_val,
                                         graph_params['epoch'],
                                         graph_params['batch_size'])
# Out:
# epoch 1, total batch 37854, train loss 27.775017, val loss 7.406361
# epoch 2, total batch 41639, train loss 7.528040, val loss 7.344817
# epoch 3, total batch 45424, train loss 7.458973, val loss 7.283543
# epoch 4, total batch 49209, train loss 7.410847, val loss 7.231106
# epoch 5, total batch 52994, train loss 7.341531, val loss 7.166517
# epoch 6, total batch 56779, train loss 7.292459, val loss 7.129110
# epoch 7, total batch 60564, train loss 7.242589, val loss 7.074622
# epoch 8, total batch 64349, train loss 7.183248, val loss 7.042345
# epoch 9, total batch 68134, train loss 7.153751, val loss 7.009714
# epoch 10, total batch 71919, train loss 7.097043, val loss 6.966605
# epoch 11, total batch 75704, train loss 7.077203, val loss 6.934313
# epoch 12, total batch 79489, train loss 7.025670, val loss 6.903539
# epoch 13, total batch 83274, train loss 7.011487, val loss 6.871939
# epoch 14, total batch 87059, train loss 6.947018, val loss 6.834058
# epoch 15, total batch 90844, train loss 6.901513, val loss 6.744246
# epoch 16, total batch 94629, train loss 6.739558, val loss 6.542551
# epoch 17, total batch 98414, train loss 6.537875, val loss 6.339016
# epoch 18, total batch 102199, train loss 6.290569, val loss 6.117075
# epoch 19, total batch 105984, train loss 6.082273, val loss 5.924623
# epoch 20, total batch 109769, train loss 5.900564, val loss 5.748482
# epoch 21, total batch 113554, train loss 5.702888, val loss 5.582890
# epoch 22, total batch 117339, train loss 5.526835, val loss 5.430567
# epoch 23, total batch 121124, train loss 5.383767, val loss 5.302560
# epoch 24, total batch 124909, train loss 5.249413, val loss 5.198275
# epoch 25, total batch 128694, train loss 5.147354, val loss 5.099083
# epoch 26, total batch 132479, train loss 5.053355, val loss 5.020289
# epoch 27, total batch 136264, train loss 4.959749, val loss 4.944946
# epoch 28, total batch 140049, train loss 4.877103, val loss 4.878649
# epoch 29, total batch 143834, train loss 4.811850, val loss 4.804190
# epoch 30, total batch 147619, train loss 4.737291, val loss 4.730936
# epoch 31, total batch 151404, train loss 4.683357, val loss 4.664904
# epoch 32, total batch 155189, train loss 4.620344, val loss 4.605449
# epoch 33, total batch 158974, train loss 4.567793, val loss 4.564846
# epoch 34, total batch 162759, train loss 4.512658, val loss 4.513616
# epoch 35, total batch 166544, train loss 4.477588, val loss 4.456373
# epoch 36, total batch 170329, train loss 4.421095, val loss 4.419668
# epoch 37, total batch 174114, train loss 4.372306, val loss 4.371694
# epoch 38, total batch 177899, train loss 4.326263, val loss 4.331458
# epoch 39, total batch 181684, train loss 4.297860, val loss 4.296829
# epoch 40, total batch 185469, train loss 4.251107, val loss 4.262014
# epoch 41, total batch 189254, train loss 4.219775, val loss 4.213550
# epoch 42, total batch 193039, train loss 4.189628, val loss 4.189668
# epoch 43, total batch 196824, train loss 4.149686, val loss 4.155839
# epoch 44, total batch 200609, train loss 4.109980, val loss 4.118297
# epoch 45, total batch 204394, train loss 4.091004, val loss 4.097470
# epoch 46, total batch 208179, train loss 4.061116, val loss 4.076778
# epoch 47, total batch 211964, train loss 4.031376, val loss 4.040392
# epoch 48, total batch 215749, train loss 4.001619, val loss 4.017734
# epoch 49, total batch 219534, train loss 3.991657, val loss 3.988282
# epoch 50, total batch 223319, train loss 3.965285, val loss 3.957411
# epoch 51, total batch 227104, train loss 3.928788, val loss 3.946465
# epoch 52, total batch 230889, train loss 3.911156, val loss 3.918848
# epoch 53, total batch 234674, train loss 3.879270, val loss 3.908158
# epoch 54, total batch 238459, train loss 3.867347, val loss 3.883300
# epoch 55, total batch 242244, train loss 3.843622, val loss 3.856874
# epoch 56, total batch 246029, train loss 3.812564, val loss 3.839768
# epoch 57, total batch 249814, train loss 3.802893, val loss 3.824840
# epoch 58, total batch 253599, train loss 3.799165, val loss 3.801520
# epoch 59, total batch 257384, train loss 3.766020, val loss 3.783563
# epoch 60, total batch 261169, train loss 3.743674, val loss 3.769042
# epoch 61, total batch 264954, train loss 3.719424, val loss 3.761347
# epoch 62, total batch 268739, train loss 3.722242, val loss 3.732553
# epoch 63, total batch 272524, train loss 3.705648, val loss 3.724613
# epoch 64, total batch 276309, train loss 3.672898, val loss 3.708498
# epoch 65, total batch 280094, train loss 3.670154, val loss 3.693628
# epoch 66, total batch 283879, train loss 3.641141, val loss 3.688612
# epoch 67, total batch 287664, train loss 3.638420, val loss 3.668282
# epoch 68, total batch 291449, train loss 3.609801, val loss 3.654187
# epoch 69, total batch 295234, train loss 3.595176, val loss 3.632521
# epoch 70, total batch 299019, train loss 3.591582, val loss 3.624643
# epoch 71, total batch 302804, train loss 3.573551, val loss 3.611596
# epoch 72, total batch 306589, train loss 3.579102, val loss 3.597483
# epoch 73, total batch 310374, train loss 3.547519, val loss 3.587356
# epoch 74, total batch 314159, train loss 3.532054, val loss 3.577115
# epoch 75, total batch 317944, train loss 3.518689, val loss 3.561620
# epoch 76, total batch 321729, train loss 3.516475, val loss 3.550208
# epoch 77, total batch 325514, train loss 3.508200, val loss 3.556631
# epoch 78, total batch 329299, train loss 3.499231, val loss 3.531869
# epoch 79, total batch 333084, train loss 3.483134, val loss 3.521231
# epoch 80, total batch 336869, train loss 3.475706, val loss 3.513382
# epoch 81, total batch 340654, train loss 3.460254, val loss 3.501355
# epoch 82, total batch 344439, train loss 3.442566, val loss 3.489701
# epoch 83, total batch 348224, train loss 3.441046, val loss 3.480108
# epoch 84, total batch 352009, train loss 3.428816, val loss 3.471513
# epoch 85, total batch 355794, train loss 3.409424, val loss 3.464318
# epoch 86, total batch 359579, train loss 3.413542, val loss 3.459156
# epoch 87, total batch 363364, train loss 3.397869, val loss 3.446854
# epoch 88, total batch 367149, train loss 3.389008, val loss 3.441898
# epoch 89, total batch 370934, train loss 3.375473, val loss 3.430010
# epoch 90, total batch 374719, train loss 3.374867, val loss 3.422127
# epoch 91, total batch 378504, train loss 3.364153, val loss 3.419424
# epoch 92, total batch 382289, train loss 3.362538, val loss 3.403819
# epoch 93, total batch 386074, train loss 3.356891, val loss 3.390968
# epoch 94, total batch 389859, train loss 3.344369, val loss 3.384850
# epoch 95, total batch 393644, train loss 3.326092, val loss 3.381312
# epoch 96, total batch 397429, train loss 3.326705, val loss 3.370306
# epoch 97, total batch 401214, train loss 3.307708, val loss 3.367412
# epoch 98, total batch 404999, train loss 3.313149, val loss 3.360298
# epoch 99, total batch 408784, train loss 3.300674, val loss 3.351824
# epoch 100, total batch 412569, train loss 3.289067, val loss 3.346829
# epoch 101, total batch 416354, train loss 3.289986, val loss 3.346148
# epoch 102, total batch 420139, train loss 3.270350, val loss 3.329344
# epoch 103, total batch 423924, train loss 3.268256, val loss 3.330038
# epoch 104, total batch 427709, train loss 3.265218, val loss 3.316732
# epoch 105, total batch 431494, train loss 3.245476, val loss 3.318956
# epoch 106, total batch 435279, train loss 3.256270, val loss 3.306775
# epoch 107, total batch 439064, train loss 3.246297, val loss 3.301858
# epoch 108, total batch 442849, train loss 3.236467, val loss 3.291148
# epoch 109, total batch 446634, train loss 3.227268, val loss 3.283912
# epoch 110, total batch 450419, train loss 3.228327, val loss 3.275371
# epoch 111, total batch 454204, train loss 3.215319, val loss 3.268026
# epoch 112, total batch 457989, train loss 3.208777, val loss 3.271782
# epoch 113, total batch 461774, train loss 3.196817, val loss 3.252379
# epoch 114, total batch 465559, train loss 3.205755, val loss 3.255265
# epoch 115, total batch 469344, train loss 3.185396, val loss 3.243002
# epoch 116, total batch 473129, train loss 3.189457, val loss 3.233929
# epoch 117, total batch 476914, train loss 3.177662, val loss 3.235833
# epoch 118, total batch 480699, train loss 3.165812, val loss 3.231130
# epoch 119, total batch 484484, train loss 3.163656, val loss 3.227587
# epoch 120, total batch 488269, train loss 3.168986, val loss 3.224645
# epoch 121, total batch 492054, train loss 3.162571, val loss 3.215884
# epoch 122, total batch 495839, train loss 3.143522, val loss 3.211528
# epoch 123, total batch 499624, train loss 3.144404, val loss 3.198927
# epoch 124, total batch 503409, train loss 3.133033, val loss 3.205785
# epoch 125, total batch 507194, train loss 3.139104, val loss 3.197602
# epoch 126, total batch 510979, train loss 3.120154, val loss 3.187375
# epoch 127, total batch 514764, train loss 3.116951, val loss 3.183427
# epoch 128, total batch 518549, train loss 3.121773, val loss 3.179230
# epoch 129, total batch 522334, train loss 3.109184, val loss 3.176414
# epoch 130, total batch 526119, train loss 3.093776, val loss 3.168834
# epoch 131, total batch 529904, train loss 3.107713, val loss 3.166140
# epoch 132, total batch 533689, train loss 3.095188, val loss 3.161166
# epoch 133, total batch 537474, train loss 3.087890, val loss 3.161793
# epoch 134, total batch 541259, train loss 3.103570, val loss 3.150471
# epoch 135, total batch 545044, train loss 3.076543, val loss 3.145565
# epoch 136, total batch 548829, train loss 3.070626, val loss 3.143993
# epoch 137, total batch 552614, train loss 3.066606, val loss 3.137566
# epoch 138, total batch 556399, train loss 3.066686, val loss 3.134999
# epoch 139, total batch 560184, train loss 3.064294, val loss 3.128781
# epoch 140, total batch 563969, train loss 3.060976, val loss 3.125804
# epoch 141, total batch 567754, train loss 3.050348, val loss 3.119668
# epoch 142, total batch 571539, train loss 3.047945, val loss 3.119518
# epoch 143, total batch 575324, train loss 3.051413, val loss 3.110692
# epoch 144, total batch 579109, train loss 3.035970, val loss 3.113204
# epoch 145, total batch 582894, train loss 3.039098, val loss 3.105767
# epoch 146, total batch 586679, train loss 3.017587, val loss 3.102683
# epoch 147, total batch 590464, train loss 3.024433, val loss 3.100415
# epoch 148, total batch 594249, train loss 3.021607, val loss 3.091923
# epoch 149, total batch 598034, train loss 3.018904, val loss 3.090831
# epoch 150, total batch 601819, train loss 3.013325, val loss 3.084458
# epoch 151, total batch 605604, train loss 2.996652, val loss 3.083178
# epoch 152, total batch 609389, train loss 3.010919, val loss 3.075353
# epoch 153, total batch 613174, train loss 2.999264, val loss 3.073824
# epoch 154, total batch 616959, train loss 2.991051, val loss 3.073381
# epoch 155, total batch 620744, train loss 2.993455, val loss 3.062692
# epoch 156, total batch 624529, train loss 2.995550, val loss 3.063593
# epoch 157, total batch 628314, train loss 2.984241, val loss 3.061036
# epoch 158, total batch 632099, train loss 2.984509, val loss 3.053647
# epoch 159, total batch 635884, train loss 2.968184, val loss 3.057279
# epoch 160, total batch 639669, train loss 2.965628, val loss 3.052766
# epoch 161, total batch 643454, train loss 2.972923, val loss 3.037952
# epoch 162, total batch 647239, train loss 2.967552, val loss 3.039644
# epoch 163, total batch 651024, train loss 2.954352, val loss 3.038171
# epoch 164, total batch 654809, train loss 2.954178, val loss 3.034925
# epoch 165, total batch 658594, train loss 2.950975, val loss 3.032503
# epoch 166, total batch 662379, train loss 2.949388, val loss 3.024632
# epoch 167, total batch 666164, train loss 2.946628, val loss 3.025392
# epoch 168, total batch 669949, train loss 2.943127, val loss 3.017151
# epoch 169, total batch 673734, train loss 2.941977, val loss 3.018972
# epoch 170, total batch 677519, train loss 2.939467, val loss 3.010739
# epoch 171, total batch 681304, train loss 2.927313, val loss 3.012659
# epoch 172, total batch 685089, train loss 2.938445, val loss 3.006892
# epoch 173, total batch 688874, train loss 2.926492, val loss 3.004750
# epoch 174, total batch 692659, train loss 2.931538, val loss 3.002790
# epoch 175, total batch 696444, train loss 2.925329, val loss 2.996250
# epoch 176, total batch 700229, train loss 2.923318, val loss 2.997626
# epoch 177, total batch 704014, train loss 2.905946, val loss 2.992471
# epoch 178, total batch 707799, train loss 2.919063, val loss 2.997092
# epoch 179, total batch 711584, train loss 2.909164, val loss 2.993108
# epoch 180, total batch 715369, train loss 2.906344, val loss 2.984288
# epoch 181, total batch 719154, train loss 2.910996, val loss 2.977644
# epoch 182, total batch 722939, train loss 2.892170, val loss 2.978001
# epoch 183, total batch 726724, train loss 2.894100, val loss 2.976267
# epoch 184, total batch 730509, train loss 2.882501, val loss 2.973827
# epoch 185, total batch 734294, train loss 2.884889, val loss 2.968861
# epoch 186, total batch 738079, train loss 2.884404, val loss 2.969775
# epoch 187, total batch 741864, train loss 2.883085, val loss 2.965450
# epoch 188, total batch 745649, train loss 2.883854, val loss 2.962723
# epoch 189, total batch 749434, train loss 2.870193, val loss 2.952248
# epoch 190, total batch 753219, train loss 2.867366, val loss 2.958908
# epoch 191, total batch 757004, train loss 2.875414, val loss 2.951093
# epoch 192, total batch 760789, train loss 2.864072, val loss 2.949069
# epoch 193, total batch 764574, train loss 2.863791, val loss 2.945074
# epoch 194, total batch 768359, train loss 2.852881, val loss 2.937153
# epoch 195, total batch 772144, train loss 2.858757, val loss 2.948886
# epoch 196, total batch 775929, train loss 2.866850, val loss 2.942039
# epoch 197, total batch 779714, train loss 2.853546, val loss 2.941876
# epoch 198, total batch 783499, train loss 2.838118, val loss 2.941347
# epoch 199, total batch 787284, train loss 2.840546, val loss 2.930053
# epoch 200, total batch 791069, train loss 2.838760, val loss 2.933834
# epoch 201, total batch 794854, train loss 2.845992, val loss 2.925093
# epoch 202, total batch 798639, train loss 2.830299, val loss 2.921184
# epoch 203, total batch 802424, train loss 2.842137, val loss 2.925776
# epoch 204, total batch 806209, train loss 2.833340, val loss 2.913907
# epoch 205, total batch 809994, train loss 2.839108, val loss 2.918320
# epoch 206, total batch 813779, train loss 2.816015, val loss 2.916356
# epoch 207, total batch 817564, train loss 2.818835, val loss 2.910277
# epoch 208, total batch 821349, train loss 2.823287, val loss 2.910913
# epoch 209, total batch 825134, train loss 2.822966, val loss 2.903161
# epoch 210, total batch 828919, train loss 2.811968, val loss 2.899662
# epoch 211, total batch 832704, train loss 2.823538, val loss 2.902123
# epoch 212, total batch 836489, train loss 2.807568, val loss 2.893419
# epoch 213, total batch 840274, train loss 2.810390, val loss 2.893133
# epoch 214, total batch 844059, train loss 2.798414, val loss 2.892998
# epoch 215, total batch 847844, train loss 2.804050, val loss 2.893668
# epoch 216, total batch 851629, train loss 2.805049, val loss 2.888866
# epoch 217, total batch 855414, train loss 2.803231, val loss 2.882615
# epoch 218, total batch 859199, train loss 2.798175, val loss 2.886416
# epoch 219, total batch 862984, train loss 2.800322, val loss 2.887602
# epoch 220, total batch 866769, train loss 2.785728, val loss 2.877696
# epoch 221, total batch 870554, train loss 2.795518, val loss 2.879281
# epoch 222, total batch 874339, train loss 2.788168, val loss 2.880398
# epoch 223, total batch 878124, train loss 2.790524, val loss 2.877428
# epoch 224, total batch 881909, train loss 2.782521, val loss 2.873771
# epoch 225, total batch 885694, train loss 2.785411, val loss 2.872052
# epoch 226, total batch 889479, train loss 2.776846, val loss 2.862123
# epoch 227, total batch 893264, train loss 2.772886, val loss 2.862045
# epoch 228, total batch 897049, train loss 2.773434, val loss 2.862042
# epoch 229, total batch 900834, train loss 2.765056, val loss 2.860909
# epoch 230, total batch 904619, train loss 2.762966, val loss 2.862591
# epoch 231, total batch 908404, train loss 2.765877, val loss 2.854916
# epoch 232, total batch 912189, train loss 2.758621, val loss 2.853738
# epoch 233, total batch 915974, train loss 2.764966, val loss 2.850591
# epoch 234, total batch 919759, train loss 2.763235, val loss 2.850336
# epoch 235, total batch 923544, train loss 2.747820, val loss 2.849854
# epoch 236, total batch 927329, train loss 2.748396, val loss 2.840853
# epoch 237, total batch 931114, train loss 2.762116, val loss 2.842444
# epoch 238, total batch 934899, train loss 2.741730, val loss 2.838300
# epoch 239, total batch 938684, train loss 2.749215, val loss 2.833186
# epoch 240, total batch 942469, train loss 2.754120, val loss 2.829525
# epoch 241, total batch 946254, train loss 2.736547, val loss 2.837233
# epoch 242, total batch 950039, train loss 2.740422, val loss 2.833393
# epoch 243, total batch 953824, train loss 2.733942, val loss 2.832869
# epoch 244, total batch 957609, train loss 2.741336, val loss 2.828641
# epoch 245, total batch 961394, train loss 2.732675, val loss 2.825133
# epoch 246, total batch 965179, train loss 2.731682, val loss 2.819785
# epoch 247, total batch 968964, train loss 2.727946, val loss 2.820430
# epoch 248, total batch 972749, train loss 2.715274, val loss 2.815116
# epoch 249, total batch 976534, train loss 2.731396, val loss 2.816437
# epoch 250, total batch 980319, train loss 2.732347, val loss 2.824369
# epoch 251, total batch 984104, train loss 2.741718, val loss 2.814149
# epoch 252, total batch 987889, train loss 2.714493, val loss 2.815064
# epoch 253, total batch 991674, train loss 2.716904, val loss 2.808487
# epoch 254, total batch 995459, train loss 2.714455, val loss 2.811739
# epoch 255, total batch 999244, train loss 2.717650, val loss 2.804229
# epoch 256, total batch 1003029, train loss 2.713934, val loss 2.809540
# epoch 257, total batch 1006814, train loss 2.708650, val loss 2.798152
# epoch 258, total batch 1010599, train loss 2.708980, val loss 2.806342
# epoch 259, total batch 1014384, train loss 2.700691, val loss 2.798952
# epoch 260, total batch 1018169, train loss 2.704615, val loss 2.801182
# epoch 261, total batch 1021954, train loss 2.696932, val loss 2.797883
# epoch 262, total batch 1025739, train loss 2.694026, val loss 2.795553
# epoch 263, total batch 1029524, train loss 2.707481, val loss 2.788275
# epoch 264, total batch 1033309, train loss 2.690281, val loss 2.796958
# epoch 265, total batch 1037094, train loss 2.689972, val loss 2.790392
# epoch 266, total batch 1040879, train loss 2.686138, val loss 2.791821
# epoch 267, total batch 1044664, train loss 2.693416, val loss 2.790583
# epoch 268, total batch 1048449, train loss 2.685951, val loss 2.783325
# epoch 269, total batch 1052234, train loss 2.674036, val loss 2.792317
# epoch 270, total batch 1056019, train loss 2.685390, val loss 2.778163
# epoch 271, total batch 1059804, train loss 2.684322, val loss 2.785558
# epoch 272, total batch 1063589, train loss 2.687867, val loss 2.777429
# epoch 273, total batch 1067374, train loss 2.679691, val loss 2.783335
# epoch 274, total batch 1071159, train loss 2.675709, val loss 2.782195
# epoch 275, total batch 1074944, train loss 2.680371, val loss 2.774707
# epoch 276, total batch 1078729, train loss 2.682231, val loss 2.772973
# epoch 277, total batch 1082514, train loss 2.671289, val loss 2.773247
# epoch 278, total batch 1086299, train loss 2.679082, val loss 2.777281
# epoch 279, total batch 1090084, train loss 2.661527, val loss 2.769091
# epoch 280, total batch 1093869, train loss 2.660214, val loss 2.767278
# epoch 281, total batch 1097654, train loss 2.663344, val loss 2.765525
# epoch 282, total batch 1101439, train loss 2.660869, val loss 2.760810
# epoch 283, total batch 1105224, train loss 2.653097, val loss 2.763572
# epoch 284, total batch 1109009, train loss 2.661170, val loss 2.753147
# epoch 285, total batch 1112794, train loss 2.654607, val loss 2.759175
# epoch 286, total batch 1116579, train loss 2.649936, val loss 2.763203
# epoch 287, total batch 1120364, train loss 2.665065, val loss 2.753014
# epoch 288, total batch 1124149, train loss 2.657468, val loss 2.758557
# epoch 289, total batch 1127934, train loss 2.662977, val loss 2.750545
# epoch 290, total batch 1131719, train loss 2.652868, val loss 2.750962
# epoch 291, total batch 1135504, train loss 2.655209, val loss 2.739897
# epoch 292, total batch 1139289, train loss 2.647097, val loss 2.755418
# epoch 293, total batch 1143074, train loss 2.647216, val loss 2.745122
# epoch 294, total batch 1146859, train loss 2.638380, val loss 2.743538
# epoch 295, total batch 1150644, train loss 2.641219, val loss 2.747287
# epoch 296, total batch 1154429, train loss 2.644674, val loss 2.748322
# epoch 297, total batch 1158214, train loss 2.636379, val loss 2.744946
# epoch 298, total batch 1161999, train loss 2.632649, val loss 2.734708
# epoch 299, total batch 1165784, train loss 2.634146, val loss 2.736335
# epoch 300, total batch 1169569, train loss 2.632290, val loss 2.734607
# epoch 301, total batch 1173354, train loss 2.640315, val loss 2.734262
# epoch 302, total batch 1177139, train loss 2.628457, val loss 2.738630
# epoch 303, total batch 1180924, train loss 2.625546, val loss 2.728402
# epoch 304, total batch 1184709, train loss 2.623030, val loss 2.735060
# epoch 305, total batch 1188494, train loss 2.637101, val loss 2.729694
# epoch 306, total batch 1192279, train loss 2.624019, val loss 2.724490
# epoch 307, total batch 1196064, train loss 2.620144, val loss 2.725391
# epoch 308, total batch 1199849, train loss 2.627097, val loss 2.723064
# epoch 309, total batch 1203634, train loss 2.625750, val loss 2.723753
# epoch 310, total batch 1207419, train loss 2.626634, val loss 2.725079
# epoch 311, total batch 1211204, train loss 2.618182, val loss 2.717908
# epoch 312, total batch 1214989, train loss 2.616121, val loss 2.710634
# epoch 313, total batch 1218774, train loss 2.613355, val loss 2.712091
# epoch 314, total batch 1222559, train loss 2.602723, val loss 2.714016
# epoch 315, total batch 1226344, train loss 2.610416, val loss 2.711899
# epoch 316, total batch 1230129, train loss 2.610594, val loss 2.708024
# epoch 317, total batch 1233914, train loss 2.617247, val loss 2.710891
# epoch 318, total batch 1237699, train loss 2.613079, val loss 2.712359
# epoch 319, total batch 1241484, train loss 2.598116, val loss 2.711225
# epoch 320, total batch 1245269, train loss 2.607110, val loss 2.710986
# epoch 321, total batch 1249054, train loss 2.601503, val loss 2.702092
# epoch 322, total batch 1252839, train loss 2.607440, val loss 2.701165
# epoch 323, total batch 1256624, train loss 2.600734, val loss 2.702646
# epoch 324, total batch 1260409, train loss 2.591293, val loss 2.707290
# epoch 325, total batch 1264194, train loss 2.589996, val loss 2.706791
# epoch 326, total batch 1267979, train loss 2.602455, val loss 2.702532
# epoch 327, total batch 1271764, train loss 2.592161, val loss 2.703662
# epoch 328, total batch 1275549, train loss 2.585468, val loss 2.702978
# epoch 329, total batch 1279334, train loss 2.592280, val loss 2.703062
# epoch 330, total batch 1283119, train loss 2.585666, val loss 2.700687
# epoch 331, total batch 1286904, train loss 2.592054, val loss 2.697327
# epoch 332, total batch 1290689, train loss 2.584083, val loss 2.693629
# epoch 333, total batch 1294474, train loss 2.597527, val loss 2.690703
# epoch 334, total batch 1298259, train loss 2.587427, val loss 2.685667
# epoch 335, total batch 1302044, train loss 2.587108, val loss 2.693429
# epoch 336, total batch 1305829, train loss 2.580220, val loss 2.684621
# epoch 337, total batch 1309614, train loss 2.578955, val loss 2.688428
# epoch 338, total batch 1313399, train loss 2.581448, val loss 2.687063
# epoch 339, total batch 1317184, train loss 2.580229, val loss 2.684761
# epoch 340, total batch 1320969, train loss 2.580580, val loss 2.690389
# epoch 341, total batch 1324754, train loss 2.570819, val loss 2.693065
# epoch 342, total batch 1328539, train loss 2.575884, val loss 2.685226
# epoch 343, total batch 1332324, train loss 2.576528, val loss 2.681706
# epoch 344, total batch 1336109, train loss 2.570877, val loss 2.682223
# epoch 345, total batch 1339894, train loss 2.574519, val loss 2.676708
# epoch 346, total batch 1343679, train loss 2.574904, val loss 2.677015
# epoch 347, total batch 1347464, train loss 2.568021, val loss 2.676933
# epoch 348, total batch 1351249, train loss 2.562613, val loss 2.674960
# epoch 349, total batch 1355034, train loss 2.574678, val loss 2.675268
# epoch 350, total batch 1358819, train loss 2.569717, val loss 2.677200
# epoch 351, total batch 1362604, train loss 2.563932, val loss 2.671529
# epoch 352, total batch 1366389, train loss 2.566910, val loss 2.672845
# epoch 353, total batch 1370174, train loss 2.555291, val loss 2.670766
# epoch 354, total batch 1373959, train loss 2.560101, val loss 2.670930
# epoch 355, total batch 1377744, train loss 2.571714, val loss 2.661388
# epoch 356, total batch 1381529, train loss 2.555720, val loss 2.657750
# epoch 357, total batch 1385314, train loss 2.558743, val loss 2.666113
# epoch 358, total batch 1389099, train loss 2.553623, val loss 2.666794
# epoch 359, total batch 1392884, train loss 2.555882, val loss 2.661963
# epoch 360, total batch 1396669, train loss 2.560223, val loss 2.660661
# epoch 361, total batch 1400454, train loss 2.551699, val loss 2.657298
# epoch 362, total batch 1404239, train loss 2.548730, val loss 2.656112
# epoch 363, total batch 1408024, train loss 2.561115, val loss 2.659007
# epoch 364, total batch 1411809, train loss 2.546641, val loss 2.657311
# epoch 365, total batch 1415594, train loss 2.540765, val loss 2.652180
# epoch 366, total batch 1419379, train loss 2.542452, val loss 2.651722
# epoch 367, total batch 1423164, train loss 2.549127, val loss 2.646657
# epoch 368, total batch 1426949, train loss 2.547884, val loss 2.652150
# epoch 369, total batch 1430734, train loss 2.539573, val loss 2.649419
# epoch 370, total batch 1434519, train loss 2.540071, val loss 2.651786
# epoch 371, total batch 1438304, train loss 2.536906, val loss 2.646030
# epoch 372, total batch 1442089, train loss 2.538878, val loss 2.645987
# epoch 373, total batch 1445874, train loss 2.542390, val loss 2.645104
# epoch 374, total batch 1449659, train loss 2.528723, val loss 2.647176
# epoch 375, total batch 1453444, train loss 2.536898, val loss 2.639612
# epoch 376, total batch 1457229, train loss 2.527861, val loss 2.639215
# epoch 377, total batch 1461014, train loss 2.533061, val loss 2.643615
# epoch 378, total batch 1464799, train loss 2.535856, val loss 2.635354
# epoch 379, total batch 1468584, train loss 2.531109, val loss 2.641750
# epoch 380, total batch 1472369, train loss 2.537612, val loss 2.639718
# epoch 381, total batch 1476154, train loss 2.526249, val loss 2.635509
# epoch 382, total batch 1479939, train loss 2.525231, val loss 2.640610
# epoch 383, total batch 1483724, train loss 2.512177, val loss 2.634896
# epoch 384, total batch 1487509, train loss 2.527021, val loss 2.632201
# epoch 385, total batch 1491294, train loss 2.525192, val loss 2.629779
# epoch 386, total batch 1495079, train loss 2.517038, val loss 2.638222
# epoch 387, total batch 1498864, train loss 2.524082, val loss 2.630803
# epoch 388, total batch 1502649, train loss 2.528839, val loss 2.626658
# epoch 389, total batch 1506434, train loss 2.516225, val loss 2.626481
# epoch 390, total batch 1510219, train loss 2.517968, val loss 2.625545
# epoch 391, total batch 1514004, train loss 2.513889, val loss 2.624766
# epoch 392, total batch 1517789, train loss 2.516008, val loss 2.631694
# epoch 393, total batch 1521574, train loss 2.518280, val loss 2.629115
# epoch 394, total batch 1525359, train loss 2.518665, val loss 2.625612
# epoch 395, total batch 1529144, train loss 2.513406, val loss 2.629206
# epoch 396, total batch 1532929, train loss 2.515587, val loss 2.621592
# epoch 397, total batch 1536714, train loss 2.510739, val loss 2.623629
# epoch 398, total batch 1540499, train loss 2.517746, val loss 2.624353
# epoch 399, total batch 1544284, train loss 2.518858, val loss 2.624177
# epoch 400, total batch 1548069, train loss 2.510744, val loss 2.618397
# epoch 401, total batch 1551854, train loss 2.512492, val loss 2.617561
# epoch 402, total batch 1555639, train loss 2.503522, val loss 2.614348
# epoch 403, total batch 1559424, train loss 2.505843, val loss 2.607366
# epoch 404, total batch 1563209, train loss 2.496670, val loss 2.616996
# epoch 405, total batch 1566994, train loss 2.497309, val loss 2.609135
# epoch 406, total batch 1570779, train loss 2.505950, val loss 2.616994
# epoch 407, total batch 1574564, train loss 2.507635, val loss 2.613430
# epoch 408, total batch 1578349, train loss 2.506417, val loss 2.605018
# epoch 409, total batch 1582134, train loss 2.497025, val loss 2.615236
# epoch 410, total batch 1585919, train loss 2.504393, val loss 2.606924
# epoch 411, total batch 1589704, train loss 2.498235, val loss 2.606808
# epoch 412, total batch 1593489, train loss 2.492301, val loss 2.604208
# epoch 413, total batch 1597274, train loss 2.500712, val loss 2.609291
# epoch 414, total batch 1601059, train loss 2.491503, val loss 2.602329
# epoch 415, total batch 1604844, train loss 2.492293, val loss 2.605158
# epoch 416, total batch 1608629, train loss 2.483319, val loss 2.604336
# epoch 417, total batch 1612414, train loss 2.497964, val loss 2.600857
# epoch 418, total batch 1616199, train loss 2.486960, val loss 2.605200
# epoch 419, total batch 1619984, train loss 2.500777, val loss 2.602544
# epoch 420, total batch 1623769, train loss 2.479878, val loss 2.601247
# epoch 421, total batch 1627554, train loss 2.490311, val loss 2.600378
# epoch 422, total batch 1631339, train loss 2.479288, val loss 2.595577
# epoch 423, total batch 1635124, train loss 2.467488, val loss 2.596361
# epoch 424, total batch 1638909, train loss 2.487005, val loss 2.596561
# epoch 425, total batch 1642694, train loss 2.481307, val loss 2.589718
# epoch 426, total batch 1646479, train loss 2.480253, val loss 2.591817
# epoch 427, total batch 1650264, train loss 2.481601, val loss 2.596885
# epoch 428, total batch 1654049, train loss 2.484755, val loss 2.594276
# epoch 429, total batch 1657834, train loss 2.487851, val loss 2.593072
# epoch 430, total batch 1661619, train loss 2.479253, val loss 2.587259
# epoch 431, total batch 1665404, train loss 2.481232, val loss 2.587725
# epoch 432, total batch 1669189, train loss 2.470637, val loss 2.584399
# epoch 433, total batch 1672974, train loss 2.483307, val loss 2.590686
# epoch 434, total batch 1676759, train loss 2.468033, val loss 2.589175
# epoch 435, total batch 1680544, train loss 2.472293, val loss 2.584016
# epoch 436, total batch 1684329, train loss 2.474366, val loss 2.584294
# epoch 437, total batch 1688114, train loss 2.466893, val loss 2.579704
# epoch 438, total batch 1691899, train loss 2.467122, val loss 2.584760
# epoch 439, total batch 1695684, train loss 2.471344, val loss 2.579550
# epoch 440, total batch 1699469, train loss 2.474414, val loss 2.580415
# epoch 441, total batch 1703254, train loss 2.461119, val loss 2.577431
# epoch 442, total batch 1707039, train loss 2.474886, val loss 2.581615
# epoch 443, total batch 1710824, train loss 2.475845, val loss 2.583597
# epoch 444, total batch 1714609, train loss 2.473170, val loss 2.577716
# epoch 445, total batch 1718394, train loss 2.475666, val loss 2.573479
# epoch 446, total batch 1722179, train loss 2.459658, val loss 2.581871
# epoch 447, total batch 1725964, train loss 2.465923, val loss 2.572921
# epoch 448, total batch 1729749, train loss 2.467896, val loss 2.575591
# epoch 449, total batch 1733534, train loss 2.466148, val loss 2.577648
# epoch 450, total batch 1737319, train loss 2.455359, val loss 2.572308
# epoch 451, total batch 1741104, train loss 2.462974, val loss 2.581767
# epoch 452, total batch 1744889, train loss 2.453704, val loss 2.570050
# epoch 453, total batch 1748674, train loss 2.466026, val loss 2.571249
# epoch 454, total batch 1752459, train loss 2.460181, val loss 2.570001
# epoch 455, total batch 1756244, train loss 2.467085, val loss 2.571581
# epoch 456, total batch 1760029, train loss 2.464799, val loss 2.572097
# epoch 457, total batch 1763814, train loss 2.465245, val loss 2.568176
# epoch 458, total batch 1767599, train loss 2.452525, val loss 2.564731
# epoch 459, total batch 1771384, train loss 2.449967, val loss 2.566703
# epoch 460, total batch 1775169, train loss 2.453235, val loss 2.566139
# epoch 461, total batch 1778954, train loss 2.455122, val loss 2.562216
# epoch 462, total batch 1782739, train loss 2.454776, val loss 2.561412
# epoch 463, total batch 1786524, train loss 2.450692, val loss 2.555563
# epoch 464, total batch 1790309, train loss 2.449283, val loss 2.561437
# epoch 465, total batch 1794094, train loss 2.452910, val loss 2.558150
# epoch 466, total batch 1797879, train loss 2.450321, val loss 2.559134
# epoch 467, total batch 1801664, train loss 2.450627, val loss 2.560527
# epoch 468, total batch 1805449, train loss 2.448902, val loss 2.558786
# epoch 469, total batch 1809234, train loss 2.455826, val loss 2.559622
# epoch 470, total batch 1813019, train loss 2.447725, val loss 2.551462
# epoch 471, total batch 1816804, train loss 2.454659, val loss 2.551530
# epoch 472, total batch 1820589, train loss 2.450204, val loss 2.550610
# epoch 473, total batch 1824374, train loss 2.453555, val loss 2.555403
# epoch 474, total batch 1828159, train loss 2.443371, val loss 2.548574
# epoch 475, total batch 1831944, train loss 2.435146, val loss 2.558153
# epoch 476, total batch 1835729, train loss 2.445720, val loss 2.552871
# epoch 477, total batch 1839514, train loss 2.443060, val loss 2.553616
# epoch 478, total batch 1843299, train loss 2.445988, val loss 2.550740
# epoch 479, total batch 1847084, train loss 2.428874, val loss 2.551641
# epoch 480, total batch 1850869, train loss 2.444194, val loss 2.546666
# epoch 481, total batch 1854654, train loss 2.430932, val loss 2.550333
# epoch 482, total batch 1858439, train loss 2.428718, val loss 2.541390
# epoch 483, total batch 1862224, train loss 2.440165, val loss 2.544914
# epoch 484, total batch 1866009, train loss 2.443694, val loss 2.545515
# epoch 485, total batch 1869794, train loss 2.427947, val loss 2.550838
# epoch 486, total batch 1873579, train loss 2.439292, val loss 2.551626
# epoch 487, total batch 1877364, train loss 2.433153, val loss 2.538756
# epoch 488, total batch 1881149, train loss 2.434463, val loss 2.541650
# epoch 489, total batch 1884934, train loss 2.435554, val loss 2.543995
# epoch 490, total batch 1888719, train loss 2.424168, val loss 2.543902
# epoch 491, total batch 1892504, train loss 2.437647, val loss 2.544141
# epoch 492, total batch 1896289, train loss 2.428904, val loss 2.536078
# epoch 493, total batch 1900074, train loss 2.416425, val loss 2.540429
# epoch 494, total batch 1903859, train loss 2.431385, val loss 2.531617
# epoch 495, total batch 1907644, train loss 2.432521, val loss 2.533105
# epoch 496, total batch 1911429, train loss 2.435830, val loss 2.538331
# epoch 497, total batch 1915214, train loss 2.421521, val loss 2.536522
# epoch 498, total batch 1918999, train loss 2.422768, val loss 2.538185
# epoch 499, total batch 1922784, train loss 2.417379, val loss 2.538039
# epoch 500, total batch 1926569, train loss 2.411049, val loss 2.537803

# %%
word_vector_embed = word2vec.Word2Vec(embed_weights, dictionary)
word_vector_nce = word2vec.Word2Vec(nce_weights, dictionary)

# %%
word = 'mahathir'
print("Embedding layer: 8 closest words to: '%s'"%(word))
print(word_vector_embed.n_closest(word=word, num_closest=8, metric='cosine'), '\n')
print("NCE layer: 8 closest words to: '%s'"%(word))
print(word_vector_nce.n_closest(word=word, num_closest=8, metric='cosine'))
# Out:
# Embedding layer: 8 closest words to: 'mahathir'
# ['zambry', 'dzulkefly', 'singaraveloo', 'jeyaindran', 'jokowi', 'subramaniam', 'shaeraine', 'mahahir']
#
# NCE layer: 8 closest words to: 'mahathir'
# ['zakir', 'zambry', 'subramaniam', 'zamihan', 'dzulkefly', 'adam', 'husam', 'shahidan']

# %%
print(word_vector_nce.analogy('mahathir', 'anwar', 'kerajaan', 5))
# Out:
# ['kerajaan', 'spr', 'jentera', 'bolasepak', 'malaysiakini']

# %%
print(word_vector_embed.analogy('mahathir', 'anwar', 'kerajaan', 5))
# Out:
# ['kerajaan', 'penjimat', 'cicin', 'knalpot', 'telekomuniasi']

# %%
passage = [rev_dictionary[i] for i in word_array[12200:12300]]

# %%
readable = ''
for word in passage:
    if word == '"':
        readable += word
    elif word in ['?', '!', '.', ',']:
        readable += word + ' '
    else: 
        readable += ' ' + word
print(readable)
# Out:
#  sangat dominan sedangkan mca ada masalah mic dan gerakan ada masalah ini yang lemahkan bnnamun nature politik memang begitu tapi boleh settle down lepas prucuma bimbang orang malaysia sangat emosi dengan apa yang berlaku maka ia tidak sihatazizudin politik kena rasional jadi kita patut ke arah politik matangnamun hakikatnya melihat pada isu kaum ia berlaku di semua negarakena rasionalkan politik perkauman itu cuma di malaysia kita masih baik dan tidak berperang sesama sendirilihat faktor ekonomi mempengaruhi politik jadi fenomena arab spring tidak akan berlaku di malaysiamoderator adakah bn boleh reformmaszlee kalau kita lihat bn dan umno ada dinamik berevolusi ketika

# %%
x, y = word2vec.build_training_set(word_array[(12200-2):(12300+2)])
y_hat = model.sess.run(model.logits,feed_dict={model.X:x})
passage_predict = [rev_dictionary[i] for i in y_hat]

# %%
readable = ''
for word in passage_predict:
    if word == '"':
        readable += word
    elif word in ['?', '!', '.', ',']:
        readable += word + ' '
    else: 
        readable += ' ' + word
print(readable)
# Out:
#  sangat baik dari sama dan anggota keselamatan dan sama ini negeri sosial yang juga riwayat partai politik yang bersalah juga boleh menghubungi allah lalu saya mengatakan harga melayu mempunyai baik dengan apa yang berlaku kerana ia tidak melakukan tidak bn boleh itu saya pergi ke atas politik namun bn masih kepada itu ini yang berada di semua menjadi bermain politik seperti itu terutamanya di malaysia ia lebih relevan dan tidak cukup dengan jenis hal yang dan negara terhadap perbuatan arab saudi yang akan berlaku di malaysia adakah bn boleh dilakukan kalau kita lihat kerajaan kerana tidak dapat telah katanya menjadi

# %%
embed_weights.shape
# Out:
# (33735, 64)

# %%
import pickle
with open('word2vec-64.p', 'wb') as fopen:
    pickle.dump({'dictionary':dictionary,'rev_dictionary':rev_dictionary,
                 'embed_weights':embed_weights,'nce_weights':nce_weights}, fopen)
