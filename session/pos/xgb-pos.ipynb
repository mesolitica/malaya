# %%
import json
import re
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.cross_validation import train_test_split
from sklearn.naive_bayes import MultinomialNB
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def process_string(string):
    string = re.sub('[^A-Za-z0-9\-\/ ]+', ' ', string).split()
    return [y.strip() for y in string]

# %%
with open('pos-data-v3.json','r') as fopen:
    dataset = json.load(fopen)

# %%
texts, labels = [], []
for i in dataset:
    try:
        texts.append(process_string(i[0])[0].lower())
        labels.append(i[-1])
    except Exception as e:
        print(e, i)
# Out:
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['뭘봐', '뭘봐', 'PROPN']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['ひ', 'ひ', 'PROPN']
# list index out of range ['ヒ', 'ヒ', 'PROPN']
# list index out of range ['形聲', '形聲', 'NOUN']
# list index out of range ['°', '°', 'SYM']
# list index out of range ['汉', '汉', 'PROPN']
# list index out of range ['东', '东', 'PROPN']
# list index out of range ['王', '王', 'PROPN']
# list index out of range ['（', '（', 'PROPN']
# list index out of range ['伊', '伊', 'PROPN']
# list index out of range ['）', '）', 'PROPN']
# list index out of range ['ȝ', 'ȝ', 'PROPN']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['°', '°', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ["'", '_', 'PROPN']
# list index out of range ['碁', '碁', 'NOUN']
# list index out of range ['囲碁', '囲碁', 'NOUN']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['会', '会', 'PROPN']
# list index out of range ['蔡武侯', '蔡武侯', 'PROPN']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['+', '+', 'SYM']
# list index out of range ['+', '+', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['*', '*', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['+', '+', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['~', '~', 'ADJ']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['ОАО', 'оао', 'PROPN']
# list index out of range ['Газпром', 'газпром', 'PROPN']
# list index out of range ["''", '_', 'PROPN']
# list index out of range ['°', '°', 'SYM']
# list index out of range ['°', '°', 'SYM']
# list index out of range ['佐々木', '佐々木', 'PROPN']
# list index out of range ['功', '功', 'PROPN']
# list index out of range ['ɳ', 'ɳ', 'PROPN']
# list index out of range ['ʂ', 'ʂ', 'PROPN']
# list index out of range ['ʈ', 'ʈ', 'PROPN']
# list index out of range ['ɖ', 'ɖ', 'PROPN']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ["'", '_', 'NOUN']
# list index out of range ["'", '_', 'PROPN']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['鉄の森', '鉄の森', 'PROPN']
# list index out of range ['アイゼンヴァルト', 'アイゼンヴァルト', 'PROPN']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['+', '+', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['壽', '壽', 'PROPN']
# list index out of range ['陽', '陽', 'PROPN']
# list index out of range ['裴叔業', '裴叔業', 'PROPN']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['#', '#', 'SYM']
# list index out of range ['+', '+', 'SYM']
# list index out of range ['فيروز', 'فيروز', 'PROPN']
# list index out of range ['الديلامي', 'الديلامي', 'PROPN']
# list index out of range ['נביאים', 'נביאים', 'NOUN']
# list index out of range ['ראשונים', 'ראשונים', 'NOUN']
# list index out of range ['נביאים', 'נביאים', 'NOUN']
# list index out of range ['جامع', 'جامع', 'PROPN']
# list index out of range ['الرئيس', 'الرئيس', 'PROPN']
# list index out of range ['الصالح', 'الصالح', 'PROPN']
# list index out of range ['—', '—', 'NOUN']
# list index out of range ['°', '°', 'SYM']
# list index out of range ['°', '°', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['ä', 'ä', 'PROPN']
# list index out of range ['ʈ', 'ʈ', 'PROPN']
# list index out of range ['ʈʰ', 'ʈʰ', 'PROPN']
# list index out of range ['°', '°', 'SYM']
# list index out of range ['°', '°', 'SYM']
# list index out of range ["''", '_', 'PROPN']
# list index out of range ['€', '€', 'SYM']
# list index out of range ['\u200e', '\u200e', 'VERB']
# list index out of range ['\u200e', '\u200e', 'NOUN']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['$', '$', 'SYM']
# list index out of range ['Α', 'α', 'PROPN']
# list index out of range ['А', 'а', 'PROPN']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['$', '$', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['おる', 'おる', 'PROPN']
# list index out of range ['いる', 'いる', 'PROPN']
# list index out of range ['じゃ', 'じゃ', 'PROPN']
# list index out of range ['や', 'や', 'PROPN']
# list index out of range ['だ', 'だ', 'PROPN']
# list index out of range ['～', '～', 'PROPN']
# list index out of range ['ん', 'ん', 'PROPN']
# list index out of range ['わから', 'わから', 'PROPN']
# list index out of range ['ん', 'ん', 'PROPN']
# list index out of range ['～', '～', 'PROPN']
# list index out of range ['ない', 'ない', 'PROPN']
# list index out of range ['わからない', 'わからない', 'PROPN']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['#', '#', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['#', '#', 'SYM']
# list index out of range ['#', '#', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['×', '×', 'NOUN']
# list index out of range ['°', '°', 'SYM']
# list index out of range ['–', '–', 'NUM']
# list index out of range ['°', '°', 'SYM']
# list index out of range ['続', '続', 'PROPN']
# list index out of range ['・', '・', 'PROPN']
# list index out of range ['三', '三', 'PROPN']
# list index out of range ['丁目', '丁目', 'PROPN']
# list index out of range ['の', 'の', 'PROPN']
# list index out of range ['夕日', '夕日', 'PROPN']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['Ἑλλάδος', 'ἑλλάδος', 'PROPN']
# list index out of range ['παίδευσις', 'παίδευσις', 'PROPN']
# list index out of range ['€', '€', 'SYM']
# list index out of range ['ê', 'ê', 'PROPN']
# list index out of range ['é', 'é', 'PROPN']
# list index out of range ['è', 'è', 'PROPN']
# list index out of range ['ë', 'ë', 'PROPN']
# list index out of range ['ē', 'ē', 'PROPN']
# list index out of range ['ĕ', 'ĕ', 'PROPN']
# list index out of range ['ě', 'ě', 'PROPN']
# list index out of range ['ẽ', 'ẽ', 'PROPN']
# list index out of range ['ė', 'ė', 'PROPN']
# list index out of range ['ę', 'ę', 'PROPN']
# list index out of range ['ẻ', 'ẻ', 'PROPN']
# list index out of range ['ö', 'ö', 'PROPN']
# list index out of range ['°', '°', 'SYM']
# list index out of range ['°', '°', 'SYM']
# list index out of range ['°', '°', 'SYM']
# list index out of range ['°', '°', 'SYM']
# list index out of range ['.', '.', 'PROPN']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['بندر', 'بندر', 'PROPN']
# list index out of range ['عباس', 'عباس', 'PROPN']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['+', '+', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['$', '$', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['珠海', '珠海', 'PROPN']
# list index out of range ["''", '_', 'NOUN']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['서종', '서종', 'PROPN']
# list index out of range ['제', '제', 'PROPN']
# list index out of range ['±', '±', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['仙', '仙', 'PROPN']
# list index out of range ['仚', '仚', 'PROPN']
# list index out of range ['僊', '僊', 'PROPN']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['腹切り', '腹切り', 'PROPN']
# list index out of range ['§', '§', 'PROPN']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['육식', '육식', 'PROPN']
# list index out of range ['동물', '동물', 'PROPN']
# list index out of range ['도망자', '도망자', 'PROPN']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['الغرب', 'الغرب', 'PROPN']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['سدوم', 'سدوم', 'PROPN']
# list index out of range ['عمورة', 'عمورة', 'PROPN']
# list index out of range ['高雄', '高雄', 'PROPN']
# list index out of range ['大眾', '大眾', 'PROPN']
# list index out of range ['捷', '捷', 'PROPN']
# list index out of range ['運', '運', 'PROPN']
# list index out of range ['系統', '系統', 'PROPN']
# list index out of range ['°', '°', 'SYM']
# list index out of range ['°', '°', 'SYM']
# list index out of range ['=', '=', 'SYM']
# list index out of range ['亳', '亳', 'PROPN']
# list index out of range ['°', '°', 'SYM']
# list index out of range ['المعقبات', 'المعقبات', 'PROPN']
# list index out of range ['%', '%', 'SYM']
# list index out of range ['#', '#', 'SYM']
# list index out of range ['#', '#', 'SYM']
# list index out of range ['#', '#', 'SYM']
# list index out of range ['#', '#', 'SYM']
# list index out of range ['%', '%', 'SYM']

# %%
{no:i for no, i in enumerate(np.unique(labels))}
# Out:
# {0: 'ADJ',
#  1: 'ADP',
#  2: 'ADV',
#  3: 'AUX',
#  4: 'CCONJ',
#  5: 'DET',
#  6: 'NOUN',
#  7: 'NUM',
#  8: 'PART',
#  9: 'PRON',
#  10: 'PROPN',
#  11: 'SCONJ',
#  12: 'SYM',
#  13: 'VERB',
#  14: 'X'}

# %%
target = LabelEncoder().fit_transform(labels)
bow_chars = CountVectorizer(ngram_range=(2, 4), analyzer='char').fit(texts)
vectors = bow_chars.transform(texts)
vectors.shape
# Out:
# (103417, 28374)

# %%
train_X, test_X, train_Y, test_Y = train_test_split(vectors, target, test_size = 0.1)
del vectors

# %%
import xgboost as xgb

# %%
train_d = xgb.DMatrix(train_X, train_Y)
test_d = xgb.DMatrix(test_X, test_Y)
params_xgd = {
    'min_child_weight': 10.0,
    'max_depth': 14,
    'objective': 'multi:softprob',
    'max_delta_step': 1.8,
    'num_class': len(np.unique(target)),
    'colsample_bytree': 0.4,
    'subsample': 0.8,
    'learning_rate': 0.1,
    'gamma': 0.65,
    'silent':True,
    'eval_metric': 'mlogloss'
}
model = xgb.train(params_xgd, train_d, 100000, evals=[(test_d, 'validation')], 
                  early_stopping_rounds=100, verbose_eval=50)
# Out:
# [0]	validation-mlogloss:2.41931
# Will train until validation-mlogloss hasn't improved in 100 rounds.
# [50]	validation-mlogloss:0.766313
# [100]	validation-mlogloss:0.643448
# [150]	validation-mlogloss:0.599167
# [200]	validation-mlogloss:0.575259
# [250]	validation-mlogloss:0.55921
# [300]	validation-mlogloss:0.548473
# [350]	validation-mlogloss:0.540771
# [400]	validation-mlogloss:0.534592
# [450]	validation-mlogloss:0.529116
# [500]	validation-mlogloss:0.524457
# [550]	validation-mlogloss:0.520296
# [600]	validation-mlogloss:0.516776
# [650]	validation-mlogloss:0.514046
# [700]	validation-mlogloss:0.511372
# [750]	validation-mlogloss:0.509108
# [800]	validation-mlogloss:0.506961
# [850]	validation-mlogloss:0.504766
# [900]	validation-mlogloss:0.502944
# [950]	validation-mlogloss:0.50125
# [1000]	validation-mlogloss:0.499914
# [1050]	validation-mlogloss:0.498169
# [1100]	validation-mlogloss:0.497037
# [1150]	validation-mlogloss:0.495854
# [1200]	validation-mlogloss:0.494597
# [1250]	validation-mlogloss:0.493381
# [1300]	validation-mlogloss:0.49216
# [1350]	validation-mlogloss:0.491054
# [1400]	validation-mlogloss:0.490068
# [1450]	validation-mlogloss:0.489097
# [1500]	validation-mlogloss:0.488212
# [1550]	validation-mlogloss:0.487113
# [1600]	validation-mlogloss:0.486177
# [1650]	validation-mlogloss:0.485284
# [1700]	validation-mlogloss:0.484606
# [1750]	validation-mlogloss:0.48386
# [1800]	validation-mlogloss:0.483214
# [1850]	validation-mlogloss:0.482755
# [1900]	validation-mlogloss:0.482205
# [1950]	validation-mlogloss:0.481511
# [2000]	validation-mlogloss:0.48077
# [2050]	validation-mlogloss:0.480064
# [2100]	validation-mlogloss:0.479602
# [2150]	validation-mlogloss:0.479096
# [2200]	validation-mlogloss:0.478738
# [2250]	validation-mlogloss:0.478358
# [2300]	validation-mlogloss:0.477934
# [2350]	validation-mlogloss:0.477618
# [2400]	validation-mlogloss:0.477098
# [2450]	validation-mlogloss:0.47684
# [2500]	validation-mlogloss:0.476378
# [2550]	validation-mlogloss:0.475764
# [2600]	validation-mlogloss:0.475437
# [2650]	validation-mlogloss:0.475347
# [2700]	validation-mlogloss:0.475077
# [2750]	validation-mlogloss:0.474592
# [2800]	validation-mlogloss:0.474106
# [2850]	validation-mlogloss:0.473691
# [2900]	validation-mlogloss:0.473374
# [2950]	validation-mlogloss:0.473271
# [3000]	validation-mlogloss:0.472942
# [3050]	validation-mlogloss:0.472805
# [3100]	validation-mlogloss:0.472474
# [3150]	validation-mlogloss:0.472287
# [3200]	validation-mlogloss:0.471842
# [3250]	validation-mlogloss:0.471672
# [3300]	validation-mlogloss:0.471429
# [3350]	validation-mlogloss:0.471134
# [3400]	validation-mlogloss:0.470852
# [3450]	validation-mlogloss:0.470475
# [3500]	validation-mlogloss:0.470211
# [3550]	validation-mlogloss:0.470114
# [3600]	validation-mlogloss:0.469879
# [3650]	validation-mlogloss:0.469489
# [3700]	validation-mlogloss:0.469503
# [3750]	validation-mlogloss:0.4692
# [3800]	validation-mlogloss:0.469094
# [3850]	validation-mlogloss:0.469009
# [3900]	validation-mlogloss:0.468834
# [3950]	validation-mlogloss:0.468646
# [4000]	validation-mlogloss:0.468544
# [4050]	validation-mlogloss:0.468439
# [4100]	validation-mlogloss:0.46811
# [4150]	validation-mlogloss:0.467954
# [4200]	validation-mlogloss:0.467996
# [4250]	validation-mlogloss:0.467786
# [4300]	validation-mlogloss:0.467579
# [4350]	validation-mlogloss:0.467284
# [4400]	validation-mlogloss:0.467141
# [4450]	validation-mlogloss:0.466878
# [4500]	validation-mlogloss:0.466785
# [4550]	validation-mlogloss:0.466564
# [4600]	validation-mlogloss:0.466585
# [4650]	validation-mlogloss:0.466432
# [4700]	validation-mlogloss:0.46652
# [4750]	validation-mlogloss:0.466291
# [4800]	validation-mlogloss:0.466109
# [4850]	validation-mlogloss:0.466026
# [4900]	validation-mlogloss:0.466109
# Stopping. Best iteration:
# [4837]	validation-mlogloss:0.465988

# %%
from sklearn import metrics
predicted = np.argmax(model.predict(xgb.DMatrix(test_X),ntree_limit=model.best_ntree_limit),axis=1)
print(metrics.classification_report(test_Y, predicted, target_names = np.unique(labels)))
# Out:
#              precision    recall  f1-score   support
#
#         ADJ       0.78      0.66      0.71       462
#         ADP       0.94      0.95      0.95      1216
#         ADV       0.84      0.85      0.84       460
#         AUX       0.99      1.00      0.99        91
#       CCONJ       0.99      0.93      0.96       343
#         DET       0.94      0.94      0.94       401
#        NOUN       0.80      0.82      0.81      2668
#         NUM       0.77      0.93      0.84       463
#        PART       0.88      0.88      0.88        58
#        PRON       0.97      0.95      0.96       492
#       PROPN       0.79      0.77      0.78      2330
#       SCONJ       0.75      0.75      0.75       142
#         SYM       0.73      0.27      0.39        30
#        VERB       0.92      0.91      0.92      1182
#           X       0.00      0.00      0.00         4
#
# avg / total       0.85      0.85      0.85     10342
# /usr/local/lib/python3.5/dist-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
import pickle
with open('xgb-pos.pkl','wb') as fopen:
    pickle.dump(model,fopen)
with open('xgb-bow-pos.pkl','wb') as fopen:
    pickle.dump(bow_chars,fopen)
