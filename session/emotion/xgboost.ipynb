# %%
import re
import numpy as np
import pandas as pd
import collections
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from unidecode import unidecode
from nltk.util import ngrams
from tqdm import tqdm
import time

# %%
permulaan = [
    'bel',
    'se',
    'ter',
    'men',
    'meng',
    'mem',
    'memper',
    'di',
    'pe',
    'me',
    'ke',
    'ber',
    'pen',
    'per',
]

hujung = ['kan', 'kah', 'lah', 'tah', 'nya', 'an', 'wan', 'wati', 'ita']

def naive_stemmer(word):
    assert isinstance(word, str), 'input must be a string'
    hujung_result = re.findall(r'^(.*?)(%s)$' % ('|'.join(hujung)), word)
    word = hujung_result[0][0] if len(hujung_result) else word
    permulaan_result = re.findall(r'^(.*?)(%s)' % ('|'.join(permulaan[::-1])), word)
    permulaan_result.extend(re.findall(r'^(.*?)(%s)' % ('|'.join(permulaan)), word))
    mula = permulaan_result if len(permulaan_result) else ''
    if len(mula):
        mula = mula[1][1] if len(mula[1][1]) > len(mula[0][1]) else mula[0][1]
    return word.replace(mula, '')

# %%
def classification_textcleaning(string):
    string = re.sub(
        'http\S+|www.\S+',
        '',
        ' '.join(
            [i for i in string.split() if i.find('#') < 0 and i.find('@') < 0]
        ),
    )
    string = unidecode(string).replace('.', ' . ').replace(',', ' , ')
    string = re.sub('[^A-Za-z ]+', ' ', string)
    string = re.sub(r'[ ]+', ' ', string).strip()
    string = ' '.join(
        [i for i in re.findall('[\\w\']+|[;:\-\(\)&.,!?"]', string) if len(i)]
    )
    string = string.lower().split()
    string = [(naive_stemmer(word), word) for word in string]
    return (
        ' '.join([word[0] for word in string if len(word[0]) > 1]),
        ' '.join([word[1] for word in string if len(word[0]) > 1]),
    )

# %%
import os
emotion_files = [f for f in os.listdir(os.getcwd()) if 'translated-' in f]
emotion_files
# Out:
# ['translated-joy',
#  'translated-love',
#  'translated-fear',
#  'translated-sadness',
#  'translated-surprise',
#  'translated-anger']

# %%
texts, labels = [], []
for f in emotion_files:
    with open(f) as fopen:
        dataset = list(filter(None, fopen.read().split('\n')))
        labels.extend([f.split('-')[1]] * len(dataset))
        texts.extend(dataset)
        
for i in range(len(texts)):
    texts[i] = classification_textcleaning(texts[i])[0]

# %%
unique_labels = np.unique(labels).tolist()
labels = LabelEncoder().fit_transform(labels)
unique_labels
# Out:
# ['anger', 'fear', 'joy', 'love', 'sadness', 'surprise']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import xgboost as xgb

# %%
tfidf = TfidfVectorizer(ngram_range=(1, 3),min_df=2).fit(texts)
delattr(tfidf, 'stop_words_')
vectors = tfidf.transform(texts)
vectors.shape
# Out:
# (98515, 150374)

# %%
train_X, test_X, train_Y, test_Y = train_test_split(vectors, labels, test_size = 0.2)

# %%
train_d = xgb.DMatrix(train_X, train_Y)
test_d = xgb.DMatrix(test_X, test_Y)
params_xgd = {
    'min_child_weight': 10.0,
    'max_depth': 7,
    'objective': 'multi:softprob',
    'max_delta_step': 1.8,
    'num_class': len(unique_labels),
    'colsample_bytree': 0.4,
    'subsample': 0.8,
    'learning_rate': 0.1,
    'gamma': 0.65,
    'silent': True,
    'eval_metric': 'mlogloss'
}
model = xgb.train(params_xgd, train_d, 10000, evals=[(test_d, 'validation')], 
                  early_stopping_rounds=100, verbose_eval=5)
# Out:
# [0]	validation-mlogloss:1.74008
# Will train until validation-mlogloss hasn't improved in 100 rounds.
# [5]	validation-mlogloss:1.57107
# [10]	validation-mlogloss:1.44
# [15]	validation-mlogloss:1.34743
# [20]	validation-mlogloss:1.28066
# [25]	validation-mlogloss:1.22507
# [30]	validation-mlogloss:1.17591
# [35]	validation-mlogloss:1.13362
# [40]	validation-mlogloss:1.09899
# [45]	validation-mlogloss:1.06596
# [50]	validation-mlogloss:1.03805
# [55]	validation-mlogloss:1.01202
# [60]	validation-mlogloss:0.989304
# [65]	validation-mlogloss:0.968563
# [70]	validation-mlogloss:0.949455
# [75]	validation-mlogloss:0.932211
# [80]	validation-mlogloss:0.916403
# [85]	validation-mlogloss:0.901435
# [90]	validation-mlogloss:0.887864
# [95]	validation-mlogloss:0.874737
# [100]	validation-mlogloss:0.863097
# [105]	validation-mlogloss:0.851857
# [110]	validation-mlogloss:0.841303
# [115]	validation-mlogloss:0.831604
# [120]	validation-mlogloss:0.822591
# [125]	validation-mlogloss:0.813961
# [130]	validation-mlogloss:0.805982
# [135]	validation-mlogloss:0.798262
# [140]	validation-mlogloss:0.790861
# [145]	validation-mlogloss:0.783546
# [150]	validation-mlogloss:0.776976
# [155]	validation-mlogloss:0.770887
# [160]	validation-mlogloss:0.764743
# [165]	validation-mlogloss:0.759098
# [170]	validation-mlogloss:0.753682
# [175]	validation-mlogloss:0.748371
# [180]	validation-mlogloss:0.743421
# [185]	validation-mlogloss:0.738449
# [190]	validation-mlogloss:0.734026
# [195]	validation-mlogloss:0.729566
# [200]	validation-mlogloss:0.725464
# [205]	validation-mlogloss:0.721447
# [210]	validation-mlogloss:0.71765
# [215]	validation-mlogloss:0.713794
# [220]	validation-mlogloss:0.710273
# [225]	validation-mlogloss:0.706719
# [230]	validation-mlogloss:0.703426
# [235]	validation-mlogloss:0.700084
# [240]	validation-mlogloss:0.696856
# [245]	validation-mlogloss:0.693789
# [250]	validation-mlogloss:0.690693
# [255]	validation-mlogloss:0.687858
# [260]	validation-mlogloss:0.685038
# [265]	validation-mlogloss:0.682354
# [270]	validation-mlogloss:0.679855
# [275]	validation-mlogloss:0.67734
# [280]	validation-mlogloss:0.675012
# [285]	validation-mlogloss:0.672708
# [290]	validation-mlogloss:0.670161
# [295]	validation-mlogloss:0.667801
# [300]	validation-mlogloss:0.665543
# [305]	validation-mlogloss:0.663356
# [310]	validation-mlogloss:0.661416
# [315]	validation-mlogloss:0.659284
# [320]	validation-mlogloss:0.657446
# [325]	validation-mlogloss:0.655179
# [330]	validation-mlogloss:0.653188
# [335]	validation-mlogloss:0.651355
# [340]	validation-mlogloss:0.649297
# [345]	validation-mlogloss:0.647616
# [350]	validation-mlogloss:0.645902
# [355]	validation-mlogloss:0.644445
# [360]	validation-mlogloss:0.642817
# [365]	validation-mlogloss:0.64143
# [370]	validation-mlogloss:0.639868
# [375]	validation-mlogloss:0.638442
# [380]	validation-mlogloss:0.63712
# [385]	validation-mlogloss:0.635815
# [390]	validation-mlogloss:0.634388
# [395]	validation-mlogloss:0.633061
# [400]	validation-mlogloss:0.631703
# [405]	validation-mlogloss:0.630561
# [410]	validation-mlogloss:0.629443
# [415]	validation-mlogloss:0.628129
# [420]	validation-mlogloss:0.626914
# [425]	validation-mlogloss:0.625701
# [430]	validation-mlogloss:0.624529
# [435]	validation-mlogloss:0.623297
# [440]	validation-mlogloss:0.622244
# [445]	validation-mlogloss:0.621202
# [450]	validation-mlogloss:0.620118
# [455]	validation-mlogloss:0.619133
# [460]	validation-mlogloss:0.617989
# [465]	validation-mlogloss:0.617043
# [470]	validation-mlogloss:0.616097
# [475]	validation-mlogloss:0.61526
# [480]	validation-mlogloss:0.61427
# [485]	validation-mlogloss:0.613409
# [490]	validation-mlogloss:0.612667
# [495]	validation-mlogloss:0.61177
# [500]	validation-mlogloss:0.610882
# [505]	validation-mlogloss:0.610171
# [510]	validation-mlogloss:0.609349
# [515]	validation-mlogloss:0.608539
# [520]	validation-mlogloss:0.607836
# [525]	validation-mlogloss:0.607109
# [530]	validation-mlogloss:0.606424
# [535]	validation-mlogloss:0.605648
# [540]	validation-mlogloss:0.605037
# [545]	validation-mlogloss:0.60432
# [550]	validation-mlogloss:0.603647
# [555]	validation-mlogloss:0.603036
# [560]	validation-mlogloss:0.602351
# [565]	validation-mlogloss:0.601729
# [570]	validation-mlogloss:0.600992
# [575]	validation-mlogloss:0.600367
# [580]	validation-mlogloss:0.599807
# [585]	validation-mlogloss:0.599199
# [590]	validation-mlogloss:0.598636
# [595]	validation-mlogloss:0.598034
# [600]	validation-mlogloss:0.597483
# [605]	validation-mlogloss:0.596932
# [610]	validation-mlogloss:0.596368
# [615]	validation-mlogloss:0.59574
# [620]	validation-mlogloss:0.59518
# [625]	validation-mlogloss:0.594696
# [630]	validation-mlogloss:0.59417
# [635]	validation-mlogloss:0.59376
# [640]	validation-mlogloss:0.593259
# [645]	validation-mlogloss:0.592873
# [650]	validation-mlogloss:0.592349
# [655]	validation-mlogloss:0.591942
# [660]	validation-mlogloss:0.591542
# [665]	validation-mlogloss:0.591182
# [670]	validation-mlogloss:0.590683
# [675]	validation-mlogloss:0.590331
# [680]	validation-mlogloss:0.589961
# [685]	validation-mlogloss:0.589615
# [690]	validation-mlogloss:0.589238
# [695]	validation-mlogloss:0.588827
# [700]	validation-mlogloss:0.58852
# [705]	validation-mlogloss:0.588127
# [710]	validation-mlogloss:0.587687
# [715]	validation-mlogloss:0.587311
# [720]	validation-mlogloss:0.586986
# [725]	validation-mlogloss:0.586597
# [730]	validation-mlogloss:0.586304
# [735]	validation-mlogloss:0.585968
# [740]	validation-mlogloss:0.585703
# [745]	validation-mlogloss:0.585413
# [750]	validation-mlogloss:0.585154
# [755]	validation-mlogloss:0.584871
# [760]	validation-mlogloss:0.584549
# [765]	validation-mlogloss:0.584247
# [770]	validation-mlogloss:0.583973
# [775]	validation-mlogloss:0.583641
# [780]	validation-mlogloss:0.583345
# [785]	validation-mlogloss:0.583102
# [790]	validation-mlogloss:0.582856
# [795]	validation-mlogloss:0.582614
# [800]	validation-mlogloss:0.582312
# [805]	validation-mlogloss:0.582112
# [810]	validation-mlogloss:0.581782
# [815]	validation-mlogloss:0.581588
# [820]	validation-mlogloss:0.581422
# [825]	validation-mlogloss:0.581265
# [830]	validation-mlogloss:0.581109
# [835]	validation-mlogloss:0.580939
# [840]	validation-mlogloss:0.580766
# [845]	validation-mlogloss:0.580602
# [850]	validation-mlogloss:0.580518
# [855]	validation-mlogloss:0.580246
# [860]	validation-mlogloss:0.5801
# [865]	validation-mlogloss:0.579831
# [870]	validation-mlogloss:0.579653
# [875]	validation-mlogloss:0.579503
# [880]	validation-mlogloss:0.579389
# [885]	validation-mlogloss:0.579322
# [890]	validation-mlogloss:0.579141
# [895]	validation-mlogloss:0.578989
# [900]	validation-mlogloss:0.578888
# [905]	validation-mlogloss:0.578698
# [910]	validation-mlogloss:0.578575
# [915]	validation-mlogloss:0.578528
# [920]	validation-mlogloss:0.578355
# [925]	validation-mlogloss:0.578187
# [930]	validation-mlogloss:0.578083
# [935]	validation-mlogloss:0.577907
# [940]	validation-mlogloss:0.577809
# [945]	validation-mlogloss:0.577685
# [950]	validation-mlogloss:0.577519
# [955]	validation-mlogloss:0.577418
# [960]	validation-mlogloss:0.577311
# [965]	validation-mlogloss:0.577105
# [970]	validation-mlogloss:0.577029
# [975]	validation-mlogloss:0.576994
# [980]	validation-mlogloss:0.576994
# [985]	validation-mlogloss:0.57693
# [990]	validation-mlogloss:0.57688
# [995]	validation-mlogloss:0.576782
# [1000]	validation-mlogloss:0.576756
# [1005]	validation-mlogloss:0.576762
# [1010]	validation-mlogloss:0.576706
# [1015]	validation-mlogloss:0.576626
# [1020]	validation-mlogloss:0.576516
# [1025]	validation-mlogloss:0.576522
# [1030]	validation-mlogloss:0.576542
# [1035]	validation-mlogloss:0.57646
# [1040]	validation-mlogloss:0.576391
# [1045]	validation-mlogloss:0.576339
# [1050]	validation-mlogloss:0.576357
# [1055]	validation-mlogloss:0.576281
# [1060]	validation-mlogloss:0.576148
# [1065]	validation-mlogloss:0.576121
# [1070]	validation-mlogloss:0.576082
# [1075]	validation-mlogloss:0.576026
# [1080]	validation-mlogloss:0.575969
# [1085]	validation-mlogloss:0.575975
# [1090]	validation-mlogloss:0.575887
# [1095]	validation-mlogloss:0.57588
# [1100]	validation-mlogloss:0.575841
# [1105]	validation-mlogloss:0.575746
# [1110]	validation-mlogloss:0.575682
# [1115]	validation-mlogloss:0.575644
# [1120]	validation-mlogloss:0.575623
# [1125]	validation-mlogloss:0.575592
# [1130]	validation-mlogloss:0.575649
# [1135]	validation-mlogloss:0.575657
# [1140]	validation-mlogloss:0.575635
# [1145]	validation-mlogloss:0.575709
# [1150]	validation-mlogloss:0.57571
# [1155]	validation-mlogloss:0.575779
# [1160]	validation-mlogloss:0.575857
# [1165]	validation-mlogloss:0.575913
# [1170]	validation-mlogloss:0.575922
# [1175]	validation-mlogloss:0.575805
# [1180]	validation-mlogloss:0.57582
# [1185]	validation-mlogloss:0.575832
# [1190]	validation-mlogloss:0.575805
# [1195]	validation-mlogloss:0.575826
# [1200]	validation-mlogloss:0.575763
# [1205]	validation-mlogloss:0.575751
# [1210]	validation-mlogloss:0.575701
# [1215]	validation-mlogloss:0.575685
# [1220]	validation-mlogloss:0.575671
# [1225]	validation-mlogloss:0.575659
# Stopping. Best iteration:
# [1126]	validation-mlogloss:0.575583

# %%
predicted = np.argmax(model.predict(xgb.DMatrix(test_X),ntree_limit=model.best_ntree_limit),axis=1)
print(metrics.classification_report(test_Y, predicted, target_names = unique_labels))
# Out:
#              precision    recall  f1-score   support
#
#       anger       0.80      0.80      0.80      3769
#        fear       0.79      0.76      0.78      3808
#         joy       0.79      0.81      0.80      3913
#        love       0.84      0.85      0.84      2998
#     sadness       0.76      0.75      0.76      3250
#    surprise       0.77      0.77      0.77      1965
#
# avg / total       0.79      0.79      0.79     19703

# %%
import pickle
with open('xgboost-emotion.pkl','wb') as fopen:
    pickle.dump(model,fopen)

with open('tfidf-xgboost-emotion.pkl','wb') as fopen:
    pickle.dump(tfidf,fopen)
