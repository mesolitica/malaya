# %%
import src.trees_newline as trees

# %%
treebank = trees.load_trees('indon.txt')

# %%
subbatch_sentences = [[(leaf.tag, leaf.word) for leaf in tree.leaves()] for tree in treebank]

# %%
import malaya

malaya.augmentation.synonym('untuk')
# Out:
# ['untuk', 'untuk', 'untuk', 'untuk', 'untuk']

# %%
vocab_news, embedded_news = malaya.wordvector.load_news()
word_vector_news = malaya.wordvector.load(embedded_news, vocab_news)
# Out:
# downloading frozen /home/husein/Malaya/wordvector/news vocab
# 113%|██████████| 4.00/3.55 [00:01<00:00, 2.89MB/s]
# downloading frozen /home/husein/Malaya/wordvector/news model
# 100%|██████████| 191/191 [00:18<00:00, 10.6MB/s]

# %%
word_vector_wiki.n_closest(word='amankan', num_closest=8, metric='cosine')
# Out:
# [['dicarum', 0.9668262004852295],
#  ['roqueforti', 0.9649040699005127],
#  ['godhand', 0.964853048324585],
#  ['gusang', 0.9644500017166138],
#  ['valyushkina', 0.9643106460571289],
#  ['일화', 0.9641432762145996],
#  ['skrotnes', 0.9640423059463501],
#  ['mahanabad', 0.9639478921890259]]

# %%
word_vector_news.n_closest(word='olahraga', num_closest=8, metric='cosine')
# Out:
# [['sepakbola', 0.6757516860961914],
#  ['permotoran', 0.6680614948272705],
#  ['futsal', 0.6669406294822693],
#  ['memanah', 0.6625552177429199],
#  ['berbasikal', 0.6532177925109863],
#  ['teater', 0.6527734398841858],
#  ['ragbi', 0.6510101556777954],
#  ['renang', 0.6498351097106934]]

# %%
malaya.augmentation.wordvector(
    string, word_vector_news, soft = True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-527ea8c86473> in <module>
#       1 malaya.augmentation.wordvector(
# ----> 2     string, word_vector_news, soft = True
#       3 )
#
# NameError: name 'string' is not defined

# %%
subbatch_sentences
# Out:
# [[('NN', 'Kera'),
#   ('IN', 'untuk'),
#   ('-NONE-', '*'),
#   ('VB', 'amankan'),
#   ('NN', 'pesta'),
#   ('NN', 'olahraga')],
#  [('NN', 'Pemerintah'),
#   ('NN', 'kota'),
#   ('NNP', 'Delhi'),
#   ('VB', 'mengerahkan'),
#   ('NN', 'monyet'),
#   ('IN', 'untuk'),
#   ('-NONE-', '*'),
#   ('VB', 'mengusir'),
#   ('NN', 'monyet-monyet'),
#   ('JJ', 'lain'),
#   ('IN', 'yang'),
#   ('-NONE-', '*'),
#   ('VB', 'berbadan'),
#   ('RB', 'lebih'),
#   ('JJ', 'kecil'),
#   ('IN', 'dari'),
#   ('NN', 'arena'),
#   ('NNP', 'Pesta'),
#   ('NNP', 'Olahraga'),
#   ('NNP', 'Persemakmuran'),
#   ('.', '.')],
#  [('DT', 'Beberapa'),
#   ('NN', 'laporan'),
#   ('VB', 'menyebutkan'),
#   ('-NONE-', '0'),
#   ('RB', 'setidaknya'),
#   ('CD', '10'),
#   ('NN', 'monyet'),
#   ('VB', 'ditempatkan'),
#   ('-NONE-', '*-1'),
#   ('IN', 'di'),
#   ('NN', 'luar'),
#   ('NN', 'arena'),
#   ('NN', 'lomba'),
#   ('CC', 'dan'),
#   ('NN', 'pertandingan'),
#   ('IN', 'di'),
#   ('NN', 'ibukota'),
# ...
