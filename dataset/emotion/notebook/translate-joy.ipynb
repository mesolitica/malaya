# %%
with open('joy') as fopen:
    data = list(filter(None, fopen.read().split('\n')))

# %%
print(len(data))
data = [s for s in data if len(s.split()) < 20 and len(s.split()) > 5][:20000]
print(len(data))
# Out:
# 141067
# 20000

# %%
from translate_selenium import Translate, run_parallel_in_threads
batch_size = 10

# %%
translators = [Translate('en','ms') for _ in range(batch_size)]

# %%
from tqdm import tqdm
translated = []
for no in tqdm(range(0, len(data), batch_size), ncols=70):
    strings = data[no: no + batch_size]
    combined = [(translators[i],strings[i],) for i in range(len(strings))]
    translated.extend(run_parallel_in_threads(combined))
# Out:
#   2%|▍                           | 124/8068 [03:23<3:51:41,  1.75s/it]Exception in thread Thread-1248:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   2%|▋                           | 183/8068 [05:10<3:52:58,  1.77s/it]Exception in thread Thread-1836:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   2%|▋                           | 184/8068 [05:12<4:08:02,  1.89s/it]Exception in thread Thread-1853:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   2%|▋                           | 197/8068 [05:36<4:05:29,  1.87s/it]Exception in thread Thread-1978:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:48661","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d9a99000-1005-11e9-b811-4f4deda80abb/element/:wdc:1546595309109/text"}}
# Screenshot: available via screen
#
#
#   3%|▊                           | 233/8068 [06:43<4:11:14,  1.92s/it]Exception in thread Thread-2336:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   5%|█▎                          | 380/8068 [11:19<4:00:51,  1.88s/it]Exception in thread Thread-3810:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   5%|█▍                          | 415/8068 [12:25<4:11:14,  1.97s/it]Exception in thread Thread-4160:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:44694","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/dc953e40-1005-11e9-a38d-0ba9b575c5e6/element/:wdc:1546595309328/text"}}
# Screenshot: available via screen
#
#
# Exception in thread Thread-4159:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:45826","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/db207890-1005-11e9-a9f9-83a9dce00550/element/:wdc:1546595309312/text"}}
# Screenshot: available via screen
#   7%|██                          | 579/8068 [17:57<4:38:11,  2.23s/it]Exception in thread Thread-5799:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   7%|██                          | 594/8068 [18:31<4:38:08,  2.23s/it]Exception in thread Thread-5945:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:50604","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d54d3ac0-1005-11e9-86bc-cb653fa3a68e/element/:wdc:1546595309488/text"}}
# Screenshot: available via screen
#
#
#   7%|██                          | 600/8068 [18:44<4:39:11,  2.24s/it]Exception in thread Thread-6005:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:50604","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d54d3ac0-1005-11e9-86bc-cb653fa3a68e/element/:wdc:1546595309493/text"}}
# Screenshot: available via screen
#
#
#   8%|██▏                         | 636/8068 [20:04<4:40:44,  2.27s/it]Exception in thread Thread-6369:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   8%|██▏                         | 637/8068 [20:07<4:45:39,  2.31s/it]Exception in thread Thread-6376:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:41069","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d6c29cb0-1005-11e9-aa16-d165fc43c6a5/element/:wdc:1546595309507/text"}}
# Screenshot: available via screen
#   8%|██▎                         | 660/8068 [21:01<5:09:49,  2.51s/it]Exception in thread Thread-6605:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:50604","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d54d3ac0-1005-11e9-86bc-cb653fa3a68e/element/:wdc:1546595309545/text"}}
# Screenshot: available via screen
#
#
#   8%|██▎                         | 668/8068 [21:21<5:04:40,  2.47s/it]Exception in thread Thread-6691:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:37639","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/de1a0980-1005-11e9-bb6d-83090862f2d6/element/:wdc:1546595309523/text"}}
# Screenshot: available via screen
#
#
#   8%|██▎                         | 677/8068 [21:42<4:48:04,  2.34s/it]Exception in thread Thread-6784:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:40695","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/e2a42580-1005-11e9-a6c0-71639d9dfbe1/element/:wdc:1546595309549/text"}}
# Screenshot: available via screen
#
#
#   9%|██▍                         | 702/8068 [22:40<4:53:11,  2.39s/it]Exception in thread Thread-7031:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   9%|██▍                         | 716/8068 [23:15<5:00:52,  2.46s/it]Exception in thread Thread-7165:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#   9%|██▌                         | 747/8068 [24:28<4:47:06,  2.35s/it]Exception in thread Thread-7479:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:45826","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/db207890-1005-11e9-a9f9-83a9dce00550/element/:wdc:1546595309605/text"}}
# Screenshot: available via screen
#
#
#   9%|██▋                         | 764/8068 [25:10<5:09:26,  2.54s/it]Exception in thread Thread-7645:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  10%|██▊                         | 826/8068 [27:44<5:07:01,  2.54s/it]Exception in thread Thread-8266:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:41069","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d6c29cb0-1005-11e9-aa16-d165fc43c6a5/element/:wdc:1546595309670/text"}}
# Screenshot: available via screen
#
#
#  10%|██▉                         | 831/8068 [27:56<5:00:12,  2.49s/it]Exception in thread Thread-8323:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:50056","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/e11f5a40-1005-11e9-8ed3-0908806c0dd7/element/:wdc:1546595309682/text"}}
# Screenshot: available via screen
#
#
#  10%|██▉                         | 837/8068 [28:11<4:50:07,  2.41s/it]Exception in thread Thread-8384:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:40695","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/e2a42580-1005-11e9-a6c0-71639d9dfbe1/element/:wdc:1546595309689/text"}}
# Screenshot: available via screen
#  11%|██▉                         | 851/8068 [28:45<4:49:28,  2.41s/it]Exception in thread Thread-8517:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:34789","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d835dbc0-1005-11e9-a0e5-2f59840695e8/element/:wdc:1546595309707/text"}}
# Screenshot: available via screen
#
#
#  11%|██▉                         | 854/8068 [28:52<4:52:08,  2.43s/it]Exception in thread Thread-8554:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:40695","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/e2a42580-1005-11e9-a6c0-71639d9dfbe1/element/:wdc:1546595309704/text"}}
# Screenshot: available via screen
#
#
#  11%|██▉                         | 856/8068 [28:58<5:05:30,  2.54s/it]Exception in thread Thread-8570:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:44694","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/dc953e40-1005-11e9-a38d-0ba9b575c5e6/element/:wdc:1546595309725/text"}}
# Screenshot: available via screen
#
#
#  11%|███                         | 878/8068 [29:51<5:06:27,  2.56s/it]Exception in thread Thread-8790:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:44694","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/dc953e40-1005-11e9-a38d-0ba9b575c5e6/element/:wdc:1546595309744/text"}}
# Screenshot: available via screen
#  11%|███                         | 884/8068 [30:06<4:58:31,  2.49s/it]Exception in thread Thread-8848:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# ...
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 21, in translate
#     self.driver.find_element_by_id('source').send_keys(string.lower())
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 479, in send_keys
#     'value': keys_to_typing(value)})
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 402, in _request
#     resp = http.request(method, url, body=body, headers=headers)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# Exception in thread Thread-18078:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 21, in translate
#     self.driver.find_element_by_id('source').send_keys(string.lower())
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 479, in send_keys
#     'value': keys_to_typing(value)})
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 402, in _request
#     resp = http.request(method, url, body=body, headers=headers)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-18075:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 21, in translate
#     self.driver.find_element_by_id('source').send_keys(string.lower())
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 479, in send_keys
#     'value': keys_to_typing(value)})
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 402, in _request
#     resp = http.request(method, url, body=body, headers=headers)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-18076:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 21, in translate
#     self.driver.find_element_by_id('source').send_keys(string.lower())
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 479, in send_keys
#     'value': keys_to_typing(value)})
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 402, in _request
#     resp = http.request(method, url, body=body, headers=headers)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))

# %%
with open('translated-joy', 'w') as fopen:
    fopen.write('\n'.join(translated))

# %%
len(translated)
# Out:
# 15635
