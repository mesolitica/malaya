# %%
with open('love') as fopen:
    data = list(filter(None, fopen.read().split('\n')))

# %%
print(len(data))
data = [s for s in data if len(s.split()) < 20]
print(len(data))
# Out:
# 34554
# 18091

# %%
from translate_selenium import Translate, run_parallel_in_threads
batch_size = 10

# %%
translators = [Translate('en','ms') for _ in range(batch_size)]

# %%
from tqdm import tqdm
translated = []
for no in tqdm(range(0, len(data), batch_size), ncols=70):
    strings = data[no: no + batch_size]
    combined = [(translators[i],strings[i],) for i in range(len(strings))]
    translated.extend(run_parallel_in_threads(combined))
# Out:
#   0%|                                        | 0/1810 [00:00<?, ?it/s]Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   2%|▋                              | 39/1810 [01:05<49:18,  1.67s/it]Exception in thread Thread-398:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:41532","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/e770efd0-1005-11e9-996f-2dbdb61fad55/element/:wdc:1546595332602/text"}}
# Screenshot: available via screen
#
#
#   4%|█▏                             | 70/1810 [01:57<51:25,  1.77s/it]Exception in thread Thread-705:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:38999","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/e325d8a0-1005-11e9-bdab-43433c3f1578/element/:wdc:1546595332618/text"}}
# Screenshot: available via screen
#
#
#   6%|█▉                            | 116/1810 [03:18<51:09,  1.81s/it]Exception in thread Thread-1165:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  10%|██▉                           | 175/1810 [05:04<48:32,  1.78s/it]Exception in thread Thread-1760:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  10%|██▉                           | 179/1810 [05:12<51:09,  1.88s/it]Exception in thread Thread-1801:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  11%|███▎                          | 199/1810 [05:48<50:04,  1.86s/it]Exception in thread Thread-2000:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:36522","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/ea6be050-1005-11e9-ac55-ef8ffc0ddff9/element/:wdc:1546595332751/text"}}
# Screenshot: available via screen
#  12%|███▍                          | 209/1810 [06:08<51:22,  1.93s/it]Exception in thread Thread-2099:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:60520","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/e8e910e0-1005-11e9-b856-d365906c5fba/element/:wdc:1546595332751/text"}}
# Screenshot: available via screen
#
#
#  12%|███▌                          | 213/1810 [06:15<49:49,  1.87s/it]Exception in thread Thread-2141:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:52818","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/ec0a7520-1005-11e9-bde9-454fd0b77e12/element/:wdc:1546595332764/text"}}
# Screenshot: available via screen
#
#
#  12%|███▋                          | 223/1810 [06:34<48:06,  1.82s/it]Exception in thread Thread-2236:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:50494","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/e4ac0370-1005-11e9-b061-05aa7822f438/element/:wdc:1546595332757/text"}}
# Screenshot: available via screen
#
#
#  14%|████                          | 248/1810 [07:21<48:45,  1.87s/it]Exception in thread Thread-2488:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  14%|████▏                         | 249/1810 [07:23<50:07,  1.93s/it]Exception in thread Thread-2495:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:38999","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/e325d8a0-1005-11e9-bdab-43433c3f1578/element/:wdc:1546595332780/text"}}
# Screenshot: available via screen
#  14%|████▎                         | 257/1810 [07:38<49:15,  1.90s/it]Exception in thread Thread-2582:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  17%|█████▏                        | 310/1810 [09:18<46:58,  1.88s/it]Exception in thread Thread-3107:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:44213","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/e5db34a0-1005-11e9-9ed4-9720e4b10569/element/:wdc:1546595332826/text"}}
# Screenshot: available via screen
#
#
#  17%|█████▏                        | 315/1810 [09:27<47:21,  1.90s/it]Exception in thread Thread-3162:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  18%|█████▍                        | 326/1810 [09:48<48:21,  1.95s/it]Exception in thread Thread-3272:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:44342","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/ed7ca2c0-1005-11e9-a052-9570b62672b4/element/:wdc:1546595332877/text"}}
# Screenshot: available via screen
#
#
#  19%|█████▌                        | 335/1810 [10:06<47:25,  1.93s/it]Exception in thread Thread-3355:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  19%|█████▊                        | 350/1810 [10:33<44:00,  1.81s/it]Exception in thread Thread-3512:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:44342","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/ed7ca2c0-1005-11e9-a052-9570b62672b4/element/:wdc:1546595332897/text"}}
# Screenshot: available via screen
#  23%|███████                       | 425/1810 [12:57<45:22,  1.97s/it]Exception in thread Thread-4261:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:52818","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/ec0a7520-1005-11e9-bde9-454fd0b77e12/element/:wdc:1546595332940/text"}}
# Screenshot: available via screen
#
#
#  28%|████████▍                     | 511/1810 [15:47<43:54,  2.03s/it]Exception in thread Thread-5118:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:41532","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/e770efd0-1005-11e9-996f-2dbdb61fad55/element/:wdc:1546595333027/text"}}
# Screenshot: available via screen
#
#
# Exception in thread Thread-5115:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:38999","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/e325d8a0-1005-11e9-bdab-43433c3f1578/element/:wdc:1546595333018/text"}}
# Screenshot: available via screen
#
#
# Exception in thread Thread-5116:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  29%|████████▌                     | 517/1810 [16:00<46:23,  2.15s/it]Exception in thread Thread-5180:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#  29%|████████▋                     | 522/1810 [16:10<43:40,  2.03s/it]Exception in thread Thread-5230:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  29%|████████▋                     | 525/1810 [16:17<44:46,  2.09s/it]Exception in thread Thread-5255:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
# Exception in thread Thread-5262:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  32%|█████████▋                    | 582/1810 [18:20<44:57,  2.20s/it]Exception in thread Thread-5829:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:60520","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/e8e910e0-1005-11e9-b856-d365906c5fba/element/:wdc:1546595333066/text"}}
# Screenshot: available via screen
#
#
#  33%|█████████▉                    | 598/1810 [18:57<47:48,  2.37s/it]Exception in thread Thread-5989:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  34%|██████████                    | 607/1810 [19:17<43:48,  2.19s/it]Exception in thread Thread-6082:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  35%|██████████▋                   | 642/1810 [20:37<49:16,  2.53s/it]Exception in thread Thread-6431:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:52818","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/ec0a7520-1005-11e9-bde9-454fd0b77e12/element/:wdc:1546595333137/text"}}
# Screenshot: available via screen
#  38%|███████████▍                  | 690/1810 [22:32<47:54,  2.57s/it]Exception in thread Thread-6908:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  46%|█████████████▊                | 832/1810 [28:19<40:10,  2.46s/it]Exception in thread Thread-8332:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  46%|█████████████▊                | 836/1810 [28:29<39:48,  2.45s/it]Exception in thread Thread-8367:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
# ...
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:44213","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/e5db34a0-1005-11e9-9ed4-9720e4b10569/element/:wdc:1546595334042/text"}}
# Screenshot: available via screen
#
#
#  95%|█████████████████████████▌ | 1715/1810 [1:16:57<05:57,  3.76s/it]Exception in thread Thread-17164:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:60642","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/f0930a80-1005-11e9-9e9b-3df24b97f8d0/element/:wdc:1546595334118/text"}}
# Screenshot: available via screen
#
#
#  95%|█████████████████████████▋ | 1719/1810 [1:17:13<06:10,  4.07s/it]Exception in thread Thread-17195:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:38999","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/e325d8a0-1005-11e9-bdab-43433c3f1578/element/:wdc:1546595334067/text"}}
# Screenshot: available via screen
#  96%|█████████████████████████▊ | 1732/1810 [1:18:03<05:16,  4.06s/it]Exception in thread Thread-17327:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  97%|██████████████████████████ | 1748/1810 [1:19:01<03:41,  3.58s/it]Exception in thread Thread-17494:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:60642","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/f0930a80-1005-11e9-9e9b-3df24b97f8d0/element/:wdc:1546595334146/text"}}
# Screenshot: available via screen
#
#
#  97%|██████████████████████████▏| 1755/1810 [1:19:28<03:25,  3.74s/it]Exception in thread Thread-17555:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:38999","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/e325d8a0-1005-11e9-bdab-43433c3f1578/element/:wdc:1546595334099/text"}}
# Screenshot: available via screen
#
#
#  98%|██████████████████████████▌| 1779/1810 [1:21:02<01:49,  3.54s/it]Exception in thread Thread-17797:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:44213","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/e5db34a0-1005-11e9-9ed4-9720e4b10569/element/:wdc:1546595334108/text"}}
# Screenshot: available via screen
#
#
#  98%|██████████████████████████▌| 1780/1810 [1:21:05<01:49,  3.64s/it]Exception in thread Thread-17811:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
# 100%|██████████████████████████▉| 1805/1810 [1:22:17<00:12,  2.60s/it]Exception in thread Thread-18058:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
# 100%|███████████████████████████| 1810/1810 [1:22:30<00:00,  2.31s/it]

# %%
with open('translated-love', 'w') as fopen:
    fopen.write('\n'.join(translated))

# %%
len(translated)
# Out:
# 15232
