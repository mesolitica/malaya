# %%
with open('fear') as fopen:
    data = list(filter(None, fopen.read().split('\n')))

# %%
print(len(data))
data = [s for s in data if len(s.split()) < 20 and len(s.split()) > 5][:20000]
print(len(data))
# Out:
# 47712
# 20000

# %%
from translate_selenium import Translate, run_parallel_in_threads
batch_size = 10

# %%
translators = [Translate('en','ms') for _ in range(batch_size)]

# %%
from tqdm import tqdm
translated = []
for no in tqdm(range(0, len(data), batch_size), ncols=70):
    strings = data[no: no + batch_size]
    combined = [(translators[i],strings[i],) for i in range(len(strings))]
    translated.extend(run_parallel_in_threads(combined))
# Out:
#   4%|█▏                          | 120/2828 [02:40<1:04:38,  1.43s/it]Exception in thread Thread-1213:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   6%|█▋                          | 169/2828 [04:04<1:17:48,  1.76s/it]Exception in thread Thread-1695:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   9%|██▍                         | 247/2828 [06:20<1:22:39,  1.92s/it]Exception in thread Thread-2482:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  11%|███                         | 314/2828 [08:27<1:21:34,  1.95s/it]Exception in thread Thread-3149:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  12%|███▎                        | 330/2828 [08:58<1:17:21,  1.86s/it]Exception in thread Thread-3305:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  12%|███▍                        | 347/2828 [09:31<1:20:30,  1.95s/it]Exception in thread Thread-3477:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:54534","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/f835e3c0-0ffb-11e9-a79f-4136d6a4d1f4/element/:wdc:1546591067599/text"}}
# Screenshot: available via screen
#
#
#  13%|███▋                        | 376/2828 [10:27<1:18:30,  1.92s/it]Exception in thread Thread-3771:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  15%|████▏                       | 428/2828 [12:09<1:19:09,  1.98s/it]Exception in thread Thread-4288:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  17%|████▊                       | 482/2828 [13:58<1:19:26,  2.03s/it]Exception in thread Thread-4833:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:45667","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/00fa2700-0ffc-11e9-ba58-e762e0e6c185/element/:wdc:1546591067745/text"}}
# Screenshot: available via screen
#  17%|████▊                       | 490/2828 [14:14<1:21:32,  2.09s/it]Exception in thread Thread-4912:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:34169","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/ff89a710-0ffb-11e9-92ad-1f0c3b3a9af7/element/:wdc:1546591067738/text"}}
# Screenshot: available via screen
#
#
#  19%|█████▏                      | 529/2828 [15:36<1:22:52,  2.16s/it]Exception in thread Thread-5297:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  21%|█████▊                      | 592/2828 [17:52<1:23:52,  2.25s/it]Exception in thread Thread-5932:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:34169","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/ff89a710-0ffb-11e9-92ad-1f0c3b3a9af7/element/:wdc:1546591067826/text"}}
# Screenshot: available via screen
#
#
#  21%|█████▊                      | 593/2828 [17:54<1:23:47,  2.25s/it]Exception in thread Thread-5938:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  23%|██████▎                     | 640/2828 [19:37<1:21:50,  2.24s/it]Exception in thread Thread-6409:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  23%|██████▌                     | 662/2828 [20:26<1:18:56,  2.19s/it]Exception in thread Thread-6625:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:36087","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/f5533630-0ffb-11e9-b461-799154696b76/element/:wdc:1546591067875/text"}}
# Screenshot: available via screen
#  24%|██████▋                     | 672/2828 [20:48<1:20:56,  2.25s/it]Exception in thread Thread-6734:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  27%|███████▌                    | 758/2828 [24:02<1:18:24,  2.27s/it]Exception in thread Thread-7589:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  27%|███████▌                    | 763/2828 [24:13<1:15:05,  2.18s/it]Exception in thread Thread-7636:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  29%|████████                    | 808/2828 [25:55<1:19:55,  2.37s/it]Exception in thread Thread-8085:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:36087","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/f5533630-0ffb-11e9-b461-799154696b76/element/:wdc:1546591068009/text"}}
# Screenshot: available via screen
#
#
#  29%|████████                    | 815/2828 [26:13<1:24:22,  2.52s/it]Exception in thread Thread-8161:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:44717","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/fe197540-0ffb-11e9-b2c8-c98068530608/element/:wdc:1546591068051/text"}}
# Screenshot: available via screen
#
#
#  29%|████████▏                   | 830/2828 [26:50<1:23:09,  2.50s/it]Exception in thread Thread-8314:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:57825","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/026bdf70-0ffc-11e9-99e9-b1efc3aabe22/element/:wdc:1546591068057/text"}}
# Screenshot: available via screen
#  31%|████████▌                   | 866/2828 [28:20<1:26:47,  2.65s/it]Exception in thread Thread-8671:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:44717","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/fe197540-0ffb-11e9-b2c8-c98068530608/element/:wdc:1546591068099/text"}}
# Screenshot: available via screen
#
#
#  32%|█████████                   | 917/2828 [30:22<1:19:21,  2.49s/it]Exception in thread Thread-9179:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:58823","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/fb35b640-0ffb-11e9-b4e0-41b6270b0807/element/:wdc:1546591068150/text"}}
# Screenshot: available via screen
#
#
#  33%|█████████▏                  | 933/2828 [31:02<1:21:41,  2.59s/it]Exception in thread Thread-9339:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:58823","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/fb35b640-0ffb-11e9-b4e0-41b6270b0807/element/:wdc:1546591068164/text"}}
# Screenshot: available via screen
#
#
#  34%|█████████▍                  | 951/2828 [31:48<1:22:31,  2.64s/it]Exception in thread Thread-9524:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:57825","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/026bdf70-0ffc-11e9-99e9-b1efc3aabe22/element/:wdc:1546591068161/text"}}
# Screenshot: available via screen
#  34%|█████████▌                  | 961/2828 [32:14<1:17:55,  2.50s/it]Exception in thread Thread-9617:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:54534","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/f835e3c0-0ffb-11e9-a79f-4136d6a4d1f4/element/:wdc:1546591068150/text"}}
# Screenshot: available via screen
#
#
#  34%|█████████▌                  | 966/2828 [32:26<1:15:49,  2.44s/it]Exception in thread Thread-9668:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:59543","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/f9a63ca0-0ffb-11e9-9ddc-ef61d2c6accd/element/:wdc:1546591068164/text"}}
# Screenshot: available via screen
#
#
#  35%|█████████▊                  | 992/2828 [33:35<1:19:25,  2.60s/it]Exception in thread Thread-9927:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:54534","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/f835e3c0-0ffb-11e9-a79f-4136d6a4d1f4/element/:wdc:1546591068179/text"}}
# Screenshot: available via screen
#
#
#  36%|█████████▋                 | 1010/2828 [34:24<1:21:18,  2.68s/it]Exception in thread Thread-10114:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:57825","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/026bdf70-0ffc-11e9-99e9-b1efc3aabe22/element/:wdc:1546591068212/text"}}
# Screenshot: available via screen
#  36%|█████████▋                 | 1021/2828 [34:53<1:21:56,  2.72s/it]Exception in thread Thread-10218:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# ...
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 21, in translate
#     self.driver.find_element_by_id('source').send_keys(string.lower())
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 479, in send_keys
#     'value': keys_to_typing(value)})
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 402, in _request
#     resp = http.request(method, url, body=body, headers=headers)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# Exception in thread Thread-16331:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 21, in translate
#     self.driver.find_element_by_id('source').send_keys(string.lower())
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 479, in send_keys
#     'value': keys_to_typing(value)})
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 402, in _request
#     resp = http.request(method, url, body=body, headers=headers)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-16332:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 21, in translate
#     self.driver.find_element_by_id('source').send_keys(string.lower())
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 479, in send_keys
#     'value': keys_to_typing(value)})
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 402, in _request
#     resp = http.request(method, url, body=body, headers=headers)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-16329:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 21, in translate
#     self.driver.find_element_by_id('source').send_keys(string.lower())
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 479, in send_keys
#     'value': keys_to_typing(value)})
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 402, in _request
#     resp = http.request(method, url, body=body, headers=headers)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))

# %%
with open('translated-fear', 'w') as fopen:
    fopen.write('\n'.join(translated))

# %%
len(translated)
# Out:
# 14492
