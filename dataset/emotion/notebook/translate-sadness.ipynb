# %%
with open('sadness') as fopen:
    data = list(filter(None, fopen.read().split('\n')))

# %%
print(len(data))
data = [s for s in data if len(s.split()) < 20 and len(s.split()) > 4]
print(len(data))
# Out:
# 121187
# 71460

# %%
from translate_selenium import Translate, run_parallel_in_threads
batch_size = 10

# %%
translators = [Translate('en','ms') for _ in range(batch_size)]

# %%
from tqdm import tqdm
translated = []
for no in tqdm(range(0, len(data), batch_size), ncols=70):
    strings = data[no: no + batch_size]
    combined = [(translators[i],strings[i],) for i in range(len(strings))]
    translated.extend(run_parallel_in_threads(combined))
# Out:
#   1%|▎                            | 75/7146 [01:55<3:11:45,  1.63s/it]Exception in thread Thread-758:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:41171","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/008fca70-1012-11e9-aa33-8f391df1028f/element/:wdc:1546600528244/text"}}
# Screenshot: available via screen
#
#
#   1%|▎                            | 81/7146 [02:04<3:08:18,  1.60s/it]Exception in thread Thread-824:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:42111","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/097ea020-1012-11e9-9f3a-153c55adb51a/element/:wdc:1546600528257/text"}}
# Screenshot: available via screen
#
#
#   1%|▍                           | 105/7146 [02:46<3:21:57,  1.72s/it]Exception in thread Thread-1055:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   2%|▌                           | 132/7146 [03:32<3:06:12,  1.59s/it]Exception in thread Thread-1325:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:40977","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/fc337530-1011-11e9-9e93-5b77277635ae/element/:wdc:1546600528290/text"}}
# Screenshot: available via screen
#
#
#   2%|▌                           | 137/7146 [03:42<3:38:39,  1.87s/it]Exception in thread Thread-1376:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#   4%|█                           | 259/7146 [07:20<3:14:27,  1.69s/it]Exception in thread Thread-2603:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   4%|█▏                          | 306/7146 [08:44<3:44:50,  1.97s/it]Exception in thread Thread-3073:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   4%|█▏                          | 315/7146 [09:00<3:25:22,  1.80s/it]Exception in thread Thread-3159:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   5%|█▍                          | 355/7146 [10:14<3:29:33,  1.85s/it]Exception in thread Thread-3561:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   5%|█▍                          | 377/7146 [10:57<3:23:13,  1.80s/it]Exception in thread Thread-3777:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:33868","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/fef81370-1011-11e9-9894-37f0d995762b/element/:wdc:1546600528521/text"}}
# Screenshot: available via screen
#
#
#   6%|█▋                          | 427/7146 [12:33<3:48:40,  2.04s/it]Exception in thread Thread-4282:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   6%|█▋                          | 444/7146 [13:08<3:54:55,  2.10s/it]Exception in thread Thread-4446:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   6%|█▋                          | 445/7146 [13:10<3:56:07,  2.11s/it]Exception in thread Thread-4458:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   7%|█▉                          | 492/7146 [14:46<4:09:40,  2.25s/it]Exception in thread Thread-4933:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   7%|█▉                          | 499/7146 [15:02<3:56:07,  2.13s/it]Exception in thread Thread-5004:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:42111","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/097ea020-1012-11e9-9f3a-153c55adb51a/element/:wdc:1546600528630/text"}}
# Screenshot: available via screen
#   7%|█▉                          | 507/7146 [15:19<3:32:24,  1.92s/it]Exception in thread Thread-5078:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   7%|█▉                          | 508/7146 [15:21<3:40:47,  2.00s/it]Exception in thread Thread-5091:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:51686","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/055011a0-1012-11e9-acbb-9782165f57a9/element/:wdc:1546600528649/text"}}
# Screenshot: available via screen
#
#
#   7%|██                          | 512/7146 [15:30<4:00:14,  2.17s/it]Exception in thread Thread-5134:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   7%|██                          | 527/7146 [16:05<4:02:57,  2.20s/it]Exception in thread Thread-5278:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:41171","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/008fca70-1012-11e9-aa33-8f391df1028f/element/:wdc:1546600528647/text"}}
# Screenshot: available via screen
#
#
#   8%|██▏                         | 560/7146 [17:17<4:20:00,  2.37s/it]Exception in thread Thread-5606:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   8%|██▏                         | 561/7146 [17:20<4:19:41,  2.37s/it]Exception in thread Thread-5623:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   8%|██▎                         | 593/7146 [18:32<4:00:45,  2.20s/it]Exception in thread Thread-5940:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#   8%|██▎                         | 597/7146 [18:42<4:16:42,  2.35s/it]Exception in thread Thread-5975:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   9%|██▍                         | 624/7146 [19:44<4:25:07,  2.44s/it]Exception in thread Thread-6246:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:47434","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/fdc44e60-1011-11e9-8460-53e8b3dfb74f/element/:wdc:1546600528722/text"}}
# Screenshot: available via screen
#
#
#   9%|██▌                         | 643/7146 [20:30<4:34:28,  2.53s/it]Exception in thread Thread-6442:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:33928","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/06c96b30-1012-11e9-85ce-e5e410fea26a/element/:wdc:1546600528754/text"}}
# Screenshot: available via screen
#
#
#   9%|██▌                         | 669/7146 [21:34<4:39:24,  2.59s/it]Exception in thread Thread-6695:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   9%|██▋                         | 675/7146 [21:48<4:25:00,  2.46s/it]Exception in thread Thread-6764:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:42111","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/097ea020-1012-11e9-9f3a-153c55adb51a/element/:wdc:1546600528781/text"}}
# Screenshot: available via screen
#  10%|██▋                         | 697/7146 [22:40<4:08:38,  2.31s/it]Exception in thread Thread-6975:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:40977","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/fc337530-1011-11e9-9e93-5b77277635ae/element/:wdc:1546600528789/text"}}
# Screenshot: available via screen
#
#
#  10%|██▊                         | 718/7146 [23:36<4:58:31,  2.79s/it]Exception in thread Thread-7185:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:40977","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/fc337530-1011-11e9-9e93-5b77277635ae/element/:wdc:1546600528807/text"}}
# Screenshot: available via screen
#
#
#  10%|██▊                         | 719/7146 [23:38<4:36:10,  2.58s/it]Exception in thread Thread-7201:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  10%|██▊                         | 733/7146 [24:14<4:44:40,  2.66s/it]Exception in thread Thread-7341:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:51686","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/055011a0-1012-11e9-acbb-9782165f57a9/element/:wdc:1546600528847/text"}}
# Screenshot: available via screen
#
#
#  10%|██▉                         | 742/7146 [24:37<4:33:39,  2.56s/it]Exception in thread Thread-7430:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#  11%|███                         | 777/7146 [26:12<4:29:55,  2.54s/it]Exception in thread Thread-7776:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:47434","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/fdc44e60-1011-11e9-8460-53e8b3dfb74f/element/:wdc:1546600528856/text"}}
# Screenshot: available via screen
#
#
#  11%|███▏                        | 798/7146 [27:02<4:18:50,  2.45s/it]Exception in thread Thread-7993:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# ...
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 21, in translate
#     self.driver.find_element_by_id('source').send_keys(string.lower())
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 479, in send_keys
#     'value': keys_to_typing(value)})
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 402, in _request
#     resp = http.request(method, url, body=body, headers=headers)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-19022:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 21, in translate
#     self.driver.find_element_by_id('source').send_keys(string.lower())
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 479, in send_keys
#     'value': keys_to_typing(value)})
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 402, in _request
#     resp = http.request(method, url, body=body, headers=headers)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-19024:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 21, in translate
#     self.driver.find_element_by_id('source').send_keys(string.lower())
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 479, in send_keys
#     'value': keys_to_typing(value)})
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 402, in _request
#     resp = http.request(method, url, body=body, headers=headers)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-19023:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 21, in translate
#     self.driver.find_element_by_id('source').send_keys(string.lower())
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 479, in send_keys
#     'value': keys_to_typing(value)})
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py", line 402, in _request
#     resp = http.request(method, url, body=body, headers=headers)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/usr/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.5/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))

# %%
with open('translated-sadness', 'w') as fopen:
    fopen.write('\n'.join(translated))

# %%
len(translated)
# Out:
# 16053
