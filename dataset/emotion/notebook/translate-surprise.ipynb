# %%
with open('surprise') as fopen:
    data = list(filter(None, fopen.read().split('\n')))

# %%
print(len(data))
print(len(data))
# Out:
# 14972
# 14972

# %%
from translate_selenium import Translate, run_parallel_in_threads
batch_size = 10

# %%
translators = [Translate('en','ms') for _ in range(batch_size)]

# %%
from tqdm import tqdm
translated = []
for no in tqdm(range(0, len(data), batch_size), ncols=70):
    strings = data[no: no + batch_size]
    combined = [(translators[i],strings[i],) for i in range(len(strings))]
    translated.extend(run_parallel_in_threads(combined))
# Out:
#   1%|▎                              | 15/1498 [00:27<43:04,  1.74s/it]Exception in thread Thread-157:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:45447","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/cba41f50-1011-11e9-9594-adc54b496956/element/:wdc:1546600442637/text"}}
# Screenshot: available via screen
#
#
#   3%|▉                              | 44/1498 [01:16<39:47,  1.64s/it]Exception in thread Thread-449:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:46981","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/cec92d10-1011-11e9-bf6e-9936eae09f58/element/:wdc:1546600442683/text"}}
# Screenshot: available via screen
#
#
#   5%|█▋                             | 80/1498 [02:15<39:48,  1.68s/it]Exception in thread Thread-811:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:51879","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d1f1e450-1011-11e9-a385-41fdfc894e80/element/:wdc:1546600442742/text"}}
# Screenshot: available via screen
#
#
#   6%|█▉                             | 92/1498 [02:37<43:33,  1.86s/it]Exception in thread Thread-934:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:58763","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d686aeb0-1011-11e9-8e0f-d9f70df84453/element/:wdc:1546600442723/text"}}
# Screenshot: available via screen
#   6%|█▉                             | 93/1498 [02:39<44:32,  1.90s/it]Exception in thread Thread-936:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#   7%|██                            | 103/1498 [03:00<49:23,  2.12s/it]Exception in thread Thread-1044:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:58763","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d686aeb0-1011-11e9-8e0f-d9f70df84453/element/:wdc:1546600442732/text"}}
# Screenshot: available via screen
#
#
#   7%|██▏                           | 112/1498 [03:18<45:57,  1.99s/it]Exception in thread Thread-1129:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:46981","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/cec92d10-1011-11e9-bf6e-9936eae09f58/element/:wdc:1546600442736/text"}}
# Screenshot: available via screen
#
#
#   8%|██▎                           | 113/1498 [03:20<45:35,  1.98s/it]Exception in thread Thread-1143:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:41108","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d509d2b0-1011-11e9-850e-1d68b02aeb8f/element/:wdc:1546600442727/text"}}
# Screenshot: available via screen
#
#
#   8%|██▎                           | 115/1498 [03:24<47:04,  2.04s/it]Exception in thread Thread-1161:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:51879","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d1f1e450-1011-11e9-a385-41fdfc894e80/element/:wdc:1546600442767/text"}}
# Screenshot: available via screen
#   8%|██▍                           | 121/1498 [03:36<47:08,  2.05s/it]Exception in thread Thread-1223:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:41108","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d509d2b0-1011-11e9-850e-1d68b02aeb8f/element/:wdc:1546600442732/text"}}
# Screenshot: available via screen
#
#
#   8%|██▌                           | 126/1498 [03:46<45:39,  2.00s/it]Exception in thread Thread-1274:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  10%|██▉                           | 149/1498 [04:33<43:13,  1.92s/it]Exception in thread Thread-1503:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  12%|███▋                          | 186/1498 [05:48<44:04,  2.02s/it]Exception in thread Thread-1869:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:46981","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/cec92d10-1011-11e9-bf6e-9936eae09f58/element/:wdc:1546600442794/text"}}
# Screenshot: available via screen
#
#
#  13%|███▉                          | 194/1498 [06:04<41:20,  1.90s/it]Exception in thread Thread-1949:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  13%|████                          | 201/1498 [06:19<45:48,  2.12s/it]Exception in thread Thread-2021:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
# Exception in thread Thread-2016:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#  14%|████                          | 204/1498 [06:25<42:51,  1.99s/it]Exception in thread Thread-2054:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  14%|████                          | 205/1498 [06:28<45:58,  2.13s/it]Exception in thread Thread-2056:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:50699","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/c982c5f0-1011-11e9-96eb-8127dba072c1/element/:wdc:1546600442781/text"}}
# Screenshot: available via screen
#
#
# Exception in thread Thread-2062:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  15%|████▎                         | 218/1498 [06:55<43:38,  2.05s/it]Exception in thread Thread-2192:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:52421","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d377e810-1011-11e9-8b30-b9ccc2f2b6f3/element/:wdc:1546600442811/text"}}
# Screenshot: available via screen
#
#
#  16%|████▊                         | 243/1498 [07:46<40:32,  1.94s/it]Exception in thread Thread-2442:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  16%|████▉                         | 245/1498 [07:51<45:09,  2.16s/it]Exception in thread Thread-2456:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:50699","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/c982c5f0-1011-11e9-96eb-8127dba072c1/element/:wdc:1546600442812/text"}}
# Screenshot: available via screen
#  17%|█████▏                        | 258/1498 [08:19<42:23,  2.05s/it]Exception in thread Thread-2590:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:51151","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d0528c30-1011-11e9-9397-b5e6503f259a/element/:wdc:1546600442856/text"}}
# Screenshot: available via screen
#
#
#  17%|█████▏                        | 261/1498 [08:25<43:33,  2.11s/it]Exception in thread Thread-2623:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  18%|█████▍                        | 271/1498 [08:48<48:05,  2.35s/it]Exception in thread Thread-2717:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:45447","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/cba41f50-1011-11e9-9594-adc54b496956/element/:wdc:1546600442843/text"}}
# Screenshot: available via screen
#
#
#  20%|██████                        | 302/1498 [09:54<38:00,  1.91s/it]Exception in thread Thread-3028:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:36362","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/cd242fa0-1011-11e9-9878-0bedf4c09e7b/element/:wdc:1546600442864/text"}}
# Screenshot: available via screen
#
#
#  20%|██████                        | 303/1498 [09:56<39:41,  1.99s/it]Exception in thread Thread-3036:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#  22%|██████▌                       | 327/1498 [10:46<40:11,  2.06s/it]Exception in thread Thread-3281:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  27%|████████▏                     | 408/1498 [13:28<32:51,  1.81s/it]Exception in thread Thread-4088:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:36362","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/cd242fa0-1011-11e9-9878-0bedf4c09e7b/element/:wdc:1546600442952/text"}}
# Screenshot: available via screen
#
#
#  27%|████████▏                     | 409/1498 [13:31<37:42,  2.08s/it]Exception in thread Thread-4095:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
# ...
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:51151","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d0528c30-1011-11e9-9397-b5e6503f259a/element/:wdc:1546600443758/text"}}
# Screenshot: available via screen
#
#
#  94%|█████████████████████████▍ | 1414/1498 [1:06:13<04:46,  3.41s/it]Exception in thread Thread-14147:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  95%|█████████████████████████▌ | 1418/1498 [1:06:27<04:49,  3.62s/it]Exception in thread Thread-14191:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:51879","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d1f1e450-1011-11e9-a385-41fdfc894e80/element/:wdc:1546600443785/text"}}
# Screenshot: available via screen
#  95%|█████████████████████████▊ | 1429/1498 [1:07:15<05:13,  4.54s/it]Exception in thread Thread-14304:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:58763","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d686aeb0-1011-11e9-8e0f-d9f70df84453/element/:wdc:1546600443788/text"}}
# Screenshot: available via screen
#
#
#  96%|█████████████████████████▉ | 1436/1498 [1:07:43<04:26,  4.29s/it]Exception in thread Thread-14370:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:51151","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d0528c30-1011-11e9-9397-b5e6503f259a/element/:wdc:1546600443780/text"}}
# Screenshot: available via screen
#
#
#  97%|██████████████████████████▏| 1456/1498 [1:09:12<02:49,  4.03s/it]Exception in thread Thread-14573:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  97%|██████████████████████████▎| 1460/1498 [1:09:27<02:20,  3.69s/it]Exception in thread Thread-14610:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:51151","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d0528c30-1011-11e9-9397-b5e6503f259a/element/:wdc:1546600443798/text"}}
# Screenshot: available via screen
#
#
#  98%|██████████████████████████▍| 1469/1498 [1:10:11<02:16,  4.69s/it]Exception in thread Thread-14696:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#  99%|██████████████████████████▌| 1476/1498 [1:10:41<01:28,  4.04s/it]Exception in thread Thread-14774:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 24, in translate
#     return text[0]
# IndexError: list index out of range
#
#  99%|██████████████████████████▋| 1482/1498 [1:11:05<01:09,  4.34s/it]Exception in thread Thread-14833:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/husein/space/translation/translate_selenium.py", line 34, in task_wrapper
#     result.put(target(*args))
#   File "/home/husein/space/translation/translate_selenium.py", line 27, in task_translate
#     return translator.translate(string)
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in translate
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/home/husein/space/translation/translate_selenium.py", line 23, in <listcomp>
#     text = [elem.text for elem in self.driver.find_elements_by_xpath(span)]
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 76, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: {"errorMessage":"Element is no longer attached to the DOM","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:41108","User-Agent":"selenium/3.141.0 (python linux)"},"httpVersion":"1.1","method":"GET","url":"/text","urlParsed":{"anchor":"","query":"","file":"text","directory":"/","path":"/text","relative":"/text","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/text","queryKey":{},"chunks":["text"]},"urlOriginal":"/session/d509d2b0-1011-11e9-850e-1d68b02aeb8f/element/:wdc:1546600443787/text"}}
# Screenshot: available via screen
#
#
# 100%|███████████████████████████| 1498/1498 [1:12:13<00:00,  3.93s/it]

# %%
with open('translated-surprise', 'w') as fopen:
    fopen.write('\n'.join(translated))

# %%
len(translated)
# Out:
# 9712
